# %% [markdown]
# # Lecture 2: Setting up RDS and connection to cloud
# Gittu George, January 9 2025

# %% [markdown]
# ## Todays Agenda
#
# - Connecting to RDS (Postgres)
#
# ## Learning objectives
# - Setup your first cloud database (RDS instance)
# - You will know how to connect to a remote database from a Jupyter notebook.
# - Different ways in interacting with the database from jupyter notebook.
# - Showing different ways of loading the data.
# - You will use queries to bring data into a Jupyter notebook and provide a simple data analysis.

# %% [markdown]
# (settingup)=
# ## Setting up RDS
#
# Demo time
# ```{figure} img/explore.png
# ---
# width: 200px
# align: center
# ---
# ```
#
# I recommend you do this with me or during the class activity time. Or you can watch the youtube video that I made on setting up your first RDS instance.
#
# Here is the youtube video [https://www.youtube.com/watch?v=Wm5zLfpLD8I](https://www.youtube.com/watch?v=Wm5zLfpLD8I)
#
# Consider the database that you built as an independent entity. Then, follow the below instructions to connect to your database in the cloud.

# %% [markdown]
# ## Connecting To Cloud (RDS)
#
# If you haven't yet set it up, please follow instructions in [Setting up RDS](settingup)
#
# OKAY.. so now you have your database ready! In our case, we set up our Postgres database in RDS. Since you are not using an already existing database, you created it, so it's empty now. So we need to load data into this database. After loading data to the database, we are all set with querying from the database.
#
# Whether it's for loading or querying the database, we need to connect to the database.
#
# Well, we have a variety of options to run our SQL statements in PostgreSQL (You already aware of couple of options from your BAIT 507) :
#
# We will be using the following 2 approaches in this course
# - pgAdmin is the official web-based GUI for interacting with PostgreSQL databases
# - `%sql` and `%%sql` magic commands in Jupyter notebooks, which are provided by the `ipython-sql` package
#
# Some other ways you can connect (we won't be discussing these)
# - `psql` is PostgreSQL's interactive command-line interface
# - `psycopg2` is the official Python adapter for PostgreSQL databases
# - Using `.read_sql_query()` method in Pandas
#
#
# ### First thing first
# ***What information do you want to know if you're going to connect to the above?*** We need to know the information of the database that you wanted to connect to
# - Hostname
# - Port number
# - User name (need to make sure that this user have access to the database)
# - Password (Ofcourse !! you need to know the password for this user)
#
# Now let's think about other sources you want to connect to the database. Here are a few that I thought of
# - From a programming language (java, R, python, etc..)
# - From your jupyter notebook
# - From tableau
# - From excel
# - From R Studio
# - OR from any other application that you are using, e.g., your banking website
#
# Besides knowing the hostname, port name, username, and password, we also need to install an Application programming interface (API) that helps the applications on the client-side communicate with the server-side (in our case database). Java Database Connectivity (JDBC) and Open Database Connectivity (ODBC) are 2 of such APIs that are provided by the database vendor (Postgres, Oracle, MySQL, etc..) to access their database.
#
# JDBC is language-specific, and its the standard interface between any java application and database. JDBC converts the java programmer's requests to the database to something that the database understands (you can think of it as a translator). Meanwhile, ODBC is not language-specific, so it can convert requests from any application/software/programming language to something the database understands. Here is a diagram that will help you understand how ODBC works.
#
# <img src="img/connection.png" width= 65%>
#
# ```{sidebar} How ODBC connects ?
# ```{figure} img/odbc.png
# ---
# width: 450px
# align: center
# ---
# ```
# In the rest of the section, let's focus on connecting to the database from python and the jupyter notebook. We will be using specific packages to make this possible, but as we have discussed, it uses ODBC for the connection.

# %% [markdown]
# ### pgAdmin
#
# ```{important}
# You use pgadmin to load dumps for worksheet 2 and assignment 1.
# ```
#
# ```{admonition} Checkout
# Please check [here](../installation/pgadmin.md) for more details on setting up pgadmin and connecting to your database.
# ```
#
# > I like to use a `Shift + Enter` keyboard shortcut to run my queries. You can configure this too by going Preferences -> Query Tool -> Keyboard shortcuts -> Change "Execute query" to `Shift + Enter`.
#
# ### psql
#
# ```{note}
# You can run SQL commands in pgadmin and/or jupyter notebook. ***We don't need this for this course.***
# ```

# %% [markdown]
# ### `ipython-sql` (`%sql` and `%%sql`)
#
# `ipython-sql` is a package that enables us to run SQL statements right from a Jupyter notebook. You should install this package in your conda environment ( you probabily have it [if you used the yml file](../installation/conda.md) to setup your environment). In order to use it, we should load it first:

# %%
# %load_ext sql

# %% [markdown]
# Now we need the host address of where the database is stored, along with a username and a password.
#
# ```{margin}
# <img src="img/secret.png">
# ```
#
# There are a couple of ways to deal with packages. In the following section, I am showing you one way of dealing with passwords, and I recommend the following approach.
#
# It is always a bad idea to store login information directly in a notebook or code file because of security reasons. Say if you want to share this notebook with your colleague, or if somebody came by and looked at your notebook, they can see your database connection details, including your password. It's probably okay now as it's a toy database, but when you start working in the industry, you will be dealing with a database ( or, in other words, business), and it can cause lots of problems if the password is compromised. So, let's practice not doing the connection call by including the credentials directly into your notebook.
#
# In order to avoid that, we store that kind of information in a separate file, like `credentials.json` here, and read the username and password into our IPython session:
#
# ```{note}
# Make sure that your `credentials.json` file looks like this:
# ```json
# {
#   "host": "<the_end_point>",
#   "port": 5432,
#   "user": "postgres",
#   "password": "<your_password>"
# }
# ```
#
# ```{margin}
# <img src='img/demos.png'>
# ```

# %% [markdown]
# This way, you don't have to worry about exposing your password to anyone.
#
# ```{caution}
# Nowhere in assignments/projects should you include the hostname or password. If anything needs to be checked, then TA's will contact you.
# ```

# %%
import json
import urllib.parse

with open('credentials.json') as f:
    login = json.load(f)
    
username = login['user']
password = urllib.parse.quote(login['password'])
host = login['host']
port = login['port']

# %% [markdown]
# Now we can establish the connection to the `postgres` database using the following code:

# %%
# %sql postgresql://{username}:{password}@{host}:{port}/postgres
# Out:
# 'Connected: postgres@postgres'

# %% [markdown]
# Note that we have used the `%sql` line magic to interpret the line in front of it as a magic command.
#
# We can also use `%%sql` cell magic to apply the magic to an entire notebook cell.

# %% [markdown]
# List the relations (i.e. tables) in the database:

# %%
# %%sql
# SELECT *
# FROM pg_catalog.pg_tables
# WHERE schemaname != 'pg_catalog' AND
#     schemaname != 'information_schema';
# Out:
#  * postgresql://postgres:***@database-2.ch0m6kus6nrp.us-east-1.rds.amazonaws.com:5432/postgres
# 9 rows affected.
# [('tweets', 'stockvalues', 'postgres', None, False, False, True, False),
#  ('fakedata', 'testindex', 'postgres', None, True, False, False, False),
#  ('tweets', 'tweets', 'postgres', None, True, False, False, False),
#  ('tweets', 'symbols', 'postgres', None, True, False, True, False),
#  ('tweets', 'cashtags', 'postgres', None, False, False, True, False),
#  ('tweets', 'cleantweets', 'postgres', None, True, False, True, False),
#  ('tweets', 'users', 'postgres', None, True, False, True, False),
#  ('tweets', 'replies', 'postgres', None, False, False, True, False),
#  ('tweets', 'retweets', 'postgres', None, False, False, True, False)]

# %% [markdown]
# Let's run some SQL statements now. Let's retrieve the `name` and `population` columns from the `country` table:

# %%
# %sql SELECT * FROM tweets.symbols limit 10;
# Out:
#  * postgresql://postgres:***@database-2.ch0m6kus6nrp.us-east-1.rds.amazonaws.com:5432/postgres
# 10 rows affected.
# [(1, 'A', 'Agilent Technologies, Inc. Common Stock'),
#  (2, 'AA', 'Alcoa Corporation Common Stock '),
#  (3, 'AAA', 'Listed Funds Trust AAF First Priority CLO Bond ETF'),
#  (4, 'AAAU', 'Goldman Sachs Physical Gold ETF Shares'),
#  (5, 'AAC', 'Ares Acquisition Corporation Class A Ordinary Shares'),
#  (6, 'AAC=', 'Ares Acquisition Corporation Units, each consisting of one Class A ordinary share, and one-fifth of one redeemable warrant'),
#  (7, 'AAC+', 'Ares Acquisition Corporation Redeemable Warrants, each whole warrant exercisable for one Class A ordinary share at an exercise price of $11.50'),
#  (8, 'AAIC', 'Arlington Asset Investment Corp Class A (new)'),
#  (9, 'AAIC-B', 'Arlington Asset Investment Corp 7.00% '),
#  (10, 'AAIC-C', 'Arlington Asset Investment Corp 8.250% Seies C Fixed-to-Floating Rate Cumulative Redeemable Preferred Stock   ')]

# %% [markdown]
# #### Limiting returned and displayed rows
#
# As you can see, all rows are returned and displayed by default. This behaviour can be problematic if our table is very large for two reasons:
# 1. Retrieving large tables can be slow, and maybe not necessary
# 2. Displaying a lot of rows clutters our Jupyter notebook
#
# We can modifying `ipython-sql` configuration to limit the number of returned and displayed rows. For example, here we change the display limit:

# %%
# %config SqlMagic.displaylimit = 10

# %%
# %sql SELECT * FROM tweets.symbols;
# Out:
#  * postgresql://postgres:***@database-2.ch0m6kus6nrp.us-east-1.rds.amazonaws.com:5432/postgres
# 6121 rows affected.
# [(1, 'A', 'Agilent Technologies, Inc. Common Stock'),
#  (2, 'AA', 'Alcoa Corporation Common Stock '),
#  (3, 'AAA', 'Listed Funds Trust AAF First Priority CLO Bond ETF'),
#  (4, 'AAAU', 'Goldman Sachs Physical Gold ETF Shares'),
#  (5, 'AAC', 'Ares Acquisition Corporation Class A Ordinary Shares'),
#  (6, 'AAC=', 'Ares Acquisition Corporation Units, each consisting of one Class A ordinary share, and one-fifth of one redeemable warrant'),
#  (7, 'AAC+', 'Ares Acquisition Corporation Redeemable Warrants, each whole warrant exercisable for one Class A ordinary share at an exercise price of $11.50'),
#  (8, 'AAIC', 'Arlington Asset Investment Corp Class A (new)'),
#  (9, 'AAIC-B', 'Arlington Asset Investment Corp 7.00% '),
#  (10, 'AAIC-C', 'Arlington Asset Investment Corp 8.250% Seies C Fixed-to-Floating Rate Cumulative Redeemable Preferred Stock   '),
#  (11, 'AAIN', 'Arlington Asset Investment Corp 6.000% Senior Notes Due 2026'),
#  (12, 'AAMC', 'Altisource Asset Management Corp Com'),
#  (13, 'AAN', 'Aarons Holdings Company, Inc. Common Stock '),
#  (14, 'AAP', 'Advance Auto Parts Inc Advance Auto Parts Inc W/I'),
#  (15, 'AAQC', 'Accelerate Acquisition Corp. Class A Common Stock'),
#  (16, 'AAQC=', 'Accelerate Acquisition Corp. Units, each consisting of one Class A common stock, and one-third of one redeemable warrant'),
#  (17, 'AAQC+', 'Accelerate Acquisition Corp. Warrants, each whole warrant exercisable for one share of Class A common stock at an exercise price of $11.50'),
#  (18, 'AAT', 'American Assets Trust, Inc. Common Stock'),
#  (19, 'AAU', 'Almaden Minerals, Ltd. Common Shares'),
#  (20, 'AB', 'AllianceBernstein Holding L.P.  Units'),
#  (21, 'ABB', 'ABB Ltd Common Stock'),
#  (22, 'ABBV', 'AbbVie Inc. Common Stock'),
#  (23, 'ABC', 'AmerisourceBergen Corporation Common Stock'),
#  (24, 'ABEQ', 'Absolute Core Strategy ETF'),
#  (25, 'ABEV', 'Ambev S.A. American Depositary Shares (Each representing 1 Common Share)'),
#  (26, 'ABG', 'Asbury Automotive Group Inc Common Stock'),
#  (27, 'ABM', 'ABM Industries Incorporated Common Stock'),
#  (28, 'ABR', 'Arbor Realty Trust Common Stock'),
#  (29, 'ABR-D', 'Arbor Realty Trust 6.375% Series D Cumulative Redeemable Preferred Stock, Liquidation Preference $25.00 per Share'),
#  (30, 'ABT', 'Abbott Laboratories Common Stock'),
#  (31, 'AC', 'Associated Capital Group, Inc. Common Stock'),
#  (32, 'ACA', 'Arcosa, Inc. Common Stock '),
#  (33, 'ACC', 'American Campus Communities Inc Common Stock'),
#  (34, 'ACCO', 'Acco Brands Corporation Common Stock'),
#  (35, 'ACEL', 'Accel Entertainment, Inc. '),
#  (36, 'ACES', 'ALPS Clean Energy ETF'),
#  (37, 'ACH', 'Aluminum Corporation of China Limited American Depositary Shares'),
#  (38, 'ACI', 'Albertsons Companies, Inc. Class A Common Stock'),
#  (39, 'ACIC', 'Atlas Crest Investment Corp. Class A Common Stock'),
#  (40, 'ACIC=', 'Atlas Crest Investment Corp. Units, each consisting of one Class A common stock, and one-third of one redeemable warrant'),
#  (41, 'ACIC+', 'Atlas Crest Investment Corp. Redeemable warrants included as part of the units, each whole warrant exercisable for one Class A common stock at an exercise price of $11.50'),
#  (42, 'ACII', 'Atlas Crest Investment Corp. II Class A Common Stock'),
#  (43, 'ACII=', 'Atlas Crest Investment Corp. II Units, each consisting of one Class A common stock, $.0001 par value, and one-fourth of one redeemable warrant'),
#  (44, 'ACII+', 'Atlas Crest Investment Corp. II Redeemable Warrants, each whole warrant exercisable for one Class A common stock at an exercise price of $11.50'),
#  (45, 'ACIO', 'ETF Series Solutions Aptus Collared Income Opportunity ETF'),
#  (46, 'ACM', 'AECOM Common Stock'),
#  (47, 'ACN', 'Accenture plc Class A Ordinary Shares (Ireland)'),
#  (48, 'ACP', 'Aberdeen Income Credit Strategies Fund Common Shares'),
#  (49, 'ACP-A', 'Aberdeen Income Credit Strategies Fund 5.250% Series A Perpetual Preferred Stock'),
#  (50, 'ACR', 'ACRES Commercial Realty Corp. Common Stock'),
#  (51, 'ACR-C', 'ACRES Commercial Realty Corp. 8.625% Fixed-to-Floating Series C Cumulative Redeemable Preferred Stock '),
#  (52, 'ACR-D', 'ACRES Commercial Realty Corp. 7.875% Series D Cumulative Redeemable Preferred Stock'),
#  (53, 'ACRE', 'Ares Commercial Real Estate Corporation Common Stock'),
#  (54, 'ACRO=', 'Acropolis Infrastructure Acquisition Corp. Units, each consisting of one share of Class A Common Stock and one-third of one Warrant'),
#  (55, 'ACSG', 'Xtrackers MSCI ACWI ex USA ESG Leaders Equity ETF'),
#  (56, 'ACSI', 'American Customer Satisfaction ETF'),
#  (57, 'ACTV', 'LeaderShares Activist Leaders ETF'),
#  (58, 'ACU', 'Acme United Corporation. Common Stock'),
#  (59, 'ACV', 'Virtus AllianzGI Diversified Income & Convertible Fund Common Shares of Beneficial Interest'),
#  (60, 'ACVF', 'American Conservative Values ETF'),
#  (61, 'ACWF', 'iShares MSCI Global Multifactor ETF'),
#  (62, 'ACWV', 'iShares MSCI Global Min Vol Factor ETF'),
#  (63, 'ACY', 'AeroCentury Corp. Common Stock'),
#  (64, 'ADC', 'Agree Realty Corporation Common Stock'),
#  (65, 'ADCT', 'ADC Therapeutics SA Common Shares'),
#  (66, 'ADEX', 'Adit EdTech Acquisition Corp. Common Stock'),
#  (67, 'ADEX=', 'Adit EdTech Acquisition Corp. Units, each consisting of one share of common stock, and one-half of one redeemable warrant'),
#  (68, 'ADEX+', 'Adit EdTech Acquisition Corp. Redeemable Warrants, each whole warrant exercisable for shares of common stock at an exercise price of $11.50 per share'),
#  (69, 'ADF', 'Aldel Financial Inc. Class A Common Stock'),
#  (70, 'ADF=', 'Aldel Financial Inc. Units, each consisting of one share of Class A common stock and one-half of one redeemable warrant'),
#  (71, 'ADF+', 'Aldel Financial Inc. Warrants, each whole warrant entitles the holder thereof to purchase one share of Class A common stock at a price of $11.50 per share'),
#  (72, 'ADFI', 'Anfield Dynamic Fixed Income ETF'),
#  (73, 'ADIV', 'SmartETFs Asia Pacific Dividend Builder ETF'),
#  (74, 'ADM', 'Archer-Daniels-Midland Company Common Stock'),
#  (75, 'ADME', 'Aptus Drawdown Managed Equity ETF'),
#  (76, 'ADNT', 'Adient plc Ordinary Shares '),
#  (77, 'ADRA', 'Adara Acquisition Corp. Class A Common Stock'),
#  (78, 'ADRA=', 'Adara Acquisition Corp. Units, each consisting of one share of Class A common stock, and one-half of one redeemable warrant'),
#  (162, 'AIEQ', 'AI Powered Equity ETF'),
#  (79, 'ADRA+', 'Adara Acquisition Corp. Redeemable Warrants, each whole warrant exercisable for one share of Class A Common Stock at an exercise price of $11.50'),
#  (80, 'ADS', 'Alliance Data Systems Corporation Common Stock'),
#  (81, 'ADT', 'ADT Inc. Common Stock'),
#  (82, 'ADX', 'Adams Diversified Equity Fund Inc.'),
#  (83, 'AE', 'Adams Resources & Energy, Inc. Common Stock'),
#  (84, 'AEB', 'AEGON N.V. Perp. Cap. Secs. Floating Rate (Netherlands)'),
#  (85, 'AEE', 'Ameren Corporation Common Stock'),
#  (86, 'AEF', 'Aberdeen Emerging Markets Equity Income Fund, Inc. Common Stock'),
#  (87, 'AEFC', 'Aegon Funding Company LLC 5.10% Subordinated Notes due 2049'),
#  (88, 'AEG', 'AEGON N.V. Common Stock'),
#  (89, 'AEL', 'American Equity Investment Life Holding Company Common Stock'),
#  (90, 'AEL-A', 'American Equity Investment Life Holding Company Depositary Shares, each representing a 1/1,000th interest in a share of 5.95% Fixed-Rate Reset Non-Cumulative Preferred Stock, Series A'),
#  (91, 'AEL-B', 'American Equity Investment Life Holding Company Depositary Shares, each representing a 1/1,000th interest in a share of 6.625% Fixed-Rate Reset Non-Cumulative Preferred Stock, Series B'),
#  (92, 'AEM', 'Agnico Eagle Mines Limited Common Stock'),
#  (93, 'AEMB', 'American Century Emerging Markets Bond ETF'),
#  (94, 'AENZ', 'Aenza S.A.A. American Depositary Shares'),
#  (95, 'AEO', 'American Eagle Outfitters, Inc. Common Stock'),
#  (96, 'AER', 'AerCap Holdings N.V. Ordinary Shares'),
#  (97, 'AES', 'The AES Corporation Common Stock'),
#  (98, 'AESC', 'The AES Corporation Corporate Units'),
#  (99, 'AESR', 'Anfield U.S. Equity Sector Rotation ETF'),
#  (100, 'AEVA', 'Aeva Technologies, Inc. Common Stock'),
#  (101, 'AEVA+', 'Aeva Technologies, Inc. Redeemable Warrants, each whole warrant exercisable for shares of common stock at an exercise price of $11.50 per share'),
#  (102, 'AFB', 'AllianceBernstein National Municipal Income Fund Inc'),
#  (103, 'AFG', 'American Financial Group, Inc. Common Stock'),
#  (104, 'AFGB', 'American Financial Group, Inc. 5.875% Subordinated Debentures due 2059'),
#  (105, 'AFGC', 'American Financial Group, Inc. 5.125% Subordinated Debentures due 2059'),
#  (106, 'AFGD', 'American Financial Group, Inc. 5.625% Subordinated Debentures due 2060'),
#  (107, 'AFGE', 'American Financial Group, Inc. 4.500% Subordinated Debentures due 2060'),
#  (108, 'AFI', 'Armstrong Flooring, Inc. Common Stock'),
#  (109, 'AFIF', 'Anfield Universal Fixed Income ETF'),
#  (110, 'AFK', 'VanEck Vectors-Africa Index ETF'),
#  (111, 'AFL', 'AFLAC Incorporated Common Stock'),
#  (112, 'AFLG', 'First Trust Active Factor Large Cap ETF'),
#  (113, 'AFMC', 'First Trust Active Factor Mid Cap ETF'),
#  (114, 'AFSM', 'First Trust Active Factor Small Cap ETF'),
#  (115, 'AFT', 'Apollo Senior Floating Rate Fund Inc. Common Stock'),
#  (116, 'AFTY', 'Pacer CSOP FTSE China A50 ETF'),
#  (117, 'AG', 'First Majestic Silver Corp. Ordinary Shares (Canada)'),
#  (118, 'AGAC', 'African Gold Acquisition Corporation Class A Ordinary Shares'),
#  (119, 'AGAC=', 'African Gold Acquisition Corporation Units, each consisting of one Class A ordinary share and three-quarters of one redeemable warrant'),
#  (120, 'AGAC+', 'African Gold Acquisition Corporation Redeemable Warrants, each whole warrant exercisable for one Class A ordinary share at an exercise price of $11.50'),
#  (121, 'AGCB', 'Altimeter Growth Corp. 2 Class A Ordinary Shares'),
#  (122, 'AGCO', 'AGCO Corporation Common Stock'),
#  (123, 'AGD', 'Aberdeen Global Dynamic Dividend Fund'),
#  (124, 'AGE', 'AgeX Therapeutics, Inc. Common Stock'),
#  (125, 'AGG', 'iShares Core U.S. Aggregate Bond ETF'),
#  (126, 'AGGY', 'WisdomTree Yield Enhanced U.S. Aggregate Bond Fund'),
#  (127, 'AGI', 'Alamos Gold Inc. Class A Common Shares'),
#  (128, 'AGL', 'agilon health, inc. Common Stock'),
#  (129, 'AGM', 'Federal Agricultural Mortgage Corporation Common Stock'),
#  (130, 'AGM-C', 'Federal Agricultural Mortgage Corporation Preferred Series C Fixed to Fltg'),
#  (131, 'AGM-D', 'Federal Agricultural Mortgage Corporation 5.700% Non-Cumulative Preferred Stock, Series D'),
#  (132, 'AGM-E', 'Federal Agricultural Mortgage Corporation 5.750% Non-Cumulative Preferred Stock, Series E'),
#  (133, 'AGM-F', 'Federal Agricultural Mortgage Corporation 5.250% Non-Cumulative Preferred Stock, Series F'),
#  (134, 'AGM-G', 'Federal Agricultural Mortgage Corporation 4.875% Non-Cumulative Preferred Stock, Series G'),
#  (135, 'AGM.A', 'Federal Agricultural Mortgage Corporation Common Stock'),
#  (136, 'AGO', 'Assured Guaranty Ltd. Common Stock'),
#  (137, 'AGO-E', 'Assured Guaranty Ltd.'),
#  (138, 'AGO-F', 'Assured Guaranty Ltd.'),
#  (139, 'AGOV', 'Exchange Listed Funds Trust Gavekal Asia Pacific Government Bond ETF'),
#  (140, 'AGOX', 'Adaptive Growth Opportunities ETF'),
#  (141, 'AGQ', 'ProShares Ultra Silver'),
#  (142, 'AGR', 'Avangrid, Inc. Common Stock'),
#  (143, 'AGRO', 'Adecoagro S.A. Common Shares'),
#  (144, 'AGS', 'PlayAGS, Inc. Common Stock'),
#  (145, 'AGT', 'iShares MSCI Argentina and Global Exposure ETF'),
#  (146, 'AGTI', 'Agiliti, Inc. Common Stock'),
#  (147, 'AGX', 'Argan, Inc. Common Stock'),
#  (148, 'AGZ', 'iShares  Agency Bond ETF'),
#  (149, 'AHH', 'Armada Hoffler Properties, Inc. Common Stock'),
#  (150, 'AHH-A', 'Armada Hoffler Properties, Inc. 6.75% Series A Cumulative Redeemable Perpetual Preferred Stock'),
#  (151, 'AHL-C', 'Aspen Insurance Holdings Limited 5.95% Fixed-to-Floating Rate Perpetual Non-Cumulative Preference Shares'),
#  (152, 'AHL-D', 'Aspen Insurance Holdings Limited 5.625% Perpetual Non-Cumulative Preference Shares'),
#  (153, 'AHL-E', 'Aspen Insurance Holdings Limited Depositary Shares, each representing a 1/1000th interest in a share of 5.625% Perpetual Non-Cumulative Preference Shares'),
#  (154, 'AHT', 'Ashford Hospitality Trust Inc Common Stock'),
#  (155, 'AHT-D', 'Ashford Hospitality Trust Inc 8.45% Series D Cumulative Preferred Stock'),
#  (156, 'AHT-F', 'Ashford Hospitality Trust Inc 7.375% Series F Cumulative Preferred Stock'),
#  (157, 'AHT-G', 'Ashford Hospitality Trust Inc 7.375% Series G Cumulative Preferred Stock'),
#  (158, 'AHT-H', 'Ashford Hospitality Trust Inc 7.50% Series H Cumulative Preferred Stock'),
#  (159, 'AHT-I', 'Ashford Hospitality Trust Inc 7.50% Series I Cumulative Preferred Stock'),
#  (160, 'AI', 'C3.ai, Inc. Class A Common Stock'),
#  (161, 'AIC', 'Arlington Asset Investment Corp 6.750% Notes due 2025'),
#  (163, 'AIF', 'Apollo Tactical Income Fund Inc. Common Stock'),
#  (164, 'AIG', 'American International Group, Inc. New Common Stock'),
#  (165, 'AIG-A', 'American International Group, Inc. Depositary Shares Each Representing a 1/1,000th Interest in a Share of Series A 5.85% Non-Cumulative Perpetual Preferred Stock'),
#  (166, 'AIIQ', 'AI Powered International Equity ETF'),
#  (167, 'AIM', 'AIM ImmunoTech Inc. Common Stock'),
#  (168, 'AIN', 'Albany International Corporation Common Stock'),
#  (169, 'AINC', 'Ashford Inc. (Holding Company) Common Stock'),
#  (170, 'AIO', 'Virtus AllianzGI Artificial Intelligence & Technology Opportunities Fund Common Shares'),
#  (171, 'AIR', 'AAR Corp. Common Stock'),
#  (172, 'AIRC', 'Apartment Income REIT Corp. Common Stock'),
#  (173, 'AIRI', 'Air Industries Group Common Stock'),
#  (174, 'AIT', 'Applied Industrial Technologies, Inc. Common Stock'),
#  (175, 'AIV', 'Apartment Investment and Management Company Common Stock'),
#  (176, 'AIZ', 'Assurant, Inc. Common Stock'),
#  (177, 'AIZN', 'Assurant, Inc. 5.25% Subordinated Notes due 2061'),
#  (178, 'AJAX', 'Ajax I Class A Ordinary Shares'),
#  (179, 'AJAX=', 'Ajax I Units, each consisting of one Class A ordinary share and one-fourth of one redeemable warrant'),
#  (180, 'AJAX+', 'Ajax I Redeemable warrants, each whole warrant exercisable for one Class A ordinary share at an exercise price of $11.50'),
#  (181, 'AJG', 'Arthur J. Gallagher & Co. Common Stock'),
#  (182, 'AJRD', 'Aerojet Rocketdyne Holdings, Inc. Common Stock'),
#  (183, 'AJX', 'Great Ajax Corp. Common Stock'),
#  (184, 'AJXA', 'Great Ajax Corp. 7.25% Convertible Senior Notes due 2024'),
#  (185, 'AKO.A', 'Embotelladora Andina S.A. Common Stock'),
#  (186, 'AKO.B', 'Embotelladora Andina S.A. Common Stock'),
#  (187, 'AKR', 'Acadia Realty Trust Common Stock'),
#  (188, 'AL', 'Air Lease Corporation Class A Common Stock'),
#  (189, 'AL-A', 'Air Lease Corporation 6.150% Fixed-to-Floating Rate Non-Cumulative Perpetual Preferred Stock, Series A'),
#  (190, 'ALB', 'Albemarle Corporation Common Stock'),
#  (191, 'ALC', 'Alcon Inc. Ordinary Shares'),
#  (192, 'ALCC', 'AltC Acquisition Corp. Class A Common Stock'),
#  (193, 'ALE', 'Allete, Inc.'),
#  (194, 'ALEX', 'Alexander & Baldwin, Inc. Common Stock REIT Holding Company'),
#  (195, 'ALFA', 'AlphaClone Alternative Alpha ETF'),
#  (196, 'ALG', 'Alamo Group, Inc. Common Stock'),
#  (197, 'ALIN-A', 'Altera Infrastructure L.P. 7.25% Series A '),
#  (198, 'ALIN-B', 'Altera Infrastructure L.P. 8.50% Series B '),
#  (199, 'ALIN-E', 'Altera Infrastructure L.P. 8.875% Series E '),
#  (200, 'ALIT', 'Alight, Inc. Class A Common Stock'),
#  (201, 'ALIT+', 'Alight, Inc. Warrants, each exercisable for one share of Class A Common Stock at an exercise price of $11.50 per share'),
#  (202, 'ALK', 'Alaska Air Group, Inc. Common Stock'),
#  (203, 'ALL', 'Allstate Corporation (The) Common Stock'),
#  (204, 'ALL-B', 'Allstate Corporation (The) 5.100% Fixed-to-Floating Rate Subordinated Debentures due 2053'),
#  (205, 'ALL-G', 'Allstate Corporation (The) Depositary Shares each representing a 1/1,000th interest in a share of Fixed Rate Noncumulative Perpetual Preferred Stock, Series G'),
#  (206, 'ALL-H', 'Allstate Corporation (The) Depositary Shares each representing a 1/1,000th interest in a share of Fixed Rate Noncumulative Perpetual Preferred Stock, Series H'),
#  (207, 'ALL-I', 'Allstate Corporation (The) Depositary Shares each representing a 1/1,000th interest in a share of Fixed Rate Noncumulative Perpetual Preferred Stock, Series I'),
#  (208, 'ALLE', 'Allegion plc Ordinary Shares'),
#  (209, 'ALLY', 'Ally Financial Inc. Common Stock'),
#  (210, 'ALLY-A', 'GMAC Capital Trust I Fixed Rate Floating Rate Trust Preferred Securities, Series 2'),
#  (211, 'ALP-Q', 'Alabama Power Company 5.00% Class A Preferred Stock, Cumulative, Par Value $1 Per Share (Stated Capital $25 Per Share)'),
#  (212, 'ALSN', 'Allison Transmission Holdings, Inc. Common Stock'),
#  (213, 'ALTG', 'Alta Equipment Group Inc. Class A Common Stock'),
#  (214, 'ALTG-A', 'Alta Equipment Group Inc. Depositary Shares (each representing 1/1000th in a share of 10% Series A Cumulative Perpetual Preferred Stock)'),
#  (215, 'ALTL', 'Pacer Lunt Large Cap Alternator ETF'),
#  (216, 'ALTS', 'ProShares Morningstar Alternatives Solution ETF'),
#  (217, 'ALV', 'Autoliv, Inc. Common Stock'),
#  (218, 'ALX', "Alexander's, Inc. Common Stock"),
#  (219, 'AM', 'Antero Midstream Corporation Common Stock'),
#  (220, 'AMAM', 'Ambrx Biopharma Inc. American Depositary Shares (each representing seven Ordinary Shares)'),
#  (221, 'AMBC', 'Ambac Financial Group, Inc. Common Stock'),
#  (222, 'AMBC+', 'Ambac Financial Group, Inc. Warrants'),
#  (223, 'AMBO', 'Ambow Education Holding Ltd. American Depository Shares, each representing two Class A ordinary shares'),
#  (224, 'AMBP', 'Ardagh Metal Packaging S.A. Ordinary Shares'),
#  (225, 'AMBP+', 'Ardagh Metal Packaging S.A. Warrants, each exercisable for one Share at an exercise price of $11.50 per share'),
#  (226, 'AMC', 'AMC Entertainment Holdings, Inc. Class A Common Stock'),
#  (227, 'AMCR', 'Amcor plc Ordinary Shares'),
#  (228, 'AME', 'AMETEK, Inc.'),
#  (229, 'AMER', 'Emles Made in America ETF'),
#  (230, 'AMG', 'Affiliated Managers Group, Inc. Common Stock'),
#  (231, 'AMH', 'American Homes 4 Rent Common Shares of Beneficial Interest'),
#  (232, 'AMH-F', 'American Homes 4 Rent 5.875% Series F Cumulative Redeemable Perpetual Preferred Shares'),
#  (233, 'AMH-G', 'American Homes 4 Rent Series G cumulative redeemable perpetual preferred shares of beneficial interest'),
#  (234, 'AMH-H', 'American Homes 4 Rent Series H cumulative redeemable perpetual Preferred Shares of Beneficial Interest'),
#  (235, 'AMJ', 'JPMorgan Chase Capital XVI JP Morgan Alerian MLP ETN'),
#  (236, 'AMK', 'AssetMark Financial Holdings, Inc. Common Stock'),
#  (237, 'AMLP', 'Alerian MLP ETF'),
#  (238, 'AMN', 'AMN Healthcare Services Inc AMN Healthcare Services Inc'),
#  (239, 'AMNA', 'ETRACS Alerian Midstream Energy Index ETN'),
#  (240, 'AMND', 'UBS AG ETRACS Alerian Midstream Energy High Dividend Index ETN'),
#  (241, 'AMOM', 'QRAFT AI-Enhanced U.S. Large Cap Momentum ETF'),
#  (242, 'AMOV', 'America Movil, S.A.B. de C.V. Class A American Depositary Shares'),
#  (243, 'AMP', 'Ameriprise Financial, Inc. Common Stock'),
#  (244, 'AMPE', 'Ampio Pharmaceuticals, Inc.'),
#  (245, 'AMPI', 'Advanced Merger Partners, Inc. Class A Common Stock'),
#  (246, 'AMPI=', 'Advanced Merger Partners, Inc. Units, each consisting of one share of Class A common stock and one-sixth of one redeemable warrant'),
#  (247, 'AMPI+', 'Advanced Merger Partners, Inc. Warrants, each whole warrant exercisable for one share of Class A Common Stock at an exercise price of $11.50'),
#  (248, 'AMPY', 'Amplify Energy Corp. Common Stock'),
#  (249, 'AMR', 'Alpha Metallurgical Resources, Inc. Common Stock'),
#  (250, 'AMRC', 'Ameresco, Inc. Class A Common Stock'),
#  (251, 'AMRX', 'Amneal Pharmaceuticals, Inc. Class A Common Stock'),
#  (252, 'AMS', 'American Shared Hospital Services Common Stock'),
#  (253, 'AMT', 'American Tower Corporation (REIT) Common Stock'),
#  (254, 'AMTR', 'ETRACS Alerian Midstream Energy Total Return Index ETN'),
#  (255, 'AMUB', 'ETRACS Alerian MLP Index ETN Series B due July 18, 2042'),
#  (256, 'AMWL', 'American Well Corporation Class A Common Stock'),
#  (257, 'AMX', 'America Movil, S.A.B. de C.V. American Depository Receipt Series L'),
#  (258, 'AMZA', 'InfraCap MLP ETF'),
#  (259, 'AN', 'AutoNation, Inc. Common Stock'),
#  (260, 'ANAC', 'Arctos NorthStar Acquisition Corp. Class A Ordinary Shares'),
#  (261, 'ANAC=', 'Arctos NorthStar Acquisition Corp. Units, each consisting of one Class A ordinary share, and one-fourth of one redeemable warrant'),
#  (262, 'ANAC+', 'Arctos NorthStar Acquisition Corp. Warrants, each whole warrant exercisable for one Class A ordinary share at an exercise price of $11.50'),
#  (263, 'ANET', 'Arista Networks, Inc. Common Stock'),
#  (264, 'ANEW', 'ProShares MSCI Transformational Changes ETF'),
#  (265, 'ANF', 'Abercrombie & Fitch Company Common Stock'),
#  (266, 'ANTM', 'Anthem, Inc. Common Stock'),
#  (267, 'ANVS', 'Annovis Bio, Inc. Common Stock'),
#  (268, 'AOA', 'iShares Core Aggressive Allocation ETF'),
#  (269, 'AOD', 'Aberdeen Total Dynamic Dividend Fund Common Stock'),
#  (270, 'AOK', 'iShares Core Conservative Allocation ETF'),
#  (271, 'AOM', 'iShares Core Moderate Allocation ETF'),
#  (272, 'AOMR', 'Angel Oak Mortgage, Inc. Common Stock'),
#  (273, 'AON', 'Aon plc Class A Ordinary Shares (Ireland)'),
#  (274, 'AOR', 'iShares Core Growth Allocation ETF'),
#  (275, 'AOS', 'A.O. Smith Corporation Common Stock'),
#  (276, 'AP', 'Ampco-Pittsburgh Corporation Common Stock'),
#  (277, 'AP+', 'Ampco-Pittsburgh Corporation Series A Warrants to purchase Shares of common stock'),
#  (278, 'APAM', 'Artisan Partners Asset Management Inc. Class A Common Stock'),
#  (279, 'APD', 'Air Products and Chemicals, Inc. Common Stock'),
#  (280, 'APG', 'APi Group Corporation Common Stock'),
#  (281, 'APGB', 'Apollo Strategic Growth Capital II Class A Ordinary Shares'),
#  (282, 'APGB=', 'Apollo Strategic Growth Capital II Units, each consisting of one Class A Ordinary Share and one-fifth Warrant'),
#  (283, 'APGB+', 'Apollo Strategic Growth Capital II Warrants, each exercisable for one Class A Ordinary Share at an exercise price of $11.50 per share'),
#  (284, 'APH', 'Amphenol Corporation Common Stock'),
#  (285, 'APLE', 'Apple Hospitality REIT, Inc. Common Shares'),
#  (286, 'APO', 'Apollo Global Management, Inc. Class A Common Stock'),
#  (287, 'APO-A', 'Apollo Global Management, Inc. 6.375% Series A Preferred Shares'),
#  (288, 'APO-B', 'Apollo Global Management, Inc 6.375% Series B Preferred Shares'),
#  (289, 'APRN', 'Blue Apron Holdings, Inc. Class A Common Stock'),
#  (290, 'APRZ', 'Trust TrueShares Structured Outcome (April) ETF'),
#  (291, 'APSG', 'Apollo Strategic Growth Capital Class A Ordinary Shares'),
#  (292, 'APSG=', 'Apollo Strategic Growth Capital Units, each consisting of one Class A Ordinary Share and one-third Warrant'),
#  (293, 'APSG+', 'Apollo Strategic Growth Capital Warrants, each exercisable for one Class A Ordinary Share at an exercise price of $11.50 per share'),
#  (294, 'APT', 'Alpha Pro Tech, Ltd. Common Stock'),
#  (295, 'APTS', 'Preferred Apartment Communities, Inc. Common Stock'),
#  (296, 'APTV', 'Aptiv PLC Ordinary Shares'),
#  (297, 'APTV-A', 'Aptiv PLC 5.50% Series A Mandatory Convertible Preferred Shares'),
#  (298, 'AQN', 'Algonquin Power & Utilities Corp. Common Shares'),
#  (299, 'AQNA', 'Algonquin Power & Utilities Corp. 6.875% Fixed-to-Floating Rate Subordinated Notes Series 2018-A due October 17, 2078'),
#  (300, 'AQNB', 'Algonquin Power & Utilities Corp. 6.20% Fixed-to-Floating Subordinated Notes Series 2019-A due July 1, 2079'),
#  (301, 'AQNU', 'Algonquin Power & Utilities Corp. Corporate Units'),
#  (302, 'AQUA', 'Evoqua Water Technologies Corp. Common Stock'),
#  (303, 'AR', 'Antero Resources Corporation Common Stock'),
#  (304, 'ARB', 'AltShares Merger Arbitrage ETF'),
#  (305, 'ARC', 'ARC Document Solutions, Inc. Common Stock'),
#  (306, 'ARCH', 'Arch Resources, Inc. Class A Common Stock'),
#  (307, 'ARCM', 'Arrow Reserve Capital Management ETF'),
#  (308, 'ARCO', 'Arcos Dorados Holdings Inc. Class A Shares'),
#  (309, 'ARD', 'Ardagh Group S.A. Common Shares'),
#  (310, 'ARDC', 'Ares Dynamic Credit Allocation Fund, Inc. Common Shares'),
#  (311, 'ARE', 'Alexandria Real Estate Equities, Inc. Common Stock'),
#  (312, 'ARES', 'Ares Management Corporation Class A Common Stock'),
#  (313, 'ARGD', 'Argo Group International Holdings, Ltd. 6.5% Senior Notes Due 2042'),
#  (314, 'ARGO', 'Argo Group International Holdings, Ltd.'),
#  (315, 'ARGO-A', 'Argo Group International Holdings, Ltd. Depositary Shares, Each Representing a 1/1,000th Interest in a 7.00% Resettable Fixed Rate Preference Share, Series A'),
#  (316, 'ARGT', 'Global X MSCI Argentina ETF'),
#  (317, 'ARI', 'Apollo Commercial Real Estate Finance, Inc'),
#  (318, 'ARKF', 'ARK Fintech Innovation ETF'),
#  (319, 'ARKG', 'ARK Genomic Revolution ETF'),
#  (320, 'ARKK', 'ARK Innovation ETF'),
#  (321, 'ARKQ', 'ARK Autonomous Technology & Robotics ETF'),
#  (322, 'ARKW', 'ARK Next Generation Internet ETF'),
#  (323, 'ARKX', 'ARK Space Exploration & Innovation ETF'),
#  (324, 'ARL', 'American Realty Investors, Inc. Common Stock'),
#  (325, 'ARLO', 'Arlo Technologies, Inc. Common Stock'),
#  (326, 'ARMK', 'Aramark Common Stock'),
#  (327, 'ARMP', 'Armata Pharmaceuticals, Inc. Common Stock'),
#  (328, 'ARMR', 'Exchange Listed Funds Trust Armor US Equity Index ETF'),
#  (329, 'ARNC', 'Arconic Corporation Common Stock '),
#  (330, 'AROC', 'Archrock, Inc. Common Stock'),
#  (331, 'ARR', 'ARMOUR Residential REIT, Inc.'),
#  (332, 'ARR-C', 'ARMOUR Residential REIT, Inc. 7% Series C Cumulative Redeemable Preferred Stock (liquidation preference $25.00 per share)'),
#  (333, 'ARW', 'Arrow Electronics, Inc. Common Stock'),
#  (334, 'ASA', 'ASA  Gold and Precious Metals Limited'),
#  (335, 'ASAI', 'Sendas Distribuidora S.A. ADS'),
#  (336, 'ASAN', 'Asana, Inc. Class A Common Stock'),
#  (337, 'ASAQ', 'Atlantic Street Acquisition Corp Class A Common Stock'),
#  (338, 'ASAQ=', 'Atlantic Street Acquisition Corp Units, each consisting of one share of Class A common stock and one-half of one Warrant'),
#  (339, 'ASAQ+', 'Atlantic Street Acquisition Corp Warrants, each whole warrant exercisable for one share of Class A common stock at an exercise price of $11.50 per share'),
#  (340, 'ASB', 'Associated Banc-Corp Common Stock'),
#  (341, 'ASB-D', 'Associated Banc-Corp Depositary Shares, each representing a 1/40th interest in a share of Associated Banc-Corp 5.375% Non-Cumulative Perpetual Preferred Stock, Series D'),
#  (342, 'ASB-E', 'Associated Banc-Corp Depositary Shares, each representing a 1/40th interest in a share of 5.875% Non-Cumulative Perpetual Preferred Stock, Series E'),
#  (343, 'ASB-F', 'Associated Banc-Corp Depositary Shares, each representing a 1/40th interest in a share of Associated Banc-Corp 5.625% Non-Cumulative Perpetual Preferred Stock, Series F'),
#  (344, 'ASC', 'Ardmore Shipping Corporation Common Stock'),
#  (345, 'ASEA', 'Global X FTSE Southeast Asia ETF'),
#  (346, 'ASG', 'Liberty All-Star Growth Fund, Inc.'),
#  (347, 'ASGI', 'Aberdeen Standard Global Infrastructure Income Fund Common Shares of Beneficial Interest'),
#  (348, 'ASGN', 'ASGN Incorporated Common Stock'),
#  (349, 'ASH', 'Ashland Global Holdings Inc. Common Stock'),
#  (350, 'ASHR', 'Xtrackers Harvest CSI 300 China A-Shares ETF'),
#  (351, 'ASHS', 'Xtrackers Harvest CSI 500 China A-Shares Small Cap ETF'),
#  (352, 'ASHX', 'Xtrackers MSCI China A Inclusion Equity ETF'),
#  (353, 'ASIX', 'AdvanSix Inc. Common Stock '),
#  (354, 'ASM', 'Avino Silver & Gold Mines Ltd. Common Shares (Canada)'),
#  (355, 'ASPN', 'Aspen Aerogels, Inc. Common Stock'),
#  (356, 'ASPY', 'ASYMmetric ETFs Trust ASYMshares ASYMmetric 500 ETF'),
#  (357, 'ASR', 'Grupo Aeroportuario del Sureste, S.A. de C.V. Common Stock'),
#  (358, 'ASX', 'ASE Technology Holding Co., Ltd. American Depositary Shares (each representing Two Common Shares) '),
#  (359, 'ASXC', 'Asensus Surgical, Inc. Common Stock'),
#  (360, 'ASZ', 'Austerlitz Acquisition Corporation II Class A Ordinary Shares'),
#  (361, 'ASZ=', 'Austerlitz Acquisition Corporation II Units, each consisting of one Class A ordinary share and one-fourth of one redeemable warrant'),
#  (362, 'ASZ+', 'Austerlitz Acquisition Corporation II Warrants, each whole Warrant exercisable for one Class A Ordinary Share at an exercise price of $11.50 per share'),
#  (363, 'ATA', 'Americas Technology Acquisition Corp. Ordinary Shares'),
#  (364, 'ATA=', 'Americas Technology Acquisition Corp. Units, each consisting of one Ordinary Share and one half of Redeemable Warrant'),
#  (365, 'ATA+', 'Americas Technology Acquisition Corp. Redeemable Warrants, each whole warrant exercisable for one Ordinary Share at an exercise price of $11.50'),
#  (366, 'ATAQ', 'Altimar Acquisition Corp. III Class A Ordinary Shares'),
#  (367, 'ATAQ=', 'Altimar Acquisition Corp. III Units, each consisting of one Class A Ordinary Share and one-fourth of one redeemable warrant'),
#  (368, 'ATAQ+', 'Altimar Acquisition Corp. III Warrants, each whole warrant exercisable for one Class A Ordinary Share at an exercise price of $11.50 per share'),
#  (369, 'ATC', 'Atotech Limited Common Shares'),
#  (370, 'ATCO', 'Atlas Corp. Common Shares'),
#  (371, 'ATCO-D', 'Atlas Corp. 7.95% Series D'),
#  (372, 'ATCO-H', 'Atlas Corp. 7.875% Series H'),
#  (373, 'ATCO-I', 'Atlas Corp. Series I Fixed-to-Floating '),
#  (374, 'ATEN', 'A10 Networks, Inc. Common Stock'),
#  (375, 'ATEST', 'Tick Pilot Test Control Common Stock'),
#  (376, 'ATEST.A', 'Tick Pilot Test Group 1 Common Stock'),
#  (377, 'ATEST.B', 'Tick pilot Test 2 Common Stock'),
#  (378, 'ATEST.C', 'Tick Pilot Test 3 Common Stock'),
#  (379, 'ATFV', 'Alger 35 ETF'),
#  (380, 'ATGE', 'Adtalem Global Education Inc. Common Stock'),
#  (381, 'ATH', 'Athene Holding Ltd. Class A Common Shares'),
#  (382, 'ATH-A', 'Athene Holding Ltd. Depositary Shares, Each Representing a 1/1,000th Interest in a 6.35% Fixed-to-Floating Rate Perpetual Non-Cumulative Preference Share, Series A'),
#  (383, 'ATH-B', 'Athene Holding Ltd. Depositary Shares, Each Representing a 1/1,000th Interest in a 5.625% Fixed Rate Perpetual Non- Cumulative Preference Share, Series B, par value $1.00 per share'),
#  (384, 'ATH-C', 'Athene Holding Ltd. Depositary Shares, each representing a 1/1,000th Interest in a Share of 6.375% Fixed-Rate Reset Perpetual Non-Cumulative Preference Shares, Series C'),
#  (385, 'ATH-D', 'Athene Holding Ltd. Depositary Shares, Each Representing a 1/1,000th Interest in a 4.875% Fixed-Rate Perpetual Non-Cumulative Preference Share, Series D'),
#  (386, 'ATHM', 'Autohome Inc. American Depositary Shares, each representing four class A ordinary shares.'),
#  (387, 'ATHN', 'Athena Technology Acquisition Corp. Class A Common Stock'),
#  (388, 'ATHN=', 'Athena Technology Acquisition Corp. Units, each consisting of one share of Class A Common Stock and one-third of one Redeemable Warrant'),
#  (389, 'ATHN+', 'Athena Technology Acquisition Corp. Redeemable Warrants, each whole warrant exercisable for one share of Class A Common Stock at an exercise price of $11.50'),
#  (390, 'ATI', 'Allegheny Technologies Incorporated Common Stock'),
#  (391, 'ATIP', 'ATI Physical Therapy, Inc. Class A Common Stock'),
#  (392, 'ATIP+', 'ATI Physical Therapy, Inc. Warrants'),
#  (393, 'ATKR', 'Atkore Inc. Common Stock'),
#  (394, 'ATMP', 'iPath Select MLP ETN'),
#  (395, 'ATMR', 'Altimar Acquisition Corp. II Class A Ordinary Shares'),
#  (396, 'ATMR=', 'Altimar Acquisition Corp. II Units, each consisting of one Class A ordinary share and one-fourth of one redeemable warrant'),
#  (397, 'ATMR+', 'Altimar Acquisition Corp. II Warrants, each whole warrant exercisable for one Class A Ordinary Share at an exercise price of $11.50 per share'),
#  (398, 'ATNM', 'Actinium Pharmaceuticals, Inc. (Delaware) Common Stock'),
#  (399, 'ATO', 'Atmos Energy Corporation Common Stock'),
#  (400, 'ATR', 'AptarGroup, Inc. Common Stock'),
#  (401, 'ATTO', 'Atento S.A. Ordinary Shares'),
#  (402, 'ATUS', 'Altice USA, Inc. Class A Common Stock'),
#  (403, 'AU', 'AngloGold Ashanti Limited Common Stock'),
#  (404, 'AUD', 'Audacy Common Stock'),
#  (405, 'AUGZ', 'TrueShares Structured Outcome (August) ETF'),
#  (406, 'AUMN', 'Golden Minerals Company Common Stock'),
#  (407, 'AUS', 'Austerlitz Acquisition Corporation I Class A Ordinary Shares'),
#  (408, 'AUS=', 'Austerlitz Acquisition Corporation I Units, each consisting of one Class A ordinary share and one-fourth of one redeemable warrant'),
#  (409, 'AUS+', 'Austerlitz Acquisition Corporation I Warrants, each whole Warrant exercisable for one Class A Ordinary Share at an exercise price of $11.50 per share'),
#  (410, 'AUSF', 'Global X Funds Global X Adaptive U.S. Factor ETF'),
#  (411, 'AUY', 'Yamana Gold Inc. Ordinary Shares (Canada)'),
#  (412, 'AVA', 'Avista Corporation Common Stock'),
#  (413, 'AVAL', 'Grupo Aval Acciones y Valores S.A. ADR (Each representing 20 preferred shares)'),
#  (414, 'AVAN', 'Avanti Acquisition Corp. Class A Ordinary Shares'),
#  (415, 'AVAN=', 'Avanti Acquisition Corp. Units, each consisting of one Class A ordinary share, and redeemable warrant'),
#  (416, 'AVAN+', 'Avanti Acquisition Corp. Redeemable Warrants, each whole warrant exercisable for one Class A ordinary share at an exercise price of $11.50'),
#  (417, 'AVB', 'AvalonBay Communities, Inc. Common Stock'),
#  (418, 'AVD', 'American Vanguard Corporation Common Stock ($0.10 Par Value)'),
#  (419, 'AVDE', 'Avantis International Equity ETF'),
#  (420, 'AVDG', 'AVDR US LargeCap ESG ETF'),
#  (421, 'AVDR', 'AVDR US LargeCap Leading ETF'),
#  (422, 'AVDV', 'Avantis International Small Cap Value ETF'),
#  (423, 'AVEM', 'Avantis Emerging Markets Equity ETF'),
#  (424, 'AVIG', 'Avantis Core Fixed Income ETF'),
#  (425, 'AVK', 'Advent Convertible and Income Fund'),
#  (426, 'AVLR', 'Avalara, Inc. Common Stock'),
#  (427, 'AVMU', 'Avantis Core Municipal Fixed Income ETF'),
#  (428, 'AVNS', 'Avanos Medical, Inc. Common Stock'),
#  (429, 'AVNT', 'Avient Corporation Common Stock'),
#  (430, 'AVSF', 'Avantis Short-Term Fixed Income ETF'),
#  (431, 'AVTR', 'Avantor, Inc. Common Stock'),
#  (432, 'AVTR-A', 'Avantor, Inc. Series A Mandatory Convertible Preferred Stock'),
#  (433, 'AVUS', 'Avantis U.S. Equity ETF'),
#  (434, 'AVUV', 'Avantis U.S. Small Cap Value ETF'),
#  (435, 'AVY', 'Avery Dennison Corporation Common Stock'),
#  (436, 'AVYA', 'Avaya Holdings Corp. Common Stock'),
#  (437, 'AWAY', 'ETFMG Travel Tech ETF'),
#  (438, 'AWF', 'Alliancebernstein Global High Income Fund'),
#  (439, 'AWI', 'Armstrong World Industries Inc Common Stock'),
#  (440, 'AWK', 'American Water Works Company, Inc. Common Stock'),
#  (441, 'AWP', 'Aberdeen Global Premier Properties Fund Common Shares of Beneficial Interest'),
#  (442, 'AWR', 'American States Water Company Common Stock'),
#  (443, 'AWTM', 'Aware Ultra-Short Duration Enhanced Income ETF'),
#  (444, 'AWX', 'Avalon Holdings Corporation Common Stock'),
#  (445, 'AWYX', 'ETFMG 2X Daily Travel Tech ETF'),
#  (446, 'AX', 'Axos Financial, Inc. Common Stock'),
#  (447, 'AXL', 'American Axle & Manufacturing Holdings, Inc. Common Stock'),
#  (448, 'AXP', 'American Express Company Common Stock'),
#  (449, 'AXR', 'AMREP Corporation Common Stock'),
#  (450, 'AXS', 'Axis Capital Holdings Limited Common Stock'),
#  (451, 'AXS-E', 'Axis Capital Holdings Limited Depositary Shares, each representing 1/100th interest in a share of a 5.50% Series E Preferred Shares'),
#  (452, 'AXTA', 'Axalta Coating Systems Ltd. Common Shares'),
#  (453, 'AXU', 'Alexco Resource Corp Common Shares (Canada)'),
#  (454, 'AYI', 'Acuity Brands, Inc. '),
#  (455, 'AYX', 'Alteryx, Inc. Class A Common Stock'),
#  (456, 'AZAA', 'AllianzIM U.S. Large Cap Buffer10 Apr ETF'),
#  (457, 'AZAJ', 'AllianzIM U.S. Large Cap Buffer10 Jan ETF'),
#  (458, 'AZAL', 'AllianzIM U.S. Large Cap Buffer10 Jul ETF'),
#  (459, 'AZAO', 'AllianzIM U.S. Large Cap Buffer10 Oct ETF'),
#  (460, 'AZBA', 'AllianzIM U.S. Large Cap Buffer20 Apr ETF'),
#  (461, 'AZBJ', 'AllianzIM U.S. Large Cap Buffer20 Jan ETF'),
#  (462, 'AZBL', 'AllianzIM U.S. Large Cap Buffer20 Jul ETF'),
#  (463, 'AZBO', 'AllianzIM U.S. Large Cap Buffer20 Oct ETF'),
#  (464, 'AZEK', 'The AZEK Company Inc. Class A Common Stock'),
#  (465, 'AZO', 'AutoZone, Inc. Common Stock'),
#  (466, 'AZRE', 'Azure Power Global Limited Equity Shares'),
#  (467, 'AZUL', 'Azul S.A. American Depositary Shares (each representing three preferred shares)'),
#  (468, 'AZZ', 'AZZ Inc.'),
#  (469, 'B', 'Barnes Group, Inc. Common Stock'),
#  (470, 'BA', 'Boeing Company (The) Common Stock'),
#  (471, 'BAB', 'Invesco Taxable Municipal Bond ETF'),
#  (472, 'BABA', 'Alibaba Group Holding Limited American Depositary Shares each representing eight Ordinary share'),
#  (473, 'BAC', 'Bank of America Corporation Common Stock'),
#  (474, 'BAC-B', 'Bank of America Corporation Depositary Shares, each representing a 1/1,000th interest in a share of 6.000% Non-Cumulative Preferred Stock, Series GG'),
#  (475, 'BAC-E', 'Bank of America Corporation Depositary Sh repstg 1/1000th Perp Pfd Ser E'),
#  (476, 'BAC-K', 'Bank of America Corporation Depositary Shares, each representing a 1/1,000th interest in a share of 5.875% Non- Cumulative Preferred Stock, Series HH'),
#  (477, 'BAC-L', 'Bank of America Corporation Non Cumulative Perpetual Conv Pfd Ser L'),
#  (478, 'BAC-M', 'Bank of America Corporation Depositary Shares, each representing a 1/1,000th interest in a share of 5.375% Non-Cumulative Preferred Stock, Series KK'),
#  (479, 'BAC-N', 'Bank of America Corporation Depositary shares, each representing 1/1,000th interest in a share of 5.000% Non-Cumulative Preferred Stock, Series LL'),
#  (480, 'BAC-O', 'Bank of America Corporation Depositary shares, each representing 1/1,000th interest in a share of 4.375% Non-Cumulative Preferred Stock, Series NN'),
#  (481, 'BAC-P', 'Bank of America Corporation Depositary Shares, each representing a 1/1,000th interest in a share of 4.125% Non-Cumulative Preferred Stock, Series PP'),
#  (482, 'BAH', 'Booz Allen Hamilton Holding Corporation Common Stock'),
#  (483, 'BAK', 'Braskem SA ADR'),
#  (484, 'BAL', 'iPathA Series B Bloomberg Cotton Subindex Total Return ETN'),
#  (485, 'BALT', 'Innovator Defined Wealth Shield ETF'),
#  (486, 'BALY', "Bally's Corporation Common Stock"),
#  (487, 'BAM', 'Brookfield Asset Management Inc. Common Stock'),
#  (488, 'BAMH', 'Brookfield Finance Inc. 4.625% Subordinated Notes due October 16, 2080'),
#  (489, 'BAMI', 'Brookfield Finance Inc. 4.50% Perpetual Subordinated Notes'),
#  (490, 'BAMR', 'Brookfield Asset Management Reinsurance Partners Ltd. Class A Exchangeable Limited Voting Shares'),
#  (491, 'BANC', 'Banc of California, Inc. Common Stock'),
#  (492, 'BANC-E', 'Banc of California, Inc. Depositary Shares Each Representing a 1/40th Interest in a Share of 7.000% Non-Cumulative Perpetual Preferred Stock, Series E'),
#  (493, 'BAP', 'Credicorp Ltd. Common Stock'),
#  (494, 'BAPR', 'Innovator S&P 500 Buffer ETF - April '),
#  (495, 'BAR', 'GraniteShares Gold Trust Shares of Beneficial Interest'),
#  (496, 'BARK', 'The Original BARK Company Common Stock'),
#  (497, 'BARK+', 'The Original BARK Company Warrants'),
#  (498, 'BATL', 'Battalion Oil Corporation Common Stock'),
#  (499, 'BATT', 'Amplify Lithium & Battery Technology ETF'),
#  (500, 'BAUG', 'Innovator S&P 500 Buffer ETF - August'),
#  (501, 'BAX', 'Baxter International Inc. Common Stock'),
#  (502, 'BB', 'BlackBerry Limited Common Stock'),
#  (503, 'BBAR', 'Banco BBVA Argentina S.A. ADS'),
#  (504, 'BBAX', 'JPMorgan BetaBuilders Developed Asia-ex Japan ETF '),
#  (505, 'BBC', 'Virtus LifeSci Biotech Clinical Trials ETF'),
#  (506, 'BBCA', 'JPMorgan BetaBuilders Canada ETF '),
#  (507, 'BBD', 'Banco Bradesco Sa American Depositary Shares'),
#  (508, 'BBDC', 'Barings BDC, Inc. Common Stock'),
#  (509, 'BBDO', 'Banco Bradesco Sa American Depositary Shares (each representing one Common Share)'),
#  (510, 'BBEU', 'JPMorgan BetaBuilders Europe ETF '),
#  (511, 'BBIN', 'JPMorgan BetaBuilders International Equity ETF'),
#  (512, 'BBJP', 'JPMorgan BetaBuilders Japan ETF '),
#  (513, 'BBL', 'BHP Group PlcSponsored ADR'),
#  (514, 'BBMC', 'JPMorgan BetaBuilders U.S. Mid Cap Equity ETF'),
#  (515, 'BBN', 'BlackRock Taxable Municipal Bond Trust Common Shares of Beneficial Interest'),
#  (516, 'BBP', 'Virtus LifeSci Biotech Products ETF'),
#  (517, 'BBRE', 'JPMorgan BetaBuilders MSCI U.S. REIT ETF '),
#  (518, 'BBSA', 'JPMorgan BetaBuilders 1-5 Year U.S. Aggregate Bond ETF '),
#  (519, 'BBSC', 'JPMorgan BetaBuilders U.S. Small Cap Equity ETF'),
#  (520, 'BBU', 'Brookfield Business Partners L.P. Limited Partnership Units '),
#  (521, 'BBUS', 'JPMorgan BetaBuilders U.S. Equity ETF'),
#  (522, 'BBVA', 'Banco Bilbao Vizcaya Argentaria S.A. Common Stock'),
#  (523, 'BBW', 'Build-A-Bear Workshop, Inc. Common Stock'),
#  (524, 'BBWI', 'Bath & Body Works, Inc.'),
#  (525, 'BBY', 'Best Buy Co., Inc. Common Stock'),
#  (526, 'BC', 'Brunswick Corporation Common Stock'),
#  (527, 'BC-A', 'Brunswick Corporation 6.500% Senior Notes due 2048'),
#  (528, 'BC-B', 'Brunswick Corporation 6.625% Senior Notes due 2049'),
#  (529, 'BC-C', 'Brunswick Corporation 6.375% Notes due 2049'),
#  (530, 'BCAT', 'BlackRock Capital Allocation Trust Common Shares of Beneficial Interest'),
#  (531, 'BCC', 'Boise Cascade, L.L.C. Common Stock'),
#  (532, 'BCD', 'Aberdeen Standard Bloomberg All Commodity Longer Dated Strategy K-1 Free ETF'),
#  (533, 'BCE', 'BCE, Inc. Common Stock'),
#  (534, 'BCEI', 'Bonanza Creek Energy, Inc. Common Stock'),
#  (535, 'BCH', 'Banco De Chile Banco De Chile ADS'),
#  (536, 'BCI', 'Aberdeen Standard Bloomberg All Commodity Strategy K-1 Free ETF'),
#  (537, 'BCM', 'iPath Pure Beta Broad Commodity ETN'),
#  (538, 'BCO', 'Brinks Company (The) Common Stock'),
#  (539, 'BCS', 'Barclays PLC Common Stock'),
#  (540, 'BCSF', 'Bain Capital Specialty Finance, Inc. Common Stock'),
#  (541, 'BCV', 'Bancroft Fund, Ltd.'),
#  (542, 'BCV-A', 'Bancroft Fund Limited 5.375% Series A Cumulative Preferred Shares'),
#  (543, 'BCX', 'BlackRock Resources Common Shares of Beneficial Interest'),
#  (544, 'BDC', 'Belden Inc Common Stock'),
#  (545, 'BDCX', 'ETRACS Quarterly Pay 1.5X Leveraged MVIS BDC Index ETN due June 10, 2050'),
#  (546, 'BDCZ', 'ETRACS MVIS Business Development Companies Index ETN due April 26, 2041'),
#  (547, 'BDEC', 'Innovator S&P 500 Buffer ETF - December'),
#  (548, 'BDJ', 'Blackrock Enhanced Equity Dividend Trust'),
#  (549, 'BDL', "Flanigan's Enterprises, Inc. Common Stock"),
#  (550, 'BDN', 'Brandywine Realty Trust Common Stock'),
#  (551, 'BDR', 'Blonder Tongue Laboratories, Inc. Common Stock'),
#  (552, 'BDRY', 'Breakwave Dry Bulk Shipping ETF'),
#  (553, 'BDX', 'Becton, Dickinson and Company Common Stock'),
#  (554, 'BDXB', 'Becton, Dickinson and Company Depositary Shares, each Representing a 1/20th Interest in a Share of 6.00% Mandatory Convertible Preferred Stock, Series B'),
#  (555, 'BE', 'Bloom Energy Corporation Class A Common Stock'),
#  (556, 'BECO', 'BlackRock Future Climate and Sustainable Economy ETF'),
#  (557, 'BEDU', 'Bright Scholar Education Holdings Limited American Depositary Shares, each  representing one Class A Ordinary Share'),
#  (558, 'BEDZ', 'AdvisorShares Hotel ETF'),
#  (559, 'BEKE', 'KE Holdings Inc American Depositary Shares (each representing three Class A Ordinary Shares)'),
#  (560, 'BEN', 'Franklin Resources, Inc. Common Stock'),
#  (561, 'BEP', 'Brookfield Renewable Partners L.P. '),
#  (562, 'BEP-A', 'Brookfield Renewable Partners L.P. 5.25% Class A Preferred Limited Partnership Units, Series 17'),
#  (563, 'BEPC', 'Brookfield Renewable Corporation Class A Subordinate Voting Shares '),
#  (564, 'BEPH', 'Brookfield BRP Holdings (Canada) Inc. 4.625% Perpetual Subordinated Notes'),
#  (565, 'BERY', 'Berry Global Group, Inc. Common Stock'),
#  (566, 'BEST', 'BEST Inc. American Depositary Shares, each representing one Class A Ordinary Share'),
#  (567, 'BETZ', 'Roundhill Sports Betting & iGaming ETF'),
#  (568, 'BF.A', 'Brown Forman Inc Class A Common Stock'),
#  (569, 'BF.B', 'Brown Forman Inc Class B Common Stock'),
#  (570, 'BFAM', 'Bright Horizons Family Solutions Inc. Common Stock'),
#  (571, 'BFEB', 'Innovator S&P 500 Buffer ETF - February'),
#  (572, 'BFK', 'BlackRock Municipal Income Trust'),
#  (573, 'BFLY', 'Butterfly Network, Inc. Class A Common Stock'),
#  (574, 'BFLY+', 'Butterfly Network, Inc. Warrants'),
#  (575, 'BFOR', "Barron's 400"),
#  (576, 'BFS', 'Saul Centers, Inc. Common Stock'),
#  (577, 'BFS-D', 'Saul Centers, Inc. Depositary Shares, each representing 1/100th of a share of 6.125% Series D Cumulative Redeemable Preferred Stock'),
#  (833, 'CAPL', 'CrossAmerica Partners LP Common Units representing limited partner interests'),
#  (578, 'BFS-E', 'Saul Centers, Inc. Depositary shares, each representing a 1/100th fractional interest in a share of 6.000% Series E Cumulative Redeemable Preferred Stock'),
#  (579, 'BFTR', 'BlackRock Future Innovators ETF'),
#  (580, 'BFZ', 'BlackRock California Municipal Income Trust'),
#  (581, 'BG', 'Bunge Limited Bunge Limited'),
#  (582, 'BGB', 'Blackstone Strategic Credit Fund Common Shares'),
#  (583, 'BGH', 'Barings Global Short Duration High Yield Fund Common Shares of Beneficial Interests'),
#  (584, 'BGI', 'Birks Group Inc. Common Stock'),
#  (585, 'BGIO', 'BlackRock 2022 Global Income Opportunity Trust Common Shares of Beneficial Interest'),
#  (586, 'BGLD', 'FT Cboe Vest Gold Strategy Quarterly Buffer ETF'),
#  (587, 'BGR', 'BlackRock Energy and Resources Trust'),
#  (588, 'BGS', 'B&G Foods, Inc. B&G Foods, Inc. Common Stock'),
#  (589, 'BGSF', 'BGSF, Inc. Common Stock'),
#  (590, 'BGSX', 'Build Acquisition Corp. Class A Common Stock'),
#  (591, 'BGSX=', 'Build Acquisition Corp. Units, each consisting of one share of Class A common stock and one-third of one redeemable warrant'),
#  (592, 'BGSX+', 'Build Acquisition Corp. Redeemable warrants, each whole warrant exercisable for one Class A common stock at an exercise price of $11.50'),
#  (593, 'BGT', 'BlackRock Floating Rate Income Trust'),
#  (594, 'BGX', 'Blackstone Long Short Credit Income Fund Common Shares'),
#  (595, 'BGY', 'Blackrock Enhanced International Dividend Trust'),
#  (596, 'BH', 'Biglari Holdings Inc. Class B Common Stock'),
#  (597, 'BH.A', 'Biglari Holdings Inc. Class A Common Stock'),
#  (598, 'BHB', 'Bar Harbor Bankshares, Inc. Common Stock'),
#  (599, 'BHC', 'Bausch Health Companies Inc. Common Stock'),
#  (600, 'BHE', 'Benchmark Electronics, Inc. Common Stock'),
#  (601, 'BHG', 'Bright Health Group, Inc. Common Stock'),
#  (602, 'BHK', 'Blackrock Core Bond Trust Blackrock Core Bond Trust'),
#  (603, 'BHLB', 'Berkshire Hills Bancorp, Inc. Common Stock'),
#  (604, 'BHP', 'BHP Group Limited American Depositary Shares (Each representing two Ordinary Shares)'),
#  (605, 'BHR', 'Braemar Hotels & Resorts Inc. Common Stock'),
#  (606, 'BHR-B', 'Braemar Hotels & Resorts Inc. 5.50% Series B Cumulative Convertible Preferred Stock, par value $0.01 per share'),
#  (607, 'BHR-D', 'Braemar Hotels & Resorts Inc. 8.25% Series D Cumulative Preferred Stock,  par value $0.01 per share'),
#  (608, 'BHV', 'BlackRock Virginia Municipal Bond Trust'),
#  (609, 'BHVN', 'Biohaven Pharmaceutical Holding Company Ltd. Common Shares'),
#  (610, 'BIBL', 'Inspire 100 ETF'),
#  (611, 'BIF', 'Boulder Growth & Income Fund, Inc.'),
#  (612, 'BIG', 'Big Lots, Inc. Common Stock'),
#  (613, 'BIGY', 'Defiance Next Gen Big Data ETF'),
#  (614, 'BIGZ', 'BlackRock Innovation and Growth Trust Common Shares of Beneficial Interest'),
#  (615, 'BIL', 'SPDR Bloomberg Barclays 1-3 Month T-Bill ETF'),
#  (616, 'BILL', 'Bill.com Holdings, Inc. Common Stock'),
#  (617, 'BILS', 'SPDR Bloomberg Barclays 3-12 Month T-Bill ETF'),
#  (618, 'BIO', 'Bio-Rad Laboratories, Inc. Class A Common Stock'),
#  (619, 'BIO.B', 'Bio-Rad Laboratories, Inc. Class B  Common Stock'),
#  (620, 'BIP', 'Brookfield Infrastructure Partners LP Limited Partnership Units'),
#  (621, 'BIP-A', 'Brookfield Infrastructure Partners LP 5.125% Class A Preferred Limited Partnership Units, Series 13'),
#  (622, 'BIP-B', 'Brookfield Infrastructure Partners LP 5.000% Class A Preferred Limited Partnership Units, Series 14'),
#  (623, 'BIPC', 'Brookfield Infrastructure Partners LP Class A Subordinate Voting Shares '),
#  (624, 'BIPH', 'Brookfield Infrastructure Corporation 5.000% Subordinated Notes due 2081'),
#  (625, 'BIT', 'BlackRock Multi-Sector Income Trust Common Shares of Beneficial Interest'),
#  (626, 'BITE', 'Bite Acquisition Corp. Common Stock'),
# ...
#  (792, 'BWX', 'SPDR Bloomberg Barclays Intl Treasury Bd'),
#  (793, 'BWXT', 'BWX Technologies, Inc. Common Stock'),
#  (794, 'BWZ', 'SPDR Bloomberg Barclays Short Term International Treasury Bond ETF'),
#  (795, 'BX', 'The Blackstone Group Inc. Common Stock'),
#  (796, 'BXC', 'Bluelinx Holdings Inc. Common Stock'),
#  (797, 'BXMT', 'Blackstone Mortgage Trust, Inc. Common Stock'),
#  (798, 'BXMX', 'Nuveen S&P 500 Buy-Write Income Fund Common Shares of Beneficial Interest'),
#  (799, 'BXP', 'Boston Properties, Inc. Common Stock'),
#  (800, 'BXS', 'BancorpSouth Bank Common Stock'),
#  (801, 'BXS-A', 'BancorpSouth Bank 5.50% Series A Non-Cumulative Perpetual Preferred Stock'),
#  (802, 'BY', 'Byline Bancorp, Inc. Common Stock'),
#  (803, 'BYD', 'Boyd Gaming Corporation Common Stock'),
#  (804, 'BYLD', 'iShares Yield Optimized Bond ETF'),
#  (805, 'BYM', 'Blackrock Municipal Income Quality Trust Common Shares of Beneficial Interest'),
#  (806, 'BZH', 'Beazer Homes USA, Inc. Common Stock'),
#  (807, 'BZQ', 'ProShares UltraShort MSCI Brazil Capped'),
#  (808, 'C', 'Citigroup, Inc. Common Stock'),
#  (809, 'C-J', 'Citigroup Inc. Dep Shs Repstg 1/1000 Pfd Ser J Fixed/Fltg'),
#  (810, 'C-K', 'Citigroup Inc. Dep Shs Repstg 1/1000th Pfd Ser K'),
#  (811, 'C-N', 'Citigroup Capital XIII 7.875% Fixed rate Floating Rate trust Preferred Securities (TruPS)'),
#  (812, 'CAAP', 'Corporacion America Airports SA Common Shares'),
#  (813, 'CABO', 'Cable One, Inc. Common Stock'),
#  (814, 'CACI', 'CACI International, Inc. Class A Common Stock'),
#  (815, 'CADE', 'Cadence Bancorporation Class A Common Stock'),
#  (816, 'CAE', 'CAE Inc. Ordinary Shares'),
#  (817, 'CAF', 'Morgan Stanley China A Share Fund Inc. Common Stock'),
#  (818, 'CAG', 'ConAgra Brands, Inc. Common Stock'),
#  (819, 'CAH', 'Cardinal Health, Inc. Common Stock'),
#  (820, 'CAI', 'CAI International, Inc. Common Stock'),
#  (821, 'CAI-A', 'CAI International, Inc. 8.50% Series A Fixed-to-Floating Rate Cumulative Redeemable Perpetual Preferred Stock'),
#  (822, 'CAI-B', 'CAI International, Inc. 8.50% Series B Fixed-to-Floating Rate Cumulative Redeemable Perpetual Preferred Stock'),
#  (823, 'CAJ', 'Canon, Inc. American Depositary Shares'),
#  (824, 'CAL', 'Caleres, Inc. Common Stock'),
#  (825, 'CALF', 'Pacer US Small Cap Cash Cows 100 ETF'),
#  (826, 'CALX', 'Calix, Inc Common Stock'),
#  (827, 'CANE', 'Teucrium Sugar Fund ETV'),
#  (828, 'CANF', 'Can-Fite Biopharma Ltd Sponsored ADR (Israel)'),
#  (829, 'CANG', 'Cango Inc. American Depositary Shares,  each representing two (2) Class A Ordinary Shares'),
#  (830, 'CANO', 'Cano Health, Inc. Class A Common Stock'),
#  (831, 'CANO+', 'Cano Health, Inc. Warrants'),
#  (832, 'CAPE', 'iPath Shiller CAPE ETN'),
#  (836, 'CAS', 'Cascade Acquisition Corp. Class A Common Stock'),
#  (837, 'CAS=', 'Cascade Acquisition Corp. Units, each consisting of one share of Class A Common Stock and one-half of one Redeemable Warrant'),
#  (838, 'CAS+', 'Cascade Acquisition Corp. Redeemable Warrants, each whole warrant exercisable for one share of Class A Common Stock at an exercise price of $11.50'),
#  (839, 'CAT', 'Caterpillar, Inc. Common Stock'),
#  (840, 'CATO', 'Cato Corporation (The) Class A Common Stock'),
#  (841, 'CB', 'Chubb Limited  Common Stock'),
#  (842, 'CBAH', 'CBRE Acquisition Holdings, Inc. Class A Common Stock'),
#  (843, 'CBAH=', 'CBRE Acquisition Holdings, Inc. SAIL securities, each consisting of one share of Class A common stock, and one-fifth of one redeemable warrant'),
#  (844, 'CBAH+', 'CBRE Acquisition Holdings, Inc. Warrants'),
#  (845, 'CBB', 'Cincinnati Bell Inc. Common Stock'),
#  (846, 'CBB-B', 'Cincinnati Bell Inc. Preferred Stock'),
#  (847, 'CBD', 'Companhia Brasileira de Distribuicao American Depsitary Shares; each representing one Common Share'),
#  (848, 'CBH', 'Virtus AllianzGI Convertible & Income 2024 Target Term Fund Common Shares of Beneficial Interest'),
#  (849, 'CBLS', 'Changebridge Capital Long/Short Equity ETF'),
#  (850, 'CBO', 'CBO (Listing Market - NYSE - Networks A/E) Common Stock'),
#  (851, 'CBOE', 'Cboe Global Markets, Inc. Common Stock'),
#  (852, 'CBON', 'VanEck Vectors ChinaAMC China Bond ETF'),
#  (853, 'CBRE', 'CBRE Group Inc Common Stock Class A'),
#  (854, 'CBSE', 'Changebridge Capital Sustainable Equity ETF'),
#  (855, 'CBT', 'Cabot Corporation Common Stock'),
#  (856, 'CBTG', 'Cabot Growth ETF'),
#  (857, 'CBU', 'Community Bank System, Inc. Common Stock'),
#  (858, 'CBX', 'CBX (Listing Market NYSE Networks AE) Common Stock'),
#  (859, 'CBZ', 'CBIZ, Inc. Common Stock'),
#  (860, 'CC', 'Chemours Company (The) Common Stock'),
#  (861, 'CCAC', 'CITIC Capital Acquisition Corp. Class A Ordinary Shares'),
#  (862, 'CCAC=', 'CITIC Capital Acquisition Corp. Units'),
#  (863, 'CCAC+', 'CITIC Capital Acquisition Corp. Warrants, each whole warrant exercisable for one Class A ordinary share at an exercise price of $11.50 per share'),
#  (864, 'CCCS', 'CCC Intelligent Solutions Holdings Inc. Common Stock'),
#  (865, 'CCCS+', 'CCC Intelligent Solutions Holdings Inc. Warrants'),
#  (866, 'CCEP', 'Coca-Cola Europacific Partners plc Ordinary Shares'),
#  (867, 'CCF', 'Chase Corporation Common Stock'),
#  (868, 'CCI', 'Crown Castle International Corp. (REIT) Common Stock'),
#  (869, 'CCJ', 'Cameco Corporation Common Stock'),
#  (870, 'CCK', 'Crown Holdings, Inc.'),
#  (871, 'CCL', 'Carnival Corporation Common Stock'),
#  (872, 'CCM', 'Concord Medical Services Holdings Limited ADS (Each represents three ordinary shares)'),
#  (873, 'CCO', 'Clear Channel Outdoor Holdings, Inc. Common Stock'),
#  (874, 'CCON', 'Direxion Connected Consumer ETF'),
#  (875, 'CCOR', 'Core Alternative ETF'),
#  (876, 'CCRV', 'iShares U.S. ETF Trust iShares Commodity Curve Carry Strategy ETF'),
#  (877, 'CCS', 'Century Communities, Inc. Common Stock'),
#  (878, 'CCU', 'Compania Cervecerias Unidas, S.A. Common Stock'),
#  (879, 'CCV', 'Churchill Capital Corp V Class A Common Stock'),
#  (880, 'CCV=', 'Churchill Capital Corp V Units, each consisting of one share of Class A common stock, and one-fourth of one redeemable warrant'),
#  (881, 'CCV+', 'Churchill Capital Corp V Warrants, each exercisable for one share of Class A common stock at an exercise price of $11.50 per share'),
#  (882, 'CCVI', 'Churchill Capital Corp VI Class A Common Stock'),
#  (883, 'CCVI=', 'Churchill Capital Corp VI Units, each consisting of one share of Class A common stock, and one-fifth of one redeemable warrant'),
#  (884, 'CCVI+', 'Churchill Capital Corp VI Warrants, each exercisable for one share of Class A common stock at an exercise price of $11.50 per share'),
#  (885, 'CCZ', 'Comcast Holdings ZONES'),
#  (886, 'CDAY', 'Ceridian HCM Holding Inc. Common Stock'),
#  (887, 'CDE', 'Coeur Mining, Inc. Common Stock'),
#  (888, 'CDOR', 'Condor Hospitality Trust, Inc. Common Stock'),
#  (889, 'CDR', 'Cedar Realty Trust, Inc. Common Stock'),
#  (890, 'CDR-B', 'Cedar Realty Trust, Inc. 7.25% Series B Cumulative Redeemable Preferred Stock'),
#  (891, 'CDR-C', 'Cedar Realty Trust, Inc. 6.50% Series C Cumulative Redeemable Preferred Stock'),
#  (892, 'CE', 'Celanese Corporation Celanese Corporation Common Stock'),
#  (893, 'CEA', 'China Eastern Airlines Corporation Ltd. Common Stock'),
#  (894, 'CEE', 'The Central and Eastern Europe Fund, Inc. (The) Common Stock'),
#  (895, 'CEF', 'Sprott Physical Gold and Silver Trust Units'),
#  (896, 'CEFD', 'ETRACS Monthly Pay 1.5X Leveraged Closed-End Fund Index ETN'),
#  (897, 'CEFS', 'Exchange Listed Funds Trust ETF'),
#  (898, 'CEI', 'Camber Energy, Inc. Common Stock'),
#  (899, 'CEIX', 'CONSOL Energy Inc. Common Stock '),
#  (900, 'CELG^', 'Bristol-Myers Squibb Company Celegne Contingent Value Rights'),
#  (901, 'CELP', 'Cypress Environmental Partners, L.P. Common Units representing limited partner interests'),
#  (902, 'CEM', 'ClearBridge MLP and Midstream Fund Inc. Common Stock'),
#  (903, 'CEMB', 'iShares J.P. Morgan EM Corporate Bond ETF'),
#  (904, 'CEN', 'Center Coast Brookfield MLP & Energy Infrastructure Fund'),
#  (905, 'CEPU', 'Central Puerto S.A. American Depositary Shares (each represents ten Common Shares)'),
#  (906, 'CEQP', 'Crestwood Equity Partners LP'),
#  (907, 'CEQP-', 'Crestwood Equity Partners LP Preferred Units representing limited partner interests'),
#  (908, 'CET', 'Central Securities Corporation Common Stock'),
#  (909, 'CEV', 'Eaton Vance California Municipal Income Trust Shares of Beneficial Interest'),
#  (910, 'CEW', 'WisdomTree Emerging Currency Strategy Fund'),
#  (911, 'CF', 'CF Industries Holdings, Inc. Common Stock'),
#  (912, 'CFCV', 'ClearBridge Focus Value ESG ETF'),
#  (913, 'CFG', 'Citizens Financial Group, Inc. Common Stock'),
#  (914, 'CFG-D', 'Citizens Financial Group, Inc. Depositary Shares, each representing a 1/40th Interest in a Share of 6.350% Fixed-to-Floating Rate Non-Cumulative Perpetual Preferred Stock, Series D'),
#  (915, 'CFG-E', 'Citizens Financial Group, Inc. Depositary Shares Each Representing 1/40th Interest in a Share of 5.000% Fixed-Rate Non-Cumulative Perpetual Preferred Stock, Series E'),
#  (916, 'CFR', 'Cullen/Frost Bankers, Inc. Common Stock'),
#  (1076, 'CODI-C', 'Compass Diversified Holdings 7.875% Series C Cumulative Preferred Shares'),
#  (917, 'CFR-B', 'Cullen/Frost Bankers, Inc. Depositary Shares, each representing a 1/40th ownership interest in a share of 4.450% non-cumulative perpetual preferred stock, Series B'),
#  (918, 'CFX', 'Colfax Corporation Common Stock'),
#  (919, 'CFXA', 'Colfax Corporation 5.75% Tangible Equity Units'),
#  (920, 'CGA', 'China Green Agriculture, Inc. Common Stock'),
#  (921, 'CGAU', 'Centerra Gold Inc. Common Shares'),
#  (922, 'CGW', 'Invesco S&P Global Water Index ETF'),
#  (923, 'CHAA', 'Catcha Investment Corp. Class A Ordinary Shares'),
#  (924, 'CHAA=', 'Catcha Investment Corp. Units, each consisting of one Class A ordinary share, and one-third of one redeemable warrant'),
#  (925, 'CHAA+', 'Catcha Investment Corp. Redeemable Warrants, each whole warrant exercisable for one Class A ordinary share at an exercise price of $11.50'),
#  (926, 'CHAD', 'Direxion Daily CSI 300 China A Shares Bear 1X Shares'),
#  (927, 'CHAQ', 'Chardan Healthcare Acquisition 2 Corp. Common Stock'),
#  (928, 'CHAQ=', 'Chardan Healthcare Acquisition 2 Corp. Units, each consisting of one share of Common Stock, and one Warrant entitling the holder to purchase one-half of a share of Common Stock'),
#  (929, 'CHAQ+', 'Chardan Healthcare Acquisition 2 Corp. Warrants, entitling the holder thereof to purchase one-half (1/2) of a share of common stock at a price of $11.50 per whole share'),
#  (930, 'CHAU', 'Direxion Daily CSI 300 China A Share Bull 2X Shares'),
#  (931, 'CHCT', 'Community Healthcare Trust Incorporated Common Stock'),
#  (932, 'CHD', 'Church & Dwight Company, Inc. Common Stock'),
#  (933, 'CHE', 'Chemed Corp'),
#  (934, 'CHFW', 'Consonance-HFW Acquisition Corp. Class A Ordinary Shares'),
#  (935, 'CHFW=', 'Consonance-HFW Acquisition Corp. Units, each consisting of one Class A Ordinary Share, and one-third of one Warrant to acquire one Class A Ordinary Share'),
#  (936, 'CHFW+', 'Consonance-HFW Acquisition Corp. Warrants, each whole warrant exercisable for one Class A Ordinary Share at an exercise price of $11.50'),
#  (937, 'CHGG', 'Chegg, Inc. Common Stock'),
#  (938, 'CHGX', 'Change Finance U.S. Large Cap Fossil Fuel Free ETF'),
#  (939, 'CHH', 'Choice Hotels International, Inc. Common Stock'),
#  (940, 'CHIC', 'Global X Funds Global X MSCI China Communication Services ETF'),
#  (941, 'CHIE', 'Global X MSCI China Energy ETF'),
#  (942, 'CHIH', 'Global X Funds Global X MSCI China Health Care ETF'),
#  (943, 'CHII', 'Global X MSCI China Industrials ETF'),
#  (944, 'CHIK', 'Global X Funds Global X MSCI China Information Technology ETF'),
#  (945, 'CHIL', 'Global X Funds Global X MSCI China Large-Cap 50 ETF'),
#  (946, 'CHIM', 'Global X MSCI China Materials ETF'),
#  (947, 'CHIQ', 'Global X MSCI China Consumer Discretionary ETF'),
#  (948, 'CHIR', 'Global X Funds Global X MSCI China Real Estate ETF'),
#  (949, 'CHIS', 'Global X Funds Global X MSCI China Consumer Staples ETF'),
#  (950, 'CHIU', 'Global X Funds Global X MSCI China Utilities ETF'),
#  (951, 'CHIX', 'Global X MSCI China Financials ETF'),
#  (952, 'CHMI', 'Cherry Hill Mortgage Investment Corporation Common Stock'),
#  (953, 'CHMI-A', 'Cherry Hill Mortgage Investment Corporation 8.20% Series A Cumulative Redeemable Preferred Stock'),
#  (954, 'CHMI-B', 'Cherry Hill Mortgage Investment Corporation 8.250% Series B Fixed-to-Floating Rate Cumulative Redeemable Preferred Stock'),
#  (955, 'CHN', 'China Fund, Inc. (The) Common Stock'),
#  (956, 'CHPT', 'ChargePoint Holdings, Inc. Common Stock'),
#  (957, 'CHRA', 'Charah Solutions, Inc. Common Stock'),
#  (958, 'CHS', "Chico's FAS, Inc. Common Stock"),
#  (959, 'CHT', 'Chunghwa Telecom Co., Ltd.'),
#  (960, 'CHWY', 'Chewy, Inc. Class A Common Stock'),
#  (961, 'CI', 'Cigna Corporation Common Stock'),
#  (962, 'CIA', 'Citizens, Inc. Class A Common Stock ($1.00 Par)'),
#  (963, 'CIB', 'BanColombia S.A. Common Stock'),
#  (964, 'CIEN', 'Ciena Corporation Common Stock'),
#  (965, 'CIF', 'MFS Intermediate High Income Fund Common Stock'),
#  (966, 'CIG', 'Comp En De Mn Cemig ADS American Depositary Shares'),
#  (967, 'CIG.C', 'Comp En De Mn Cemig ADS American Depositary Receipts'),
#  (968, 'CII', 'Blackrock Capital and Income Fund, Inc.'),
#  (969, 'CIK', 'Credit Suisse Asset Management Income Fund, Inc. Common Stock'),
#  (970, 'CIM', 'Chimera Investment Corporation Common Stock'),
#  (971, 'CIM-A', 'Chimera Investment Corporation 8.00% Series A Cumulative Redeemable Preferred Stock'),
#  (972, 'CIM-B', 'Chimera Investment Corporation 8.00% Series B Fixed-to-Floating Rate Cumulative Redeemable Preferred Stock'),
#  (973, 'CIM-C', 'Chimera Investment Corporation 7.75% Series C Fixed-to-Floating Rate  Cumulative Redeemable  Preferred Stock'),
#  (974, 'CIM-D', 'Chimera Investment Corporation 8.00% Series D Fixed-to-Floating Rate Cumulative Redeemable Preferred Stock'),
#  (975, 'CINR', 'Ciner Resources LP Common Units representing Limited Partner Interests'),
#  (976, 'CIO', 'City Office REIT, Inc. Common Stock'),
#  (977, 'CIO-A', 'City Office REIT, Inc. 6.625% Series A Cumulative Redeemable Preferred Stock'),
#  (978, 'CIR', 'CIRCOR International, Inc. Common Stock'),
#  (979, 'CIT', 'CIT Group Inc (DEL) Common Stock'),
#  (980, 'CIT-B', 'CIT Group Inc (DEL) 5.625 % Non-Cumulative Perpetual Preferred Stock, Series B'),
#  (981, 'CIX', 'CompX International Inc. Common Stock'),
#  (982, 'CIXX', 'CI Financial Corp. Common Shares'),
#  (983, 'CKX', 'CKX Lands, Inc. Common Stock'),
#  (984, 'CL', 'Colgate-Palmolive Company Common Stock'),
#  (985, 'CLAA', 'Colonnade Acquisition Corp. II Class A Ordinary Shares'),
#  (986, 'CLAA=', 'Colonnade Acquisition Corp. II Units, each consisting of one Class A ordinary share and one-fifth of one redeemable warrant'),
#  (987, 'CLAA+', 'Colonnade Acquisition Corp. II Warrants, each whole warrant exercisable for one Class A ordinary share at an exercise price of $11.50 per share'),
#  (988, 'CLAS', 'Class Acceleration Corp. Class A Common Stock'),
#  (989, 'CLAS=', 'Class Acceleration Corp. Units, each consisting of one share of Class A common stock, and one-half of one redeemable warrant'),
#  (990, 'CLAS+', 'Class Acceleration Corp. Redeemable Warrants, each whole warrant exercisable for one share of Class A Common Stock at an exercise price of $11.50'),
#  (991, 'CLB', 'Core Laboratories N.V. Common Stock'),
#  (992, 'CLBR', 'Colombier Acquisition Corp. Class A Common Stock'),
#  (993, 'CLBR=', 'Colombier Acquisition Corp. Units, each consisting of one share of Class A common stock, and one-third of one redeemable warrant'),
#  (1774, 'ESGV', 'Vanguard ESG U.S. Stock ETF'),
#  (994, 'CLBR+', 'Colombier Acquisition Corp. Warrants, each exercisable for one share of Class A common stock at an exercise price of $11.50 per share'),
#  (995, 'CLDL', 'Direxion Daily Cloud Computing Bull 2X Shares'),
#  (996, 'CLDR', 'Cloudera, Inc. Common Stock'),
#  (997, 'CLDS', 'Direxion Daily Cloud Computing Bear 2X Shares'),
#  (998, 'CLDT', 'Chatham Lodging Trust (REIT) Common Shares of Beneficial Interest'),
#  ...]

# %% [markdown]
# Looks good. Let's apply the magic to an entire cell so that we can break the lines:

# %%
# %%sql
# SELECT *
# FROM tweets.symbols;
# Out:
#  * postgresql://postgres:***@database-2.ch0m6kus6nrp.us-east-1.rds.amazonaws.com:5432/postgres
# 6121 rows affected.
# [(1, 'A', 'Agilent Technologies, Inc. Common Stock'),
#  (2, 'AA', 'Alcoa Corporation Common Stock '),
#  (3, 'AAA', 'Listed Funds Trust AAF First Priority CLO Bond ETF'),
#  (4, 'AAAU', 'Goldman Sachs Physical Gold ETF Shares'),
#  (5, 'AAC', 'Ares Acquisition Corporation Class A Ordinary Shares'),
#  (6, 'AAC=', 'Ares Acquisition Corporation Units, each consisting of one Class A ordinary share, and one-fifth of one redeemable warrant'),
#  (7, 'AAC+', 'Ares Acquisition Corporation Redeemable Warrants, each whole warrant exercisable for one Class A ordinary share at an exercise price of $11.50'),
#  (8, 'AAIC', 'Arlington Asset Investment Corp Class A (new)'),
#  (9, 'AAIC-B', 'Arlington Asset Investment Corp 7.00% '),
#  (10, 'AAIC-C', 'Arlington Asset Investment Corp 8.250% Seies C Fixed-to-Floating Rate Cumulative Redeemable Preferred Stock   '),
#  (11, 'AAIN', 'Arlington Asset Investment Corp 6.000% Senior Notes Due 2026'),
#  (12, 'AAMC', 'Altisource Asset Management Corp Com'),
#  (13, 'AAN', 'Aarons Holdings Company, Inc. Common Stock '),
#  (14, 'AAP', 'Advance Auto Parts Inc Advance Auto Parts Inc W/I'),
#  (15, 'AAQC', 'Accelerate Acquisition Corp. Class A Common Stock'),
#  (16, 'AAQC=', 'Accelerate Acquisition Corp. Units, each consisting of one Class A common stock, and one-third of one redeemable warrant'),
#  (17, 'AAQC+', 'Accelerate Acquisition Corp. Warrants, each whole warrant exercisable for one share of Class A common stock at an exercise price of $11.50'),
#  (18, 'AAT', 'American Assets Trust, Inc. Common Stock'),
#  (19, 'AAU', 'Almaden Minerals, Ltd. Common Shares'),
#  (20, 'AB', 'AllianceBernstein Holding L.P.  Units'),
#  (21, 'ABB', 'ABB Ltd Common Stock'),
#  (22, 'ABBV', 'AbbVie Inc. Common Stock'),
#  (23, 'ABC', 'AmerisourceBergen Corporation Common Stock'),
#  (24, 'ABEQ', 'Absolute Core Strategy ETF'),
#  (25, 'ABEV', 'Ambev S.A. American Depositary Shares (Each representing 1 Common Share)'),
#  (26, 'ABG', 'Asbury Automotive Group Inc Common Stock'),
#  (27, 'ABM', 'ABM Industries Incorporated Common Stock'),
#  (28, 'ABR', 'Arbor Realty Trust Common Stock'),
#  (29, 'ABR-D', 'Arbor Realty Trust 6.375% Series D Cumulative Redeemable Preferred Stock, Liquidation Preference $25.00 per Share'),
#  (30, 'ABT', 'Abbott Laboratories Common Stock'),
#  (31, 'AC', 'Associated Capital Group, Inc. Common Stock'),
#  (32, 'ACA', 'Arcosa, Inc. Common Stock '),
#  (33, 'ACC', 'American Campus Communities Inc Common Stock'),
#  (34, 'ACCO', 'Acco Brands Corporation Common Stock'),
#  (35, 'ACEL', 'Accel Entertainment, Inc. '),
#  (36, 'ACES', 'ALPS Clean Energy ETF'),
#  (37, 'ACH', 'Aluminum Corporation of China Limited American Depositary Shares'),
#  (38, 'ACI', 'Albertsons Companies, Inc. Class A Common Stock'),
#  (39, 'ACIC', 'Atlas Crest Investment Corp. Class A Common Stock'),
#  (40, 'ACIC=', 'Atlas Crest Investment Corp. Units, each consisting of one Class A common stock, and one-third of one redeemable warrant'),
#  (41, 'ACIC+', 'Atlas Crest Investment Corp. Redeemable warrants included as part of the units, each whole warrant exercisable for one Class A common stock at an exercise price of $11.50'),
#  (42, 'ACII', 'Atlas Crest Investment Corp. II Class A Common Stock'),
#  (43, 'ACII=', 'Atlas Crest Investment Corp. II Units, each consisting of one Class A common stock, $.0001 par value, and one-fourth of one redeemable warrant'),
#  (44, 'ACII+', 'Atlas Crest Investment Corp. II Redeemable Warrants, each whole warrant exercisable for one Class A common stock at an exercise price of $11.50'),
#  (45, 'ACIO', 'ETF Series Solutions Aptus Collared Income Opportunity ETF'),
#  (46, 'ACM', 'AECOM Common Stock'),
#  (47, 'ACN', 'Accenture plc Class A Ordinary Shares (Ireland)'),
#  (48, 'ACP', 'Aberdeen Income Credit Strategies Fund Common Shares'),
#  (49, 'ACP-A', 'Aberdeen Income Credit Strategies Fund 5.250% Series A Perpetual Preferred Stock'),
#  (50, 'ACR', 'ACRES Commercial Realty Corp. Common Stock'),
#  (51, 'ACR-C', 'ACRES Commercial Realty Corp. 8.625% Fixed-to-Floating Series C Cumulative Redeemable Preferred Stock '),
#  (52, 'ACR-D', 'ACRES Commercial Realty Corp. 7.875% Series D Cumulative Redeemable Preferred Stock'),
#  (53, 'ACRE', 'Ares Commercial Real Estate Corporation Common Stock'),
#  (54, 'ACRO=', 'Acropolis Infrastructure Acquisition Corp. Units, each consisting of one share of Class A Common Stock and one-third of one Warrant'),
#  (55, 'ACSG', 'Xtrackers MSCI ACWI ex USA ESG Leaders Equity ETF'),
#  (56, 'ACSI', 'American Customer Satisfaction ETF'),
#  (57, 'ACTV', 'LeaderShares Activist Leaders ETF'),
#  (58, 'ACU', 'Acme United Corporation. Common Stock'),
#  (59, 'ACV', 'Virtus AllianzGI Diversified Income & Convertible Fund Common Shares of Beneficial Interest'),
#  (60, 'ACVF', 'American Conservative Values ETF'),
#  (61, 'ACWF', 'iShares MSCI Global Multifactor ETF'),
#  (62, 'ACWV', 'iShares MSCI Global Min Vol Factor ETF'),
#  (63, 'ACY', 'AeroCentury Corp. Common Stock'),
#  (64, 'ADC', 'Agree Realty Corporation Common Stock'),
#  (65, 'ADCT', 'ADC Therapeutics SA Common Shares'),
#  (66, 'ADEX', 'Adit EdTech Acquisition Corp. Common Stock'),
#  (67, 'ADEX=', 'Adit EdTech Acquisition Corp. Units, each consisting of one share of common stock, and one-half of one redeemable warrant'),
#  (68, 'ADEX+', 'Adit EdTech Acquisition Corp. Redeemable Warrants, each whole warrant exercisable for shares of common stock at an exercise price of $11.50 per share'),
#  (69, 'ADF', 'Aldel Financial Inc. Class A Common Stock'),
#  (70, 'ADF=', 'Aldel Financial Inc. Units, each consisting of one share of Class A common stock and one-half of one redeemable warrant'),
#  (71, 'ADF+', 'Aldel Financial Inc. Warrants, each whole warrant entitles the holder thereof to purchase one share of Class A common stock at a price of $11.50 per share'),
#  (72, 'ADFI', 'Anfield Dynamic Fixed Income ETF'),
#  (73, 'ADIV', 'SmartETFs Asia Pacific Dividend Builder ETF'),
#  (74, 'ADM', 'Archer-Daniels-Midland Company Common Stock'),
#  (75, 'ADME', 'Aptus Drawdown Managed Equity ETF'),
#  (76, 'ADNT', 'Adient plc Ordinary Shares '),
#  (77, 'ADRA', 'Adara Acquisition Corp. Class A Common Stock'),
#  (78, 'ADRA=', 'Adara Acquisition Corp. Units, each consisting of one share of Class A common stock, and one-half of one redeemable warrant'),
#  (162, 'AIEQ', 'AI Powered Equity ETF'),
#  (79, 'ADRA+', 'Adara Acquisition Corp. Redeemable Warrants, each whole warrant exercisable for one share of Class A Common Stock at an exercise price of $11.50'),
#  (80, 'ADS', 'Alliance Data Systems Corporation Common Stock'),
#  (81, 'ADT', 'ADT Inc. Common Stock'),
#  (82, 'ADX', 'Adams Diversified Equity Fund Inc.'),
#  (83, 'AE', 'Adams Resources & Energy, Inc. Common Stock'),
#  (84, 'AEB', 'AEGON N.V. Perp. Cap. Secs. Floating Rate (Netherlands)'),
#  (85, 'AEE', 'Ameren Corporation Common Stock'),
#  (86, 'AEF', 'Aberdeen Emerging Markets Equity Income Fund, Inc. Common Stock'),
#  (87, 'AEFC', 'Aegon Funding Company LLC 5.10% Subordinated Notes due 2049'),
#  (88, 'AEG', 'AEGON N.V. Common Stock'),
#  (89, 'AEL', 'American Equity Investment Life Holding Company Common Stock'),
#  (90, 'AEL-A', 'American Equity Investment Life Holding Company Depositary Shares, each representing a 1/1,000th interest in a share of 5.95% Fixed-Rate Reset Non-Cumulative Preferred Stock, Series A'),
#  (91, 'AEL-B', 'American Equity Investment Life Holding Company Depositary Shares, each representing a 1/1,000th interest in a share of 6.625% Fixed-Rate Reset Non-Cumulative Preferred Stock, Series B'),
#  (92, 'AEM', 'Agnico Eagle Mines Limited Common Stock'),
#  (93, 'AEMB', 'American Century Emerging Markets Bond ETF'),
#  (94, 'AENZ', 'Aenza S.A.A. American Depositary Shares'),
#  (95, 'AEO', 'American Eagle Outfitters, Inc. Common Stock'),
#  (96, 'AER', 'AerCap Holdings N.V. Ordinary Shares'),
#  (97, 'AES', 'The AES Corporation Common Stock'),
#  (98, 'AESC', 'The AES Corporation Corporate Units'),
#  (99, 'AESR', 'Anfield U.S. Equity Sector Rotation ETF'),
#  (100, 'AEVA', 'Aeva Technologies, Inc. Common Stock'),
#  (101, 'AEVA+', 'Aeva Technologies, Inc. Redeemable Warrants, each whole warrant exercisable for shares of common stock at an exercise price of $11.50 per share'),
#  (102, 'AFB', 'AllianceBernstein National Municipal Income Fund Inc'),
#  (103, 'AFG', 'American Financial Group, Inc. Common Stock'),
#  (104, 'AFGB', 'American Financial Group, Inc. 5.875% Subordinated Debentures due 2059'),
#  (105, 'AFGC', 'American Financial Group, Inc. 5.125% Subordinated Debentures due 2059'),
#  (106, 'AFGD', 'American Financial Group, Inc. 5.625% Subordinated Debentures due 2060'),
#  (107, 'AFGE', 'American Financial Group, Inc. 4.500% Subordinated Debentures due 2060'),
#  (108, 'AFI', 'Armstrong Flooring, Inc. Common Stock'),
#  (109, 'AFIF', 'Anfield Universal Fixed Income ETF'),
#  (110, 'AFK', 'VanEck Vectors-Africa Index ETF'),
#  (111, 'AFL', 'AFLAC Incorporated Common Stock'),
#  (112, 'AFLG', 'First Trust Active Factor Large Cap ETF'),
#  (113, 'AFMC', 'First Trust Active Factor Mid Cap ETF'),
#  (114, 'AFSM', 'First Trust Active Factor Small Cap ETF'),
#  (115, 'AFT', 'Apollo Senior Floating Rate Fund Inc. Common Stock'),
#  (116, 'AFTY', 'Pacer CSOP FTSE China A50 ETF'),
#  (117, 'AG', 'First Majestic Silver Corp. Ordinary Shares (Canada)'),
#  (118, 'AGAC', 'African Gold Acquisition Corporation Class A Ordinary Shares'),
#  (119, 'AGAC=', 'African Gold Acquisition Corporation Units, each consisting of one Class A ordinary share and three-quarters of one redeemable warrant'),
#  (120, 'AGAC+', 'African Gold Acquisition Corporation Redeemable Warrants, each whole warrant exercisable for one Class A ordinary share at an exercise price of $11.50'),
#  (121, 'AGCB', 'Altimeter Growth Corp. 2 Class A Ordinary Shares'),
#  (122, 'AGCO', 'AGCO Corporation Common Stock'),
#  (123, 'AGD', 'Aberdeen Global Dynamic Dividend Fund'),
#  (124, 'AGE', 'AgeX Therapeutics, Inc. Common Stock'),
#  (125, 'AGG', 'iShares Core U.S. Aggregate Bond ETF'),
#  (126, 'AGGY', 'WisdomTree Yield Enhanced U.S. Aggregate Bond Fund'),
#  (127, 'AGI', 'Alamos Gold Inc. Class A Common Shares'),
#  (128, 'AGL', 'agilon health, inc. Common Stock'),
#  (129, 'AGM', 'Federal Agricultural Mortgage Corporation Common Stock'),
#  (130, 'AGM-C', 'Federal Agricultural Mortgage Corporation Preferred Series C Fixed to Fltg'),
#  (131, 'AGM-D', 'Federal Agricultural Mortgage Corporation 5.700% Non-Cumulative Preferred Stock, Series D'),
#  (132, 'AGM-E', 'Federal Agricultural Mortgage Corporation 5.750% Non-Cumulative Preferred Stock, Series E'),
#  (133, 'AGM-F', 'Federal Agricultural Mortgage Corporation 5.250% Non-Cumulative Preferred Stock, Series F'),
#  (134, 'AGM-G', 'Federal Agricultural Mortgage Corporation 4.875% Non-Cumulative Preferred Stock, Series G'),
#  (135, 'AGM.A', 'Federal Agricultural Mortgage Corporation Common Stock'),
#  (136, 'AGO', 'Assured Guaranty Ltd. Common Stock'),
#  (137, 'AGO-E', 'Assured Guaranty Ltd.'),
#  (138, 'AGO-F', 'Assured Guaranty Ltd.'),
#  (139, 'AGOV', 'Exchange Listed Funds Trust Gavekal Asia Pacific Government Bond ETF'),
#  (140, 'AGOX', 'Adaptive Growth Opportunities ETF'),
#  (141, 'AGQ', 'ProShares Ultra Silver'),
#  (142, 'AGR', 'Avangrid, Inc. Common Stock'),
#  (143, 'AGRO', 'Adecoagro S.A. Common Shares'),
#  (144, 'AGS', 'PlayAGS, Inc. Common Stock'),
#  (145, 'AGT', 'iShares MSCI Argentina and Global Exposure ETF'),
#  (146, 'AGTI', 'Agiliti, Inc. Common Stock'),
#  (147, 'AGX', 'Argan, Inc. Common Stock'),
#  (148, 'AGZ', 'iShares  Agency Bond ETF'),
#  (149, 'AHH', 'Armada Hoffler Properties, Inc. Common Stock'),
#  (150, 'AHH-A', 'Armada Hoffler Properties, Inc. 6.75% Series A Cumulative Redeemable Perpetual Preferred Stock'),
#  (151, 'AHL-C', 'Aspen Insurance Holdings Limited 5.95% Fixed-to-Floating Rate Perpetual Non-Cumulative Preference Shares'),
#  (152, 'AHL-D', 'Aspen Insurance Holdings Limited 5.625% Perpetual Non-Cumulative Preference Shares'),
#  (153, 'AHL-E', 'Aspen Insurance Holdings Limited Depositary Shares, each representing a 1/1000th interest in a share of 5.625% Perpetual Non-Cumulative Preference Shares'),
#  (154, 'AHT', 'Ashford Hospitality Trust Inc Common Stock'),
#  (155, 'AHT-D', 'Ashford Hospitality Trust Inc 8.45% Series D Cumulative Preferred Stock'),
#  (156, 'AHT-F', 'Ashford Hospitality Trust Inc 7.375% Series F Cumulative Preferred Stock'),
#  (157, 'AHT-G', 'Ashford Hospitality Trust Inc 7.375% Series G Cumulative Preferred Stock'),
#  (158, 'AHT-H', 'Ashford Hospitality Trust Inc 7.50% Series H Cumulative Preferred Stock'),
#  (159, 'AHT-I', 'Ashford Hospitality Trust Inc 7.50% Series I Cumulative Preferred Stock'),
#  (160, 'AI', 'C3.ai, Inc. Class A Common Stock'),
#  (161, 'AIC', 'Arlington Asset Investment Corp 6.750% Notes due 2025'),
#  (163, 'AIF', 'Apollo Tactical Income Fund Inc. Common Stock'),
#  (164, 'AIG', 'American International Group, Inc. New Common Stock'),
#  (165, 'AIG-A', 'American International Group, Inc. Depositary Shares Each Representing a 1/1,000th Interest in a Share of Series A 5.85% Non-Cumulative Perpetual Preferred Stock'),
#  (166, 'AIIQ', 'AI Powered International Equity ETF'),
#  (167, 'AIM', 'AIM ImmunoTech Inc. Common Stock'),
#  (168, 'AIN', 'Albany International Corporation Common Stock'),
#  (169, 'AINC', 'Ashford Inc. (Holding Company) Common Stock'),
#  (170, 'AIO', 'Virtus AllianzGI Artificial Intelligence & Technology Opportunities Fund Common Shares'),
#  (171, 'AIR', 'AAR Corp. Common Stock'),
#  (172, 'AIRC', 'Apartment Income REIT Corp. Common Stock'),
#  (173, 'AIRI', 'Air Industries Group Common Stock'),
#  (174, 'AIT', 'Applied Industrial Technologies, Inc. Common Stock'),
#  (175, 'AIV', 'Apartment Investment and Management Company Common Stock'),
#  (176, 'AIZ', 'Assurant, Inc. Common Stock'),
#  (177, 'AIZN', 'Assurant, Inc. 5.25% Subordinated Notes due 2061'),
#  (178, 'AJAX', 'Ajax I Class A Ordinary Shares'),
#  (179, 'AJAX=', 'Ajax I Units, each consisting of one Class A ordinary share and one-fourth of one redeemable warrant'),
#  (180, 'AJAX+', 'Ajax I Redeemable warrants, each whole warrant exercisable for one Class A ordinary share at an exercise price of $11.50'),
#  (181, 'AJG', 'Arthur J. Gallagher & Co. Common Stock'),
#  (182, 'AJRD', 'Aerojet Rocketdyne Holdings, Inc. Common Stock'),
#  (183, 'AJX', 'Great Ajax Corp. Common Stock'),
#  (184, 'AJXA', 'Great Ajax Corp. 7.25% Convertible Senior Notes due 2024'),
#  (185, 'AKO.A', 'Embotelladora Andina S.A. Common Stock'),
#  (186, 'AKO.B', 'Embotelladora Andina S.A. Common Stock'),
#  (187, 'AKR', 'Acadia Realty Trust Common Stock'),
#  (188, 'AL', 'Air Lease Corporation Class A Common Stock'),
#  (189, 'AL-A', 'Air Lease Corporation 6.150% Fixed-to-Floating Rate Non-Cumulative Perpetual Preferred Stock, Series A'),
#  (190, 'ALB', 'Albemarle Corporation Common Stock'),
#  (191, 'ALC', 'Alcon Inc. Ordinary Shares'),
#  (192, 'ALCC', 'AltC Acquisition Corp. Class A Common Stock'),
#  (193, 'ALE', 'Allete, Inc.'),
#  (194, 'ALEX', 'Alexander & Baldwin, Inc. Common Stock REIT Holding Company'),
#  (195, 'ALFA', 'AlphaClone Alternative Alpha ETF'),
#  (196, 'ALG', 'Alamo Group, Inc. Common Stock'),
#  (197, 'ALIN-A', 'Altera Infrastructure L.P. 7.25% Series A '),
#  (198, 'ALIN-B', 'Altera Infrastructure L.P. 8.50% Series B '),
#  (199, 'ALIN-E', 'Altera Infrastructure L.P. 8.875% Series E '),
#  (200, 'ALIT', 'Alight, Inc. Class A Common Stock'),
#  (201, 'ALIT+', 'Alight, Inc. Warrants, each exercisable for one share of Class A Common Stock at an exercise price of $11.50 per share'),
#  (202, 'ALK', 'Alaska Air Group, Inc. Common Stock'),
#  (203, 'ALL', 'Allstate Corporation (The) Common Stock'),
#  (204, 'ALL-B', 'Allstate Corporation (The) 5.100% Fixed-to-Floating Rate Subordinated Debentures due 2053'),
#  (205, 'ALL-G', 'Allstate Corporation (The) Depositary Shares each representing a 1/1,000th interest in a share of Fixed Rate Noncumulative Perpetual Preferred Stock, Series G'),
#  (206, 'ALL-H', 'Allstate Corporation (The) Depositary Shares each representing a 1/1,000th interest in a share of Fixed Rate Noncumulative Perpetual Preferred Stock, Series H'),
#  (207, 'ALL-I', 'Allstate Corporation (The) Depositary Shares each representing a 1/1,000th interest in a share of Fixed Rate Noncumulative Perpetual Preferred Stock, Series I'),
#  (208, 'ALLE', 'Allegion plc Ordinary Shares'),
#  (209, 'ALLY', 'Ally Financial Inc. Common Stock'),
#  (210, 'ALLY-A', 'GMAC Capital Trust I Fixed Rate Floating Rate Trust Preferred Securities, Series 2'),
#  (211, 'ALP-Q', 'Alabama Power Company 5.00% Class A Preferred Stock, Cumulative, Par Value $1 Per Share (Stated Capital $25 Per Share)'),
#  (212, 'ALSN', 'Allison Transmission Holdings, Inc. Common Stock'),
#  (213, 'ALTG', 'Alta Equipment Group Inc. Class A Common Stock'),
#  (214, 'ALTG-A', 'Alta Equipment Group Inc. Depositary Shares (each representing 1/1000th in a share of 10% Series A Cumulative Perpetual Preferred Stock)'),
#  (215, 'ALTL', 'Pacer Lunt Large Cap Alternator ETF'),
#  (216, 'ALTS', 'ProShares Morningstar Alternatives Solution ETF'),
#  (217, 'ALV', 'Autoliv, Inc. Common Stock'),
#  (218, 'ALX', "Alexander's, Inc. Common Stock"),
#  (219, 'AM', 'Antero Midstream Corporation Common Stock'),
#  (220, 'AMAM', 'Ambrx Biopharma Inc. American Depositary Shares (each representing seven Ordinary Shares)'),
#  (221, 'AMBC', 'Ambac Financial Group, Inc. Common Stock'),
#  (222, 'AMBC+', 'Ambac Financial Group, Inc. Warrants'),
#  (223, 'AMBO', 'Ambow Education Holding Ltd. American Depository Shares, each representing two Class A ordinary shares'),
#  (224, 'AMBP', 'Ardagh Metal Packaging S.A. Ordinary Shares'),
#  (225, 'AMBP+', 'Ardagh Metal Packaging S.A. Warrants, each exercisable for one Share at an exercise price of $11.50 per share'),
#  (226, 'AMC', 'AMC Entertainment Holdings, Inc. Class A Common Stock'),
#  (227, 'AMCR', 'Amcor plc Ordinary Shares'),
#  (228, 'AME', 'AMETEK, Inc.'),
#  (229, 'AMER', 'Emles Made in America ETF'),
#  (230, 'AMG', 'Affiliated Managers Group, Inc. Common Stock'),
#  (231, 'AMH', 'American Homes 4 Rent Common Shares of Beneficial Interest'),
#  (232, 'AMH-F', 'American Homes 4 Rent 5.875% Series F Cumulative Redeemable Perpetual Preferred Shares'),
#  (233, 'AMH-G', 'American Homes 4 Rent Series G cumulative redeemable perpetual preferred shares of beneficial interest'),
#  (234, 'AMH-H', 'American Homes 4 Rent Series H cumulative redeemable perpetual Preferred Shares of Beneficial Interest'),
#  (235, 'AMJ', 'JPMorgan Chase Capital XVI JP Morgan Alerian MLP ETN'),
#  (236, 'AMK', 'AssetMark Financial Holdings, Inc. Common Stock'),
#  (237, 'AMLP', 'Alerian MLP ETF'),
#  (238, 'AMN', 'AMN Healthcare Services Inc AMN Healthcare Services Inc'),
#  (239, 'AMNA', 'ETRACS Alerian Midstream Energy Index ETN'),
#  (240, 'AMND', 'UBS AG ETRACS Alerian Midstream Energy High Dividend Index ETN'),
#  (241, 'AMOM', 'QRAFT AI-Enhanced U.S. Large Cap Momentum ETF'),
#  (242, 'AMOV', 'America Movil, S.A.B. de C.V. Class A American Depositary Shares'),
#  (243, 'AMP', 'Ameriprise Financial, Inc. Common Stock'),
#  (244, 'AMPE', 'Ampio Pharmaceuticals, Inc.'),
#  (245, 'AMPI', 'Advanced Merger Partners, Inc. Class A Common Stock'),
#  (246, 'AMPI=', 'Advanced Merger Partners, Inc. Units, each consisting of one share of Class A common stock and one-sixth of one redeemable warrant'),
#  (247, 'AMPI+', 'Advanced Merger Partners, Inc. Warrants, each whole warrant exercisable for one share of Class A Common Stock at an exercise price of $11.50'),
#  (248, 'AMPY', 'Amplify Energy Corp. Common Stock'),
#  (249, 'AMR', 'Alpha Metallurgical Resources, Inc. Common Stock'),
#  (250, 'AMRC', 'Ameresco, Inc. Class A Common Stock'),
#  (251, 'AMRX', 'Amneal Pharmaceuticals, Inc. Class A Common Stock'),
#  (252, 'AMS', 'American Shared Hospital Services Common Stock'),
#  (253, 'AMT', 'American Tower Corporation (REIT) Common Stock'),
#  (254, 'AMTR', 'ETRACS Alerian Midstream Energy Total Return Index ETN'),
#  (255, 'AMUB', 'ETRACS Alerian MLP Index ETN Series B due July 18, 2042'),
#  (256, 'AMWL', 'American Well Corporation Class A Common Stock'),
#  (257, 'AMX', 'America Movil, S.A.B. de C.V. American Depository Receipt Series L'),
#  (258, 'AMZA', 'InfraCap MLP ETF'),
#  (259, 'AN', 'AutoNation, Inc. Common Stock'),
#  (260, 'ANAC', 'Arctos NorthStar Acquisition Corp. Class A Ordinary Shares'),
#  (261, 'ANAC=', 'Arctos NorthStar Acquisition Corp. Units, each consisting of one Class A ordinary share, and one-fourth of one redeemable warrant'),
#  (262, 'ANAC+', 'Arctos NorthStar Acquisition Corp. Warrants, each whole warrant exercisable for one Class A ordinary share at an exercise price of $11.50'),
#  (263, 'ANET', 'Arista Networks, Inc. Common Stock'),
#  (264, 'ANEW', 'ProShares MSCI Transformational Changes ETF'),
#  (265, 'ANF', 'Abercrombie & Fitch Company Common Stock'),
#  (266, 'ANTM', 'Anthem, Inc. Common Stock'),
#  (267, 'ANVS', 'Annovis Bio, Inc. Common Stock'),
#  (268, 'AOA', 'iShares Core Aggressive Allocation ETF'),
#  (269, 'AOD', 'Aberdeen Total Dynamic Dividend Fund Common Stock'),
#  (270, 'AOK', 'iShares Core Conservative Allocation ETF'),
#  (271, 'AOM', 'iShares Core Moderate Allocation ETF'),
#  (272, 'AOMR', 'Angel Oak Mortgage, Inc. Common Stock'),
#  (273, 'AON', 'Aon plc Class A Ordinary Shares (Ireland)'),
#  (274, 'AOR', 'iShares Core Growth Allocation ETF'),
#  (275, 'AOS', 'A.O. Smith Corporation Common Stock'),
#  (276, 'AP', 'Ampco-Pittsburgh Corporation Common Stock'),
#  (277, 'AP+', 'Ampco-Pittsburgh Corporation Series A Warrants to purchase Shares of common stock'),
#  (278, 'APAM', 'Artisan Partners Asset Management Inc. Class A Common Stock'),
#  (279, 'APD', 'Air Products and Chemicals, Inc. Common Stock'),
#  (280, 'APG', 'APi Group Corporation Common Stock'),
#  (281, 'APGB', 'Apollo Strategic Growth Capital II Class A Ordinary Shares'),
#  (282, 'APGB=', 'Apollo Strategic Growth Capital II Units, each consisting of one Class A Ordinary Share and one-fifth Warrant'),
#  (283, 'APGB+', 'Apollo Strategic Growth Capital II Warrants, each exercisable for one Class A Ordinary Share at an exercise price of $11.50 per share'),
#  (284, 'APH', 'Amphenol Corporation Common Stock'),
#  (285, 'APLE', 'Apple Hospitality REIT, Inc. Common Shares'),
#  (286, 'APO', 'Apollo Global Management, Inc. Class A Common Stock'),
#  (287, 'APO-A', 'Apollo Global Management, Inc. 6.375% Series A Preferred Shares'),
#  (288, 'APO-B', 'Apollo Global Management, Inc 6.375% Series B Preferred Shares'),
#  (289, 'APRN', 'Blue Apron Holdings, Inc. Class A Common Stock'),
#  (290, 'APRZ', 'Trust TrueShares Structured Outcome (April) ETF'),
#  (291, 'APSG', 'Apollo Strategic Growth Capital Class A Ordinary Shares'),
#  (292, 'APSG=', 'Apollo Strategic Growth Capital Units, each consisting of one Class A Ordinary Share and one-third Warrant'),
#  (293, 'APSG+', 'Apollo Strategic Growth Capital Warrants, each exercisable for one Class A Ordinary Share at an exercise price of $11.50 per share'),
#  (294, 'APT', 'Alpha Pro Tech, Ltd. Common Stock'),
#  (295, 'APTS', 'Preferred Apartment Communities, Inc. Common Stock'),
#  (296, 'APTV', 'Aptiv PLC Ordinary Shares'),
#  (297, 'APTV-A', 'Aptiv PLC 5.50% Series A Mandatory Convertible Preferred Shares'),
#  (298, 'AQN', 'Algonquin Power & Utilities Corp. Common Shares'),
#  (299, 'AQNA', 'Algonquin Power & Utilities Corp. 6.875% Fixed-to-Floating Rate Subordinated Notes Series 2018-A due October 17, 2078'),
#  (300, 'AQNB', 'Algonquin Power & Utilities Corp. 6.20% Fixed-to-Floating Subordinated Notes Series 2019-A due July 1, 2079'),
#  (301, 'AQNU', 'Algonquin Power & Utilities Corp. Corporate Units'),
#  (302, 'AQUA', 'Evoqua Water Technologies Corp. Common Stock'),
#  (303, 'AR', 'Antero Resources Corporation Common Stock'),
#  (304, 'ARB', 'AltShares Merger Arbitrage ETF'),
#  (305, 'ARC', 'ARC Document Solutions, Inc. Common Stock'),
#  (306, 'ARCH', 'Arch Resources, Inc. Class A Common Stock'),
#  (307, 'ARCM', 'Arrow Reserve Capital Management ETF'),
#  (308, 'ARCO', 'Arcos Dorados Holdings Inc. Class A Shares'),
#  (309, 'ARD', 'Ardagh Group S.A. Common Shares'),
#  (310, 'ARDC', 'Ares Dynamic Credit Allocation Fund, Inc. Common Shares'),
#  (311, 'ARE', 'Alexandria Real Estate Equities, Inc. Common Stock'),
#  (312, 'ARES', 'Ares Management Corporation Class A Common Stock'),
#  (313, 'ARGD', 'Argo Group International Holdings, Ltd. 6.5% Senior Notes Due 2042'),
#  (314, 'ARGO', 'Argo Group International Holdings, Ltd.'),
#  (315, 'ARGO-A', 'Argo Group International Holdings, Ltd. Depositary Shares, Each Representing a 1/1,000th Interest in a 7.00% Resettable Fixed Rate Preference Share, Series A'),
#  (316, 'ARGT', 'Global X MSCI Argentina ETF'),
#  (317, 'ARI', 'Apollo Commercial Real Estate Finance, Inc'),
#  (318, 'ARKF', 'ARK Fintech Innovation ETF'),
#  (319, 'ARKG', 'ARK Genomic Revolution ETF'),
#  (320, 'ARKK', 'ARK Innovation ETF'),
#  (321, 'ARKQ', 'ARK Autonomous Technology & Robotics ETF'),
#  (322, 'ARKW', 'ARK Next Generation Internet ETF'),
#  (323, 'ARKX', 'ARK Space Exploration & Innovation ETF'),
#  (324, 'ARL', 'American Realty Investors, Inc. Common Stock'),
#  (325, 'ARLO', 'Arlo Technologies, Inc. Common Stock'),
#  (326, 'ARMK', 'Aramark Common Stock'),
#  (327, 'ARMP', 'Armata Pharmaceuticals, Inc. Common Stock'),
#  (328, 'ARMR', 'Exchange Listed Funds Trust Armor US Equity Index ETF'),
#  (329, 'ARNC', 'Arconic Corporation Common Stock '),
#  (330, 'AROC', 'Archrock, Inc. Common Stock'),
#  (331, 'ARR', 'ARMOUR Residential REIT, Inc.'),
#  (332, 'ARR-C', 'ARMOUR Residential REIT, Inc. 7% Series C Cumulative Redeemable Preferred Stock (liquidation preference $25.00 per share)'),
#  (333, 'ARW', 'Arrow Electronics, Inc. Common Stock'),
#  (334, 'ASA', 'ASA  Gold and Precious Metals Limited'),
#  (335, 'ASAI', 'Sendas Distribuidora S.A. ADS'),
#  (336, 'ASAN', 'Asana, Inc. Class A Common Stock'),
#  (337, 'ASAQ', 'Atlantic Street Acquisition Corp Class A Common Stock'),
#  (338, 'ASAQ=', 'Atlantic Street Acquisition Corp Units, each consisting of one share of Class A common stock and one-half of one Warrant'),
#  (339, 'ASAQ+', 'Atlantic Street Acquisition Corp Warrants, each whole warrant exercisable for one share of Class A common stock at an exercise price of $11.50 per share'),
#  (340, 'ASB', 'Associated Banc-Corp Common Stock'),
#  (341, 'ASB-D', 'Associated Banc-Corp Depositary Shares, each representing a 1/40th interest in a share of Associated Banc-Corp 5.375% Non-Cumulative Perpetual Preferred Stock, Series D'),
#  (342, 'ASB-E', 'Associated Banc-Corp Depositary Shares, each representing a 1/40th interest in a share of 5.875% Non-Cumulative Perpetual Preferred Stock, Series E'),
#  (343, 'ASB-F', 'Associated Banc-Corp Depositary Shares, each representing a 1/40th interest in a share of Associated Banc-Corp 5.625% Non-Cumulative Perpetual Preferred Stock, Series F'),
#  (344, 'ASC', 'Ardmore Shipping Corporation Common Stock'),
#  (345, 'ASEA', 'Global X FTSE Southeast Asia ETF'),
#  (346, 'ASG', 'Liberty All-Star Growth Fund, Inc.'),
#  (347, 'ASGI', 'Aberdeen Standard Global Infrastructure Income Fund Common Shares of Beneficial Interest'),
#  (348, 'ASGN', 'ASGN Incorporated Common Stock'),
#  (349, 'ASH', 'Ashland Global Holdings Inc. Common Stock'),
#  (350, 'ASHR', 'Xtrackers Harvest CSI 300 China A-Shares ETF'),
#  (351, 'ASHS', 'Xtrackers Harvest CSI 500 China A-Shares Small Cap ETF'),
#  (352, 'ASHX', 'Xtrackers MSCI China A Inclusion Equity ETF'),
#  (353, 'ASIX', 'AdvanSix Inc. Common Stock '),
#  (354, 'ASM', 'Avino Silver & Gold Mines Ltd. Common Shares (Canada)'),
#  (355, 'ASPN', 'Aspen Aerogels, Inc. Common Stock'),
#  (356, 'ASPY', 'ASYMmetric ETFs Trust ASYMshares ASYMmetric 500 ETF'),
#  (357, 'ASR', 'Grupo Aeroportuario del Sureste, S.A. de C.V. Common Stock'),
#  (358, 'ASX', 'ASE Technology Holding Co., Ltd. American Depositary Shares (each representing Two Common Shares) '),
#  (359, 'ASXC', 'Asensus Surgical, Inc. Common Stock'),
#  (360, 'ASZ', 'Austerlitz Acquisition Corporation II Class A Ordinary Shares'),
#  (361, 'ASZ=', 'Austerlitz Acquisition Corporation II Units, each consisting of one Class A ordinary share and one-fourth of one redeemable warrant'),
#  (362, 'ASZ+', 'Austerlitz Acquisition Corporation II Warrants, each whole Warrant exercisable for one Class A Ordinary Share at an exercise price of $11.50 per share'),
#  (363, 'ATA', 'Americas Technology Acquisition Corp. Ordinary Shares'),
#  (364, 'ATA=', 'Americas Technology Acquisition Corp. Units, each consisting of one Ordinary Share and one half of Redeemable Warrant'),
#  (365, 'ATA+', 'Americas Technology Acquisition Corp. Redeemable Warrants, each whole warrant exercisable for one Ordinary Share at an exercise price of $11.50'),
#  (366, 'ATAQ', 'Altimar Acquisition Corp. III Class A Ordinary Shares'),
#  (367, 'ATAQ=', 'Altimar Acquisition Corp. III Units, each consisting of one Class A Ordinary Share and one-fourth of one redeemable warrant'),
#  (368, 'ATAQ+', 'Altimar Acquisition Corp. III Warrants, each whole warrant exercisable for one Class A Ordinary Share at an exercise price of $11.50 per share'),
#  (369, 'ATC', 'Atotech Limited Common Shares'),
#  (370, 'ATCO', 'Atlas Corp. Common Shares'),
#  (371, 'ATCO-D', 'Atlas Corp. 7.95% Series D'),
#  (372, 'ATCO-H', 'Atlas Corp. 7.875% Series H'),
#  (373, 'ATCO-I', 'Atlas Corp. Series I Fixed-to-Floating '),
#  (374, 'ATEN', 'A10 Networks, Inc. Common Stock'),
#  (375, 'ATEST', 'Tick Pilot Test Control Common Stock'),
#  (376, 'ATEST.A', 'Tick Pilot Test Group 1 Common Stock'),
#  (377, 'ATEST.B', 'Tick pilot Test 2 Common Stock'),
#  (378, 'ATEST.C', 'Tick Pilot Test 3 Common Stock'),
#  (379, 'ATFV', 'Alger 35 ETF'),
#  (380, 'ATGE', 'Adtalem Global Education Inc. Common Stock'),
#  (381, 'ATH', 'Athene Holding Ltd. Class A Common Shares'),
#  (382, 'ATH-A', 'Athene Holding Ltd. Depositary Shares, Each Representing a 1/1,000th Interest in a 6.35% Fixed-to-Floating Rate Perpetual Non-Cumulative Preference Share, Series A'),
#  (383, 'ATH-B', 'Athene Holding Ltd. Depositary Shares, Each Representing a 1/1,000th Interest in a 5.625% Fixed Rate Perpetual Non- Cumulative Preference Share, Series B, par value $1.00 per share'),
#  (384, 'ATH-C', 'Athene Holding Ltd. Depositary Shares, each representing a 1/1,000th Interest in a Share of 6.375% Fixed-Rate Reset Perpetual Non-Cumulative Preference Shares, Series C'),
#  (385, 'ATH-D', 'Athene Holding Ltd. Depositary Shares, Each Representing a 1/1,000th Interest in a 4.875% Fixed-Rate Perpetual Non-Cumulative Preference Share, Series D'),
#  (386, 'ATHM', 'Autohome Inc. American Depositary Shares, each representing four class A ordinary shares.'),
#  (387, 'ATHN', 'Athena Technology Acquisition Corp. Class A Common Stock'),
#  (388, 'ATHN=', 'Athena Technology Acquisition Corp. Units, each consisting of one share of Class A Common Stock and one-third of one Redeemable Warrant'),
#  (389, 'ATHN+', 'Athena Technology Acquisition Corp. Redeemable Warrants, each whole warrant exercisable for one share of Class A Common Stock at an exercise price of $11.50'),
#  (390, 'ATI', 'Allegheny Technologies Incorporated Common Stock'),
#  (391, 'ATIP', 'ATI Physical Therapy, Inc. Class A Common Stock'),
#  (392, 'ATIP+', 'ATI Physical Therapy, Inc. Warrants'),
#  (393, 'ATKR', 'Atkore Inc. Common Stock'),
#  (394, 'ATMP', 'iPath Select MLP ETN'),
#  (395, 'ATMR', 'Altimar Acquisition Corp. II Class A Ordinary Shares'),
#  (396, 'ATMR=', 'Altimar Acquisition Corp. II Units, each consisting of one Class A ordinary share and one-fourth of one redeemable warrant'),
#  (397, 'ATMR+', 'Altimar Acquisition Corp. II Warrants, each whole warrant exercisable for one Class A Ordinary Share at an exercise price of $11.50 per share'),
#  (398, 'ATNM', 'Actinium Pharmaceuticals, Inc. (Delaware) Common Stock'),
#  (399, 'ATO', 'Atmos Energy Corporation Common Stock'),
#  (400, 'ATR', 'AptarGroup, Inc. Common Stock'),
#  (401, 'ATTO', 'Atento S.A. Ordinary Shares'),
#  (402, 'ATUS', 'Altice USA, Inc. Class A Common Stock'),
#  (403, 'AU', 'AngloGold Ashanti Limited Common Stock'),
#  (404, 'AUD', 'Audacy Common Stock'),
#  (405, 'AUGZ', 'TrueShares Structured Outcome (August) ETF'),
#  (406, 'AUMN', 'Golden Minerals Company Common Stock'),
#  (407, 'AUS', 'Austerlitz Acquisition Corporation I Class A Ordinary Shares'),
#  (408, 'AUS=', 'Austerlitz Acquisition Corporation I Units, each consisting of one Class A ordinary share and one-fourth of one redeemable warrant'),
#  (409, 'AUS+', 'Austerlitz Acquisition Corporation I Warrants, each whole Warrant exercisable for one Class A Ordinary Share at an exercise price of $11.50 per share'),
#  (410, 'AUSF', 'Global X Funds Global X Adaptive U.S. Factor ETF'),
#  (411, 'AUY', 'Yamana Gold Inc. Ordinary Shares (Canada)'),
#  (412, 'AVA', 'Avista Corporation Common Stock'),
#  (413, 'AVAL', 'Grupo Aval Acciones y Valores S.A. ADR (Each representing 20 preferred shares)'),
#  (414, 'AVAN', 'Avanti Acquisition Corp. Class A Ordinary Shares'),
#  (415, 'AVAN=', 'Avanti Acquisition Corp. Units, each consisting of one Class A ordinary share, and redeemable warrant'),
#  (416, 'AVAN+', 'Avanti Acquisition Corp. Redeemable Warrants, each whole warrant exercisable for one Class A ordinary share at an exercise price of $11.50'),
#  (417, 'AVB', 'AvalonBay Communities, Inc. Common Stock'),
#  (418, 'AVD', 'American Vanguard Corporation Common Stock ($0.10 Par Value)'),
#  (419, 'AVDE', 'Avantis International Equity ETF'),
#  (420, 'AVDG', 'AVDR US LargeCap ESG ETF'),
#  (421, 'AVDR', 'AVDR US LargeCap Leading ETF'),
#  (422, 'AVDV', 'Avantis International Small Cap Value ETF'),
#  (423, 'AVEM', 'Avantis Emerging Markets Equity ETF'),
#  (424, 'AVIG', 'Avantis Core Fixed Income ETF'),
#  (425, 'AVK', 'Advent Convertible and Income Fund'),
#  (426, 'AVLR', 'Avalara, Inc. Common Stock'),
#  (427, 'AVMU', 'Avantis Core Municipal Fixed Income ETF'),
#  (428, 'AVNS', 'Avanos Medical, Inc. Common Stock'),
#  (429, 'AVNT', 'Avient Corporation Common Stock'),
#  (430, 'AVSF', 'Avantis Short-Term Fixed Income ETF'),
#  (431, 'AVTR', 'Avantor, Inc. Common Stock'),
#  (432, 'AVTR-A', 'Avantor, Inc. Series A Mandatory Convertible Preferred Stock'),
#  (433, 'AVUS', 'Avantis U.S. Equity ETF'),
#  (434, 'AVUV', 'Avantis U.S. Small Cap Value ETF'),
#  (435, 'AVY', 'Avery Dennison Corporation Common Stock'),
#  (436, 'AVYA', 'Avaya Holdings Corp. Common Stock'),
#  (437, 'AWAY', 'ETFMG Travel Tech ETF'),
#  (438, 'AWF', 'Alliancebernstein Global High Income Fund'),
#  (439, 'AWI', 'Armstrong World Industries Inc Common Stock'),
#  (440, 'AWK', 'American Water Works Company, Inc. Common Stock'),
#  (441, 'AWP', 'Aberdeen Global Premier Properties Fund Common Shares of Beneficial Interest'),
#  (442, 'AWR', 'American States Water Company Common Stock'),
#  (443, 'AWTM', 'Aware Ultra-Short Duration Enhanced Income ETF'),
#  (444, 'AWX', 'Avalon Holdings Corporation Common Stock'),
#  (445, 'AWYX', 'ETFMG 2X Daily Travel Tech ETF'),
#  (446, 'AX', 'Axos Financial, Inc. Common Stock'),
#  (447, 'AXL', 'American Axle & Manufacturing Holdings, Inc. Common Stock'),
#  (448, 'AXP', 'American Express Company Common Stock'),
#  (449, 'AXR', 'AMREP Corporation Common Stock'),
#  (450, 'AXS', 'Axis Capital Holdings Limited Common Stock'),
#  (451, 'AXS-E', 'Axis Capital Holdings Limited Depositary Shares, each representing 1/100th interest in a share of a 5.50% Series E Preferred Shares'),
#  (452, 'AXTA', 'Axalta Coating Systems Ltd. Common Shares'),
#  (453, 'AXU', 'Alexco Resource Corp Common Shares (Canada)'),
#  (454, 'AYI', 'Acuity Brands, Inc. '),
#  (455, 'AYX', 'Alteryx, Inc. Class A Common Stock'),
#  (456, 'AZAA', 'AllianzIM U.S. Large Cap Buffer10 Apr ETF'),
#  (457, 'AZAJ', 'AllianzIM U.S. Large Cap Buffer10 Jan ETF'),
#  (458, 'AZAL', 'AllianzIM U.S. Large Cap Buffer10 Jul ETF'),
#  (459, 'AZAO', 'AllianzIM U.S. Large Cap Buffer10 Oct ETF'),
#  (460, 'AZBA', 'AllianzIM U.S. Large Cap Buffer20 Apr ETF'),
#  (461, 'AZBJ', 'AllianzIM U.S. Large Cap Buffer20 Jan ETF'),
#  (462, 'AZBL', 'AllianzIM U.S. Large Cap Buffer20 Jul ETF'),
#  (463, 'AZBO', 'AllianzIM U.S. Large Cap Buffer20 Oct ETF'),
#  (464, 'AZEK', 'The AZEK Company Inc. Class A Common Stock'),
#  (465, 'AZO', 'AutoZone, Inc. Common Stock'),
#  (466, 'AZRE', 'Azure Power Global Limited Equity Shares'),
#  (467, 'AZUL', 'Azul S.A. American Depositary Shares (each representing three preferred shares)'),
#  (468, 'AZZ', 'AZZ Inc.'),
#  (469, 'B', 'Barnes Group, Inc. Common Stock'),
#  (470, 'BA', 'Boeing Company (The) Common Stock'),
#  (471, 'BAB', 'Invesco Taxable Municipal Bond ETF'),
#  (472, 'BABA', 'Alibaba Group Holding Limited American Depositary Shares each representing eight Ordinary share'),
#  (473, 'BAC', 'Bank of America Corporation Common Stock'),
#  (474, 'BAC-B', 'Bank of America Corporation Depositary Shares, each representing a 1/1,000th interest in a share of 6.000% Non-Cumulative Preferred Stock, Series GG'),
#  (475, 'BAC-E', 'Bank of America Corporation Depositary Sh repstg 1/1000th Perp Pfd Ser E'),
#  (476, 'BAC-K', 'Bank of America Corporation Depositary Shares, each representing a 1/1,000th interest in a share of 5.875% Non- Cumulative Preferred Stock, Series HH'),
#  (477, 'BAC-L', 'Bank of America Corporation Non Cumulative Perpetual Conv Pfd Ser L'),
#  (478, 'BAC-M', 'Bank of America Corporation Depositary Shares, each representing a 1/1,000th interest in a share of 5.375% Non-Cumulative Preferred Stock, Series KK'),
#  (479, 'BAC-N', 'Bank of America Corporation Depositary shares, each representing 1/1,000th interest in a share of 5.000% Non-Cumulative Preferred Stock, Series LL'),
#  (480, 'BAC-O', 'Bank of America Corporation Depositary shares, each representing 1/1,000th interest in a share of 4.375% Non-Cumulative Preferred Stock, Series NN'),
#  (481, 'BAC-P', 'Bank of America Corporation Depositary Shares, each representing a 1/1,000th interest in a share of 4.125% Non-Cumulative Preferred Stock, Series PP'),
#  (482, 'BAH', 'Booz Allen Hamilton Holding Corporation Common Stock'),
#  (483, 'BAK', 'Braskem SA ADR'),
#  (484, 'BAL', 'iPathA Series B Bloomberg Cotton Subindex Total Return ETN'),
#  (485, 'BALT', 'Innovator Defined Wealth Shield ETF'),
#  (486, 'BALY', "Bally's Corporation Common Stock"),
#  (487, 'BAM', 'Brookfield Asset Management Inc. Common Stock'),
#  (488, 'BAMH', 'Brookfield Finance Inc. 4.625% Subordinated Notes due October 16, 2080'),
#  (489, 'BAMI', 'Brookfield Finance Inc. 4.50% Perpetual Subordinated Notes'),
#  (490, 'BAMR', 'Brookfield Asset Management Reinsurance Partners Ltd. Class A Exchangeable Limited Voting Shares'),
#  (491, 'BANC', 'Banc of California, Inc. Common Stock'),
#  (492, 'BANC-E', 'Banc of California, Inc. Depositary Shares Each Representing a 1/40th Interest in a Share of 7.000% Non-Cumulative Perpetual Preferred Stock, Series E'),
#  (493, 'BAP', 'Credicorp Ltd. Common Stock'),
#  (494, 'BAPR', 'Innovator S&P 500 Buffer ETF - April '),
#  (495, 'BAR', 'GraniteShares Gold Trust Shares of Beneficial Interest'),
#  (496, 'BARK', 'The Original BARK Company Common Stock'),
#  (497, 'BARK+', 'The Original BARK Company Warrants'),
#  (498, 'BATL', 'Battalion Oil Corporation Common Stock'),
#  (499, 'BATT', 'Amplify Lithium & Battery Technology ETF'),
#  (500, 'BAUG', 'Innovator S&P 500 Buffer ETF - August'),
#  (501, 'BAX', 'Baxter International Inc. Common Stock'),
#  (502, 'BB', 'BlackBerry Limited Common Stock'),
#  (503, 'BBAR', 'Banco BBVA Argentina S.A. ADS'),
#  (504, 'BBAX', 'JPMorgan BetaBuilders Developed Asia-ex Japan ETF '),
#  (505, 'BBC', 'Virtus LifeSci Biotech Clinical Trials ETF'),
#  (506, 'BBCA', 'JPMorgan BetaBuilders Canada ETF '),
#  (507, 'BBD', 'Banco Bradesco Sa American Depositary Shares'),
#  (508, 'BBDC', 'Barings BDC, Inc. Common Stock'),
#  (509, 'BBDO', 'Banco Bradesco Sa American Depositary Shares (each representing one Common Share)'),
#  (510, 'BBEU', 'JPMorgan BetaBuilders Europe ETF '),
#  (511, 'BBIN', 'JPMorgan BetaBuilders International Equity ETF'),
#  (512, 'BBJP', 'JPMorgan BetaBuilders Japan ETF '),
#  (513, 'BBL', 'BHP Group PlcSponsored ADR'),
#  (514, 'BBMC', 'JPMorgan BetaBuilders U.S. Mid Cap Equity ETF'),
#  (515, 'BBN', 'BlackRock Taxable Municipal Bond Trust Common Shares of Beneficial Interest'),
#  (516, 'BBP', 'Virtus LifeSci Biotech Products ETF'),
#  (517, 'BBRE', 'JPMorgan BetaBuilders MSCI U.S. REIT ETF '),
#  (518, 'BBSA', 'JPMorgan BetaBuilders 1-5 Year U.S. Aggregate Bond ETF '),
#  (519, 'BBSC', 'JPMorgan BetaBuilders U.S. Small Cap Equity ETF'),
#  (520, 'BBU', 'Brookfield Business Partners L.P. Limited Partnership Units '),
#  (521, 'BBUS', 'JPMorgan BetaBuilders U.S. Equity ETF'),
#  (522, 'BBVA', 'Banco Bilbao Vizcaya Argentaria S.A. Common Stock'),
#  (523, 'BBW', 'Build-A-Bear Workshop, Inc. Common Stock'),
#  (524, 'BBWI', 'Bath & Body Works, Inc.'),
#  (525, 'BBY', 'Best Buy Co., Inc. Common Stock'),
#  (526, 'BC', 'Brunswick Corporation Common Stock'),
#  (527, 'BC-A', 'Brunswick Corporation 6.500% Senior Notes due 2048'),
#  (528, 'BC-B', 'Brunswick Corporation 6.625% Senior Notes due 2049'),
#  (529, 'BC-C', 'Brunswick Corporation 6.375% Notes due 2049'),
#  (530, 'BCAT', 'BlackRock Capital Allocation Trust Common Shares of Beneficial Interest'),
#  (531, 'BCC', 'Boise Cascade, L.L.C. Common Stock'),
#  (532, 'BCD', 'Aberdeen Standard Bloomberg All Commodity Longer Dated Strategy K-1 Free ETF'),
#  (533, 'BCE', 'BCE, Inc. Common Stock'),
#  (534, 'BCEI', 'Bonanza Creek Energy, Inc. Common Stock'),
#  (535, 'BCH', 'Banco De Chile Banco De Chile ADS'),
#  (536, 'BCI', 'Aberdeen Standard Bloomberg All Commodity Strategy K-1 Free ETF'),
#  (537, 'BCM', 'iPath Pure Beta Broad Commodity ETN'),
#  (538, 'BCO', 'Brinks Company (The) Common Stock'),
#  (539, 'BCS', 'Barclays PLC Common Stock'),
#  (540, 'BCSF', 'Bain Capital Specialty Finance, Inc. Common Stock'),
#  (541, 'BCV', 'Bancroft Fund, Ltd.'),
#  (542, 'BCV-A', 'Bancroft Fund Limited 5.375% Series A Cumulative Preferred Shares'),
#  (543, 'BCX', 'BlackRock Resources Common Shares of Beneficial Interest'),
#  (544, 'BDC', 'Belden Inc Common Stock'),
#  (545, 'BDCX', 'ETRACS Quarterly Pay 1.5X Leveraged MVIS BDC Index ETN due June 10, 2050'),
#  (546, 'BDCZ', 'ETRACS MVIS Business Development Companies Index ETN due April 26, 2041'),
#  (547, 'BDEC', 'Innovator S&P 500 Buffer ETF - December'),
#  (548, 'BDJ', 'Blackrock Enhanced Equity Dividend Trust'),
#  (549, 'BDL', "Flanigan's Enterprises, Inc. Common Stock"),
#  (550, 'BDN', 'Brandywine Realty Trust Common Stock'),
#  (551, 'BDR', 'Blonder Tongue Laboratories, Inc. Common Stock'),
#  (552, 'BDRY', 'Breakwave Dry Bulk Shipping ETF'),
#  (553, 'BDX', 'Becton, Dickinson and Company Common Stock'),
#  (554, 'BDXB', 'Becton, Dickinson and Company Depositary Shares, each Representing a 1/20th Interest in a Share of 6.00% Mandatory Convertible Preferred Stock, Series B'),
#  (555, 'BE', 'Bloom Energy Corporation Class A Common Stock'),
#  (556, 'BECO', 'BlackRock Future Climate and Sustainable Economy ETF'),
#  (557, 'BEDU', 'Bright Scholar Education Holdings Limited American Depositary Shares, each  representing one Class A Ordinary Share'),
#  (558, 'BEDZ', 'AdvisorShares Hotel ETF'),
#  (559, 'BEKE', 'KE Holdings Inc American Depositary Shares (each representing three Class A Ordinary Shares)'),
#  (560, 'BEN', 'Franklin Resources, Inc. Common Stock'),
#  (561, 'BEP', 'Brookfield Renewable Partners L.P. '),
#  (562, 'BEP-A', 'Brookfield Renewable Partners L.P. 5.25% Class A Preferred Limited Partnership Units, Series 17'),
#  (563, 'BEPC', 'Brookfield Renewable Corporation Class A Subordinate Voting Shares '),
#  (564, 'BEPH', 'Brookfield BRP Holdings (Canada) Inc. 4.625% Perpetual Subordinated Notes'),
#  (565, 'BERY', 'Berry Global Group, Inc. Common Stock'),
#  (566, 'BEST', 'BEST Inc. American Depositary Shares, each representing one Class A Ordinary Share'),
#  (567, 'BETZ', 'Roundhill Sports Betting & iGaming ETF'),
#  (568, 'BF.A', 'Brown Forman Inc Class A Common Stock'),
#  (569, 'BF.B', 'Brown Forman Inc Class B Common Stock'),
#  (570, 'BFAM', 'Bright Horizons Family Solutions Inc. Common Stock'),
#  (571, 'BFEB', 'Innovator S&P 500 Buffer ETF - February'),
#  (572, 'BFK', 'BlackRock Municipal Income Trust'),
#  (573, 'BFLY', 'Butterfly Network, Inc. Class A Common Stock'),
#  (574, 'BFLY+', 'Butterfly Network, Inc. Warrants'),
#  (575, 'BFOR', "Barron's 400"),
#  (576, 'BFS', 'Saul Centers, Inc. Common Stock'),
#  (577, 'BFS-D', 'Saul Centers, Inc. Depositary Shares, each representing 1/100th of a share of 6.125% Series D Cumulative Redeemable Preferred Stock'),
#  (833, 'CAPL', 'CrossAmerica Partners LP Common Units representing limited partner interests'),
#  (578, 'BFS-E', 'Saul Centers, Inc. Depositary shares, each representing a 1/100th fractional interest in a share of 6.000% Series E Cumulative Redeemable Preferred Stock'),
#  (579, 'BFTR', 'BlackRock Future Innovators ETF'),
#  (580, 'BFZ', 'BlackRock California Municipal Income Trust'),
#  (581, 'BG', 'Bunge Limited Bunge Limited'),
#  (582, 'BGB', 'Blackstone Strategic Credit Fund Common Shares'),
#  (583, 'BGH', 'Barings Global Short Duration High Yield Fund Common Shares of Beneficial Interests'),
#  (584, 'BGI', 'Birks Group Inc. Common Stock'),
#  (585, 'BGIO', 'BlackRock 2022 Global Income Opportunity Trust Common Shares of Beneficial Interest'),
#  (586, 'BGLD', 'FT Cboe Vest Gold Strategy Quarterly Buffer ETF'),
#  (587, 'BGR', 'BlackRock Energy and Resources Trust'),
#  (588, 'BGS', 'B&G Foods, Inc. B&G Foods, Inc. Common Stock'),
#  (589, 'BGSF', 'BGSF, Inc. Common Stock'),
#  (590, 'BGSX', 'Build Acquisition Corp. Class A Common Stock'),
#  (591, 'BGSX=', 'Build Acquisition Corp. Units, each consisting of one share of Class A common stock and one-third of one redeemable warrant'),
#  (592, 'BGSX+', 'Build Acquisition Corp. Redeemable warrants, each whole warrant exercisable for one Class A common stock at an exercise price of $11.50'),
#  (593, 'BGT', 'BlackRock Floating Rate Income Trust'),
#  (594, 'BGX', 'Blackstone Long Short Credit Income Fund Common Shares'),
#  (595, 'BGY', 'Blackrock Enhanced International Dividend Trust'),
#  (596, 'BH', 'Biglari Holdings Inc. Class B Common Stock'),
#  (597, 'BH.A', 'Biglari Holdings Inc. Class A Common Stock'),
#  (598, 'BHB', 'Bar Harbor Bankshares, Inc. Common Stock'),
#  (599, 'BHC', 'Bausch Health Companies Inc. Common Stock'),
#  (600, 'BHE', 'Benchmark Electronics, Inc. Common Stock'),
#  (601, 'BHG', 'Bright Health Group, Inc. Common Stock'),
#  (602, 'BHK', 'Blackrock Core Bond Trust Blackrock Core Bond Trust'),
#  (603, 'BHLB', 'Berkshire Hills Bancorp, Inc. Common Stock'),
#  (604, 'BHP', 'BHP Group Limited American Depositary Shares (Each representing two Ordinary Shares)'),
#  (605, 'BHR', 'Braemar Hotels & Resorts Inc. Common Stock'),
#  (606, 'BHR-B', 'Braemar Hotels & Resorts Inc. 5.50% Series B Cumulative Convertible Preferred Stock, par value $0.01 per share'),
#  (607, 'BHR-D', 'Braemar Hotels & Resorts Inc. 8.25% Series D Cumulative Preferred Stock,  par value $0.01 per share'),
#  (608, 'BHV', 'BlackRock Virginia Municipal Bond Trust'),
#  (609, 'BHVN', 'Biohaven Pharmaceutical Holding Company Ltd. Common Shares'),
#  (610, 'BIBL', 'Inspire 100 ETF'),
#  (611, 'BIF', 'Boulder Growth & Income Fund, Inc.'),
#  (612, 'BIG', 'Big Lots, Inc. Common Stock'),
#  (613, 'BIGY', 'Defiance Next Gen Big Data ETF'),
#  (614, 'BIGZ', 'BlackRock Innovation and Growth Trust Common Shares of Beneficial Interest'),
#  (615, 'BIL', 'SPDR Bloomberg Barclays 1-3 Month T-Bill ETF'),
#  (616, 'BILL', 'Bill.com Holdings, Inc. Common Stock'),
#  (617, 'BILS', 'SPDR Bloomberg Barclays 3-12 Month T-Bill ETF'),
#  (618, 'BIO', 'Bio-Rad Laboratories, Inc. Class A Common Stock'),
#  (619, 'BIO.B', 'Bio-Rad Laboratories, Inc. Class B  Common Stock'),
#  (620, 'BIP', 'Brookfield Infrastructure Partners LP Limited Partnership Units'),
#  (621, 'BIP-A', 'Brookfield Infrastructure Partners LP 5.125% Class A Preferred Limited Partnership Units, Series 13'),
#  (622, 'BIP-B', 'Brookfield Infrastructure Partners LP 5.000% Class A Preferred Limited Partnership Units, Series 14'),
#  (623, 'BIPC', 'Brookfield Infrastructure Partners LP Class A Subordinate Voting Shares '),
#  (624, 'BIPH', 'Brookfield Infrastructure Corporation 5.000% Subordinated Notes due 2081'),
#  (625, 'BIT', 'BlackRock Multi-Sector Income Trust Common Shares of Beneficial Interest'),
#  (626, 'BITE', 'Bite Acquisition Corp. Common Stock'),
# ...
#  (792, 'BWX', 'SPDR Bloomberg Barclays Intl Treasury Bd'),
#  (793, 'BWXT', 'BWX Technologies, Inc. Common Stock'),
#  (794, 'BWZ', 'SPDR Bloomberg Barclays Short Term International Treasury Bond ETF'),
#  (795, 'BX', 'The Blackstone Group Inc. Common Stock'),
#  (796, 'BXC', 'Bluelinx Holdings Inc. Common Stock'),
#  (797, 'BXMT', 'Blackstone Mortgage Trust, Inc. Common Stock'),
#  (798, 'BXMX', 'Nuveen S&P 500 Buy-Write Income Fund Common Shares of Beneficial Interest'),
#  (799, 'BXP', 'Boston Properties, Inc. Common Stock'),
#  (800, 'BXS', 'BancorpSouth Bank Common Stock'),
#  (801, 'BXS-A', 'BancorpSouth Bank 5.50% Series A Non-Cumulative Perpetual Preferred Stock'),
#  (802, 'BY', 'Byline Bancorp, Inc. Common Stock'),
#  (803, 'BYD', 'Boyd Gaming Corporation Common Stock'),
#  (804, 'BYLD', 'iShares Yield Optimized Bond ETF'),
#  (805, 'BYM', 'Blackrock Municipal Income Quality Trust Common Shares of Beneficial Interest'),
#  (806, 'BZH', 'Beazer Homes USA, Inc. Common Stock'),
#  (807, 'BZQ', 'ProShares UltraShort MSCI Brazil Capped'),
#  (808, 'C', 'Citigroup, Inc. Common Stock'),
#  (809, 'C-J', 'Citigroup Inc. Dep Shs Repstg 1/1000 Pfd Ser J Fixed/Fltg'),
#  (810, 'C-K', 'Citigroup Inc. Dep Shs Repstg 1/1000th Pfd Ser K'),
#  (811, 'C-N', 'Citigroup Capital XIII 7.875% Fixed rate Floating Rate trust Preferred Securities (TruPS)'),
#  (812, 'CAAP', 'Corporacion America Airports SA Common Shares'),
#  (813, 'CABO', 'Cable One, Inc. Common Stock'),
#  (814, 'CACI', 'CACI International, Inc. Class A Common Stock'),
#  (815, 'CADE', 'Cadence Bancorporation Class A Common Stock'),
#  (816, 'CAE', 'CAE Inc. Ordinary Shares'),
#  (817, 'CAF', 'Morgan Stanley China A Share Fund Inc. Common Stock'),
#  (818, 'CAG', 'ConAgra Brands, Inc. Common Stock'),
#  (819, 'CAH', 'Cardinal Health, Inc. Common Stock'),
#  (820, 'CAI', 'CAI International, Inc. Common Stock'),
#  (821, 'CAI-A', 'CAI International, Inc. 8.50% Series A Fixed-to-Floating Rate Cumulative Redeemable Perpetual Preferred Stock'),
#  (822, 'CAI-B', 'CAI International, Inc. 8.50% Series B Fixed-to-Floating Rate Cumulative Redeemable Perpetual Preferred Stock'),
#  (823, 'CAJ', 'Canon, Inc. American Depositary Shares'),
#  (824, 'CAL', 'Caleres, Inc. Common Stock'),
#  (825, 'CALF', 'Pacer US Small Cap Cash Cows 100 ETF'),
#  (826, 'CALX', 'Calix, Inc Common Stock'),
#  (827, 'CANE', 'Teucrium Sugar Fund ETV'),
#  (828, 'CANF', 'Can-Fite Biopharma Ltd Sponsored ADR (Israel)'),
#  (829, 'CANG', 'Cango Inc. American Depositary Shares,  each representing two (2) Class A Ordinary Shares'),
#  (830, 'CANO', 'Cano Health, Inc. Class A Common Stock'),
#  (831, 'CANO+', 'Cano Health, Inc. Warrants'),
#  (832, 'CAPE', 'iPath Shiller CAPE ETN'),
#  (836, 'CAS', 'Cascade Acquisition Corp. Class A Common Stock'),
#  (837, 'CAS=', 'Cascade Acquisition Corp. Units, each consisting of one share of Class A Common Stock and one-half of one Redeemable Warrant'),
#  (838, 'CAS+', 'Cascade Acquisition Corp. Redeemable Warrants, each whole warrant exercisable for one share of Class A Common Stock at an exercise price of $11.50'),
#  (839, 'CAT', 'Caterpillar, Inc. Common Stock'),
#  (840, 'CATO', 'Cato Corporation (The) Class A Common Stock'),
#  (841, 'CB', 'Chubb Limited  Common Stock'),
#  (842, 'CBAH', 'CBRE Acquisition Holdings, Inc. Class A Common Stock'),
#  (843, 'CBAH=', 'CBRE Acquisition Holdings, Inc. SAIL securities, each consisting of one share of Class A common stock, and one-fifth of one redeemable warrant'),
#  (844, 'CBAH+', 'CBRE Acquisition Holdings, Inc. Warrants'),
#  (845, 'CBB', 'Cincinnati Bell Inc. Common Stock'),
#  (846, 'CBB-B', 'Cincinnati Bell Inc. Preferred Stock'),
#  (847, 'CBD', 'Companhia Brasileira de Distribuicao American Depsitary Shares; each representing one Common Share'),
#  (848, 'CBH', 'Virtus AllianzGI Convertible & Income 2024 Target Term Fund Common Shares of Beneficial Interest'),
#  (849, 'CBLS', 'Changebridge Capital Long/Short Equity ETF'),
#  (850, 'CBO', 'CBO (Listing Market - NYSE - Networks A/E) Common Stock'),
#  (851, 'CBOE', 'Cboe Global Markets, Inc. Common Stock'),
#  (852, 'CBON', 'VanEck Vectors ChinaAMC China Bond ETF'),
#  (853, 'CBRE', 'CBRE Group Inc Common Stock Class A'),
#  (854, 'CBSE', 'Changebridge Capital Sustainable Equity ETF'),
#  (855, 'CBT', 'Cabot Corporation Common Stock'),
#  (856, 'CBTG', 'Cabot Growth ETF'),
#  (857, 'CBU', 'Community Bank System, Inc. Common Stock'),
#  (858, 'CBX', 'CBX (Listing Market NYSE Networks AE) Common Stock'),
#  (859, 'CBZ', 'CBIZ, Inc. Common Stock'),
#  (860, 'CC', 'Chemours Company (The) Common Stock'),
#  (861, 'CCAC', 'CITIC Capital Acquisition Corp. Class A Ordinary Shares'),
#  (862, 'CCAC=', 'CITIC Capital Acquisition Corp. Units'),
#  (863, 'CCAC+', 'CITIC Capital Acquisition Corp. Warrants, each whole warrant exercisable for one Class A ordinary share at an exercise price of $11.50 per share'),
#  (864, 'CCCS', 'CCC Intelligent Solutions Holdings Inc. Common Stock'),
#  (865, 'CCCS+', 'CCC Intelligent Solutions Holdings Inc. Warrants'),
#  (866, 'CCEP', 'Coca-Cola Europacific Partners plc Ordinary Shares'),
#  (867, 'CCF', 'Chase Corporation Common Stock'),
#  (868, 'CCI', 'Crown Castle International Corp. (REIT) Common Stock'),
#  (869, 'CCJ', 'Cameco Corporation Common Stock'),
#  (870, 'CCK', 'Crown Holdings, Inc.'),
#  (871, 'CCL', 'Carnival Corporation Common Stock'),
#  (872, 'CCM', 'Concord Medical Services Holdings Limited ADS (Each represents three ordinary shares)'),
#  (873, 'CCO', 'Clear Channel Outdoor Holdings, Inc. Common Stock'),
#  (874, 'CCON', 'Direxion Connected Consumer ETF'),
#  (875, 'CCOR', 'Core Alternative ETF'),
#  (876, 'CCRV', 'iShares U.S. ETF Trust iShares Commodity Curve Carry Strategy ETF'),
#  (877, 'CCS', 'Century Communities, Inc. Common Stock'),
#  (878, 'CCU', 'Compania Cervecerias Unidas, S.A. Common Stock'),
#  (879, 'CCV', 'Churchill Capital Corp V Class A Common Stock'),
#  (880, 'CCV=', 'Churchill Capital Corp V Units, each consisting of one share of Class A common stock, and one-fourth of one redeemable warrant'),
#  (881, 'CCV+', 'Churchill Capital Corp V Warrants, each exercisable for one share of Class A common stock at an exercise price of $11.50 per share'),
#  (882, 'CCVI', 'Churchill Capital Corp VI Class A Common Stock'),
#  (883, 'CCVI=', 'Churchill Capital Corp VI Units, each consisting of one share of Class A common stock, and one-fifth of one redeemable warrant'),
#  (884, 'CCVI+', 'Churchill Capital Corp VI Warrants, each exercisable for one share of Class A common stock at an exercise price of $11.50 per share'),
#  (885, 'CCZ', 'Comcast Holdings ZONES'),
#  (886, 'CDAY', 'Ceridian HCM Holding Inc. Common Stock'),
#  (887, 'CDE', 'Coeur Mining, Inc. Common Stock'),
#  (888, 'CDOR', 'Condor Hospitality Trust, Inc. Common Stock'),
#  (889, 'CDR', 'Cedar Realty Trust, Inc. Common Stock'),
#  (890, 'CDR-B', 'Cedar Realty Trust, Inc. 7.25% Series B Cumulative Redeemable Preferred Stock'),
#  (891, 'CDR-C', 'Cedar Realty Trust, Inc. 6.50% Series C Cumulative Redeemable Preferred Stock'),
#  (892, 'CE', 'Celanese Corporation Celanese Corporation Common Stock'),
#  (893, 'CEA', 'China Eastern Airlines Corporation Ltd. Common Stock'),
#  (894, 'CEE', 'The Central and Eastern Europe Fund, Inc. (The) Common Stock'),
#  (895, 'CEF', 'Sprott Physical Gold and Silver Trust Units'),
#  (896, 'CEFD', 'ETRACS Monthly Pay 1.5X Leveraged Closed-End Fund Index ETN'),
#  (897, 'CEFS', 'Exchange Listed Funds Trust ETF'),
#  (898, 'CEI', 'Camber Energy, Inc. Common Stock'),
#  (899, 'CEIX', 'CONSOL Energy Inc. Common Stock '),
#  (900, 'CELG^', 'Bristol-Myers Squibb Company Celegne Contingent Value Rights'),
#  (901, 'CELP', 'Cypress Environmental Partners, L.P. Common Units representing limited partner interests'),
#  (902, 'CEM', 'ClearBridge MLP and Midstream Fund Inc. Common Stock'),
#  (903, 'CEMB', 'iShares J.P. Morgan EM Corporate Bond ETF'),
#  (904, 'CEN', 'Center Coast Brookfield MLP & Energy Infrastructure Fund'),
#  (905, 'CEPU', 'Central Puerto S.A. American Depositary Shares (each represents ten Common Shares)'),
#  (906, 'CEQP', 'Crestwood Equity Partners LP'),
#  (907, 'CEQP-', 'Crestwood Equity Partners LP Preferred Units representing limited partner interests'),
#  (908, 'CET', 'Central Securities Corporation Common Stock'),
#  (909, 'CEV', 'Eaton Vance California Municipal Income Trust Shares of Beneficial Interest'),
#  (910, 'CEW', 'WisdomTree Emerging Currency Strategy Fund'),
#  (911, 'CF', 'CF Industries Holdings, Inc. Common Stock'),
#  (912, 'CFCV', 'ClearBridge Focus Value ESG ETF'),
#  (913, 'CFG', 'Citizens Financial Group, Inc. Common Stock'),
#  (914, 'CFG-D', 'Citizens Financial Group, Inc. Depositary Shares, each representing a 1/40th Interest in a Share of 6.350% Fixed-to-Floating Rate Non-Cumulative Perpetual Preferred Stock, Series D'),
#  (915, 'CFG-E', 'Citizens Financial Group, Inc. Depositary Shares Each Representing 1/40th Interest in a Share of 5.000% Fixed-Rate Non-Cumulative Perpetual Preferred Stock, Series E'),
#  (916, 'CFR', 'Cullen/Frost Bankers, Inc. Common Stock'),
#  (1076, 'CODI-C', 'Compass Diversified Holdings 7.875% Series C Cumulative Preferred Shares'),
#  (917, 'CFR-B', 'Cullen/Frost Bankers, Inc. Depositary Shares, each representing a 1/40th ownership interest in a share of 4.450% non-cumulative perpetual preferred stock, Series B'),
#  (918, 'CFX', 'Colfax Corporation Common Stock'),
#  (919, 'CFXA', 'Colfax Corporation 5.75% Tangible Equity Units'),
#  (920, 'CGA', 'China Green Agriculture, Inc. Common Stock'),
#  (921, 'CGAU', 'Centerra Gold Inc. Common Shares'),
#  (922, 'CGW', 'Invesco S&P Global Water Index ETF'),
#  (923, 'CHAA', 'Catcha Investment Corp. Class A Ordinary Shares'),
#  (924, 'CHAA=', 'Catcha Investment Corp. Units, each consisting of one Class A ordinary share, and one-third of one redeemable warrant'),
#  (925, 'CHAA+', 'Catcha Investment Corp. Redeemable Warrants, each whole warrant exercisable for one Class A ordinary share at an exercise price of $11.50'),
#  (926, 'CHAD', 'Direxion Daily CSI 300 China A Shares Bear 1X Shares'),
#  (927, 'CHAQ', 'Chardan Healthcare Acquisition 2 Corp. Common Stock'),
#  (928, 'CHAQ=', 'Chardan Healthcare Acquisition 2 Corp. Units, each consisting of one share of Common Stock, and one Warrant entitling the holder to purchase one-half of a share of Common Stock'),
#  (929, 'CHAQ+', 'Chardan Healthcare Acquisition 2 Corp. Warrants, entitling the holder thereof to purchase one-half (1/2) of a share of common stock at a price of $11.50 per whole share'),
#  (930, 'CHAU', 'Direxion Daily CSI 300 China A Share Bull 2X Shares'),
#  (931, 'CHCT', 'Community Healthcare Trust Incorporated Common Stock'),
#  (932, 'CHD', 'Church & Dwight Company, Inc. Common Stock'),
#  (933, 'CHE', 'Chemed Corp'),
#  (934, 'CHFW', 'Consonance-HFW Acquisition Corp. Class A Ordinary Shares'),
#  (935, 'CHFW=', 'Consonance-HFW Acquisition Corp. Units, each consisting of one Class A Ordinary Share, and one-third of one Warrant to acquire one Class A Ordinary Share'),
#  (936, 'CHFW+', 'Consonance-HFW Acquisition Corp. Warrants, each whole warrant exercisable for one Class A Ordinary Share at an exercise price of $11.50'),
#  (937, 'CHGG', 'Chegg, Inc. Common Stock'),
#  (938, 'CHGX', 'Change Finance U.S. Large Cap Fossil Fuel Free ETF'),
#  (939, 'CHH', 'Choice Hotels International, Inc. Common Stock'),
#  (940, 'CHIC', 'Global X Funds Global X MSCI China Communication Services ETF'),
#  (941, 'CHIE', 'Global X MSCI China Energy ETF'),
#  (942, 'CHIH', 'Global X Funds Global X MSCI China Health Care ETF'),
#  (943, 'CHII', 'Global X MSCI China Industrials ETF'),
#  (944, 'CHIK', 'Global X Funds Global X MSCI China Information Technology ETF'),
#  (945, 'CHIL', 'Global X Funds Global X MSCI China Large-Cap 50 ETF'),
#  (946, 'CHIM', 'Global X MSCI China Materials ETF'),
#  (947, 'CHIQ', 'Global X MSCI China Consumer Discretionary ETF'),
#  (948, 'CHIR', 'Global X Funds Global X MSCI China Real Estate ETF'),
#  (949, 'CHIS', 'Global X Funds Global X MSCI China Consumer Staples ETF'),
#  (950, 'CHIU', 'Global X Funds Global X MSCI China Utilities ETF'),
#  (951, 'CHIX', 'Global X MSCI China Financials ETF'),
#  (952, 'CHMI', 'Cherry Hill Mortgage Investment Corporation Common Stock'),
#  (953, 'CHMI-A', 'Cherry Hill Mortgage Investment Corporation 8.20% Series A Cumulative Redeemable Preferred Stock'),
#  (954, 'CHMI-B', 'Cherry Hill Mortgage Investment Corporation 8.250% Series B Fixed-to-Floating Rate Cumulative Redeemable Preferred Stock'),
#  (955, 'CHN', 'China Fund, Inc. (The) Common Stock'),
#  (956, 'CHPT', 'ChargePoint Holdings, Inc. Common Stock'),
#  (957, 'CHRA', 'Charah Solutions, Inc. Common Stock'),
#  (958, 'CHS', "Chico's FAS, Inc. Common Stock"),
#  (959, 'CHT', 'Chunghwa Telecom Co., Ltd.'),
#  (960, 'CHWY', 'Chewy, Inc. Class A Common Stock'),
#  (961, 'CI', 'Cigna Corporation Common Stock'),
#  (962, 'CIA', 'Citizens, Inc. Class A Common Stock ($1.00 Par)'),
#  (963, 'CIB', 'BanColombia S.A. Common Stock'),
#  (964, 'CIEN', 'Ciena Corporation Common Stock'),
#  (965, 'CIF', 'MFS Intermediate High Income Fund Common Stock'),
#  (966, 'CIG', 'Comp En De Mn Cemig ADS American Depositary Shares'),
#  (967, 'CIG.C', 'Comp En De Mn Cemig ADS American Depositary Receipts'),
#  (968, 'CII', 'Blackrock Capital and Income Fund, Inc.'),
#  (969, 'CIK', 'Credit Suisse Asset Management Income Fund, Inc. Common Stock'),
#  (970, 'CIM', 'Chimera Investment Corporation Common Stock'),
#  (971, 'CIM-A', 'Chimera Investment Corporation 8.00% Series A Cumulative Redeemable Preferred Stock'),
#  (972, 'CIM-B', 'Chimera Investment Corporation 8.00% Series B Fixed-to-Floating Rate Cumulative Redeemable Preferred Stock'),
#  (973, 'CIM-C', 'Chimera Investment Corporation 7.75% Series C Fixed-to-Floating Rate  Cumulative Redeemable  Preferred Stock'),
#  (974, 'CIM-D', 'Chimera Investment Corporation 8.00% Series D Fixed-to-Floating Rate Cumulative Redeemable Preferred Stock'),
#  (975, 'CINR', 'Ciner Resources LP Common Units representing Limited Partner Interests'),
#  (976, 'CIO', 'City Office REIT, Inc. Common Stock'),
#  (977, 'CIO-A', 'City Office REIT, Inc. 6.625% Series A Cumulative Redeemable Preferred Stock'),
#  (978, 'CIR', 'CIRCOR International, Inc. Common Stock'),
#  (979, 'CIT', 'CIT Group Inc (DEL) Common Stock'),
#  (980, 'CIT-B', 'CIT Group Inc (DEL) 5.625 % Non-Cumulative Perpetual Preferred Stock, Series B'),
#  (981, 'CIX', 'CompX International Inc. Common Stock'),
#  (982, 'CIXX', 'CI Financial Corp. Common Shares'),
#  (983, 'CKX', 'CKX Lands, Inc. Common Stock'),
#  (984, 'CL', 'Colgate-Palmolive Company Common Stock'),
#  (985, 'CLAA', 'Colonnade Acquisition Corp. II Class A Ordinary Shares'),
#  (986, 'CLAA=', 'Colonnade Acquisition Corp. II Units, each consisting of one Class A ordinary share and one-fifth of one redeemable warrant'),
#  (987, 'CLAA+', 'Colonnade Acquisition Corp. II Warrants, each whole warrant exercisable for one Class A ordinary share at an exercise price of $11.50 per share'),
#  (988, 'CLAS', 'Class Acceleration Corp. Class A Common Stock'),
#  (989, 'CLAS=', 'Class Acceleration Corp. Units, each consisting of one share of Class A common stock, and one-half of one redeemable warrant'),
#  (990, 'CLAS+', 'Class Acceleration Corp. Redeemable Warrants, each whole warrant exercisable for one share of Class A Common Stock at an exercise price of $11.50'),
#  (991, 'CLB', 'Core Laboratories N.V. Common Stock'),
#  (992, 'CLBR', 'Colombier Acquisition Corp. Class A Common Stock'),
#  (993, 'CLBR=', 'Colombier Acquisition Corp. Units, each consisting of one share of Class A common stock, and one-third of one redeemable warrant'),
#  (1774, 'ESGV', 'Vanguard ESG U.S. Stock ETF'),
#  (994, 'CLBR+', 'Colombier Acquisition Corp. Warrants, each exercisable for one share of Class A common stock at an exercise price of $11.50 per share'),
#  (995, 'CLDL', 'Direxion Daily Cloud Computing Bull 2X Shares'),
#  (996, 'CLDR', 'Cloudera, Inc. Common Stock'),
#  (997, 'CLDS', 'Direxion Daily Cloud Computing Bear 2X Shares'),
#  (998, 'CLDT', 'Chatham Lodging Trust (REIT) Common Shares of Beneficial Interest'),
#  ...]

# %% [markdown]
# #### Assigning returned rows to Python variables

# %% [markdown]
# Single line queries:

# %%
query_output = %sql SELECT * FROM tweets.symbols;
# Out:
#  * postgresql://postgres:***@database-2.ch0m6kus6nrp.us-east-1.rds.amazonaws.com:5432/postgres
# 6121 rows affected.

# %% [markdown]
# Multi-line queries:

# %%
# %%sql query_output <<
#
# SELECT *
# FROM tweets.symbols;
# Out:
#  * postgresql://postgres:***@database-2.ch0m6kus6nrp.us-east-1.rds.amazonaws.com:5432/postgres
# 6121 rows affected.
# Returning data to local variable query_output

# %%
query_output
# Out:
# [(1, 'A', 'Agilent Technologies, Inc. Common Stock'),
#  (2, 'AA', 'Alcoa Corporation Common Stock '),
#  (3, 'AAA', 'Listed Funds Trust AAF First Priority CLO Bond ETF'),
#  (4, 'AAAU', 'Goldman Sachs Physical Gold ETF Shares'),
#  (5, 'AAC', 'Ares Acquisition Corporation Class A Ordinary Shares'),
#  (6, 'AAC=', 'Ares Acquisition Corporation Units, each consisting of one Class A ordinary share, and one-fifth of one redeemable warrant'),
#  (7, 'AAC+', 'Ares Acquisition Corporation Redeemable Warrants, each whole warrant exercisable for one Class A ordinary share at an exercise price of $11.50'),
#  (8, 'AAIC', 'Arlington Asset Investment Corp Class A (new)'),
#  (9, 'AAIC-B', 'Arlington Asset Investment Corp 7.00% '),
#  (10, 'AAIC-C', 'Arlington Asset Investment Corp 8.250% Seies C Fixed-to-Floating Rate Cumulative Redeemable Preferred Stock   '),
#  (11, 'AAIN', 'Arlington Asset Investment Corp 6.000% Senior Notes Due 2026'),
#  (12, 'AAMC', 'Altisource Asset Management Corp Com'),
#  (13, 'AAN', 'Aarons Holdings Company, Inc. Common Stock '),
#  (14, 'AAP', 'Advance Auto Parts Inc Advance Auto Parts Inc W/I'),
#  (15, 'AAQC', 'Accelerate Acquisition Corp. Class A Common Stock'),
#  (16, 'AAQC=', 'Accelerate Acquisition Corp. Units, each consisting of one Class A common stock, and one-third of one redeemable warrant'),
#  (17, 'AAQC+', 'Accelerate Acquisition Corp. Warrants, each whole warrant exercisable for one share of Class A common stock at an exercise price of $11.50'),
#  (18, 'AAT', 'American Assets Trust, Inc. Common Stock'),
#  (19, 'AAU', 'Almaden Minerals, Ltd. Common Shares'),
#  (20, 'AB', 'AllianceBernstein Holding L.P.  Units'),
#  (21, 'ABB', 'ABB Ltd Common Stock'),
#  (22, 'ABBV', 'AbbVie Inc. Common Stock'),
#  (23, 'ABC', 'AmerisourceBergen Corporation Common Stock'),
#  (24, 'ABEQ', 'Absolute Core Strategy ETF'),
#  (25, 'ABEV', 'Ambev S.A. American Depositary Shares (Each representing 1 Common Share)'),
#  (26, 'ABG', 'Asbury Automotive Group Inc Common Stock'),
#  (27, 'ABM', 'ABM Industries Incorporated Common Stock'),
#  (28, 'ABR', 'Arbor Realty Trust Common Stock'),
#  (29, 'ABR-D', 'Arbor Realty Trust 6.375% Series D Cumulative Redeemable Preferred Stock, Liquidation Preference $25.00 per Share'),
#  (30, 'ABT', 'Abbott Laboratories Common Stock'),
#  (31, 'AC', 'Associated Capital Group, Inc. Common Stock'),
#  (32, 'ACA', 'Arcosa, Inc. Common Stock '),
#  (33, 'ACC', 'American Campus Communities Inc Common Stock'),
#  (34, 'ACCO', 'Acco Brands Corporation Common Stock'),
#  (35, 'ACEL', 'Accel Entertainment, Inc. '),
#  (36, 'ACES', 'ALPS Clean Energy ETF'),
#  (37, 'ACH', 'Aluminum Corporation of China Limited American Depositary Shares'),
#  (38, 'ACI', 'Albertsons Companies, Inc. Class A Common Stock'),
#  (39, 'ACIC', 'Atlas Crest Investment Corp. Class A Common Stock'),
#  (40, 'ACIC=', 'Atlas Crest Investment Corp. Units, each consisting of one Class A common stock, and one-third of one redeemable warrant'),
#  (41, 'ACIC+', 'Atlas Crest Investment Corp. Redeemable warrants included as part of the units, each whole warrant exercisable for one Class A common stock at an exercise price of $11.50'),
#  (42, 'ACII', 'Atlas Crest Investment Corp. II Class A Common Stock'),
#  (43, 'ACII=', 'Atlas Crest Investment Corp. II Units, each consisting of one Class A common stock, $.0001 par value, and one-fourth of one redeemable warrant'),
#  (44, 'ACII+', 'Atlas Crest Investment Corp. II Redeemable Warrants, each whole warrant exercisable for one Class A common stock at an exercise price of $11.50'),
#  (45, 'ACIO', 'ETF Series Solutions Aptus Collared Income Opportunity ETF'),
#  (46, 'ACM', 'AECOM Common Stock'),
#  (47, 'ACN', 'Accenture plc Class A Ordinary Shares (Ireland)'),
#  (48, 'ACP', 'Aberdeen Income Credit Strategies Fund Common Shares'),
#  (49, 'ACP-A', 'Aberdeen Income Credit Strategies Fund 5.250% Series A Perpetual Preferred Stock'),
#  (50, 'ACR', 'ACRES Commercial Realty Corp. Common Stock'),
#  (51, 'ACR-C', 'ACRES Commercial Realty Corp. 8.625% Fixed-to-Floating Series C Cumulative Redeemable Preferred Stock '),
#  (52, 'ACR-D', 'ACRES Commercial Realty Corp. 7.875% Series D Cumulative Redeemable Preferred Stock'),
#  (53, 'ACRE', 'Ares Commercial Real Estate Corporation Common Stock'),
#  (54, 'ACRO=', 'Acropolis Infrastructure Acquisition Corp. Units, each consisting of one share of Class A Common Stock and one-third of one Warrant'),
#  (55, 'ACSG', 'Xtrackers MSCI ACWI ex USA ESG Leaders Equity ETF'),
#  (56, 'ACSI', 'American Customer Satisfaction ETF'),
#  (57, 'ACTV', 'LeaderShares Activist Leaders ETF'),
#  (58, 'ACU', 'Acme United Corporation. Common Stock'),
#  (59, 'ACV', 'Virtus AllianzGI Diversified Income & Convertible Fund Common Shares of Beneficial Interest'),
#  (60, 'ACVF', 'American Conservative Values ETF'),
#  (61, 'ACWF', 'iShares MSCI Global Multifactor ETF'),
#  (62, 'ACWV', 'iShares MSCI Global Min Vol Factor ETF'),
#  (63, 'ACY', 'AeroCentury Corp. Common Stock'),
#  (64, 'ADC', 'Agree Realty Corporation Common Stock'),
#  (65, 'ADCT', 'ADC Therapeutics SA Common Shares'),
#  (66, 'ADEX', 'Adit EdTech Acquisition Corp. Common Stock'),
#  (67, 'ADEX=', 'Adit EdTech Acquisition Corp. Units, each consisting of one share of common stock, and one-half of one redeemable warrant'),
#  (68, 'ADEX+', 'Adit EdTech Acquisition Corp. Redeemable Warrants, each whole warrant exercisable for shares of common stock at an exercise price of $11.50 per share'),
#  (69, 'ADF', 'Aldel Financial Inc. Class A Common Stock'),
#  (70, 'ADF=', 'Aldel Financial Inc. Units, each consisting of one share of Class A common stock and one-half of one redeemable warrant'),
#  (71, 'ADF+', 'Aldel Financial Inc. Warrants, each whole warrant entitles the holder thereof to purchase one share of Class A common stock at a price of $11.50 per share'),
#  (72, 'ADFI', 'Anfield Dynamic Fixed Income ETF'),
#  (73, 'ADIV', 'SmartETFs Asia Pacific Dividend Builder ETF'),
#  (74, 'ADM', 'Archer-Daniels-Midland Company Common Stock'),
#  (75, 'ADME', 'Aptus Drawdown Managed Equity ETF'),
#  (76, 'ADNT', 'Adient plc Ordinary Shares '),
#  (77, 'ADRA', 'Adara Acquisition Corp. Class A Common Stock'),
#  (78, 'ADRA=', 'Adara Acquisition Corp. Units, each consisting of one share of Class A common stock, and one-half of one redeemable warrant'),
#  (162, 'AIEQ', 'AI Powered Equity ETF'),
#  (79, 'ADRA+', 'Adara Acquisition Corp. Redeemable Warrants, each whole warrant exercisable for one share of Class A Common Stock at an exercise price of $11.50'),
#  (80, 'ADS', 'Alliance Data Systems Corporation Common Stock'),
#  (81, 'ADT', 'ADT Inc. Common Stock'),
#  (82, 'ADX', 'Adams Diversified Equity Fund Inc.'),
#  (83, 'AE', 'Adams Resources & Energy, Inc. Common Stock'),
#  (84, 'AEB', 'AEGON N.V. Perp. Cap. Secs. Floating Rate (Netherlands)'),
#  (85, 'AEE', 'Ameren Corporation Common Stock'),
#  (86, 'AEF', 'Aberdeen Emerging Markets Equity Income Fund, Inc. Common Stock'),
#  (87, 'AEFC', 'Aegon Funding Company LLC 5.10% Subordinated Notes due 2049'),
#  (88, 'AEG', 'AEGON N.V. Common Stock'),
#  (89, 'AEL', 'American Equity Investment Life Holding Company Common Stock'),
#  (90, 'AEL-A', 'American Equity Investment Life Holding Company Depositary Shares, each representing a 1/1,000th interest in a share of 5.95% Fixed-Rate Reset Non-Cumulative Preferred Stock, Series A'),
#  (91, 'AEL-B', 'American Equity Investment Life Holding Company Depositary Shares, each representing a 1/1,000th interest in a share of 6.625% Fixed-Rate Reset Non-Cumulative Preferred Stock, Series B'),
#  (92, 'AEM', 'Agnico Eagle Mines Limited Common Stock'),
#  (93, 'AEMB', 'American Century Emerging Markets Bond ETF'),
#  (94, 'AENZ', 'Aenza S.A.A. American Depositary Shares'),
#  (95, 'AEO', 'American Eagle Outfitters, Inc. Common Stock'),
#  (96, 'AER', 'AerCap Holdings N.V. Ordinary Shares'),
#  (97, 'AES', 'The AES Corporation Common Stock'),
#  (98, 'AESC', 'The AES Corporation Corporate Units'),
#  (99, 'AESR', 'Anfield U.S. Equity Sector Rotation ETF'),
#  (100, 'AEVA', 'Aeva Technologies, Inc. Common Stock'),
#  (101, 'AEVA+', 'Aeva Technologies, Inc. Redeemable Warrants, each whole warrant exercisable for shares of common stock at an exercise price of $11.50 per share'),
#  (102, 'AFB', 'AllianceBernstein National Municipal Income Fund Inc'),
#  (103, 'AFG', 'American Financial Group, Inc. Common Stock'),
#  (104, 'AFGB', 'American Financial Group, Inc. 5.875% Subordinated Debentures due 2059'),
#  (105, 'AFGC', 'American Financial Group, Inc. 5.125% Subordinated Debentures due 2059'),
#  (106, 'AFGD', 'American Financial Group, Inc. 5.625% Subordinated Debentures due 2060'),
#  (107, 'AFGE', 'American Financial Group, Inc. 4.500% Subordinated Debentures due 2060'),
#  (108, 'AFI', 'Armstrong Flooring, Inc. Common Stock'),
#  (109, 'AFIF', 'Anfield Universal Fixed Income ETF'),
#  (110, 'AFK', 'VanEck Vectors-Africa Index ETF'),
#  (111, 'AFL', 'AFLAC Incorporated Common Stock'),
#  (112, 'AFLG', 'First Trust Active Factor Large Cap ETF'),
#  (113, 'AFMC', 'First Trust Active Factor Mid Cap ETF'),
#  (114, 'AFSM', 'First Trust Active Factor Small Cap ETF'),
#  (115, 'AFT', 'Apollo Senior Floating Rate Fund Inc. Common Stock'),
#  (116, 'AFTY', 'Pacer CSOP FTSE China A50 ETF'),
#  (117, 'AG', 'First Majestic Silver Corp. Ordinary Shares (Canada)'),
#  (118, 'AGAC', 'African Gold Acquisition Corporation Class A Ordinary Shares'),
#  (119, 'AGAC=', 'African Gold Acquisition Corporation Units, each consisting of one Class A ordinary share and three-quarters of one redeemable warrant'),
#  (120, 'AGAC+', 'African Gold Acquisition Corporation Redeemable Warrants, each whole warrant exercisable for one Class A ordinary share at an exercise price of $11.50'),
#  (121, 'AGCB', 'Altimeter Growth Corp. 2 Class A Ordinary Shares'),
#  (122, 'AGCO', 'AGCO Corporation Common Stock'),
#  (123, 'AGD', 'Aberdeen Global Dynamic Dividend Fund'),
#  (124, 'AGE', 'AgeX Therapeutics, Inc. Common Stock'),
#  (125, 'AGG', 'iShares Core U.S. Aggregate Bond ETF'),
#  (126, 'AGGY', 'WisdomTree Yield Enhanced U.S. Aggregate Bond Fund'),
#  (127, 'AGI', 'Alamos Gold Inc. Class A Common Shares'),
#  (128, 'AGL', 'agilon health, inc. Common Stock'),
#  (129, 'AGM', 'Federal Agricultural Mortgage Corporation Common Stock'),
#  (130, 'AGM-C', 'Federal Agricultural Mortgage Corporation Preferred Series C Fixed to Fltg'),
#  (131, 'AGM-D', 'Federal Agricultural Mortgage Corporation 5.700% Non-Cumulative Preferred Stock, Series D'),
#  (132, 'AGM-E', 'Federal Agricultural Mortgage Corporation 5.750% Non-Cumulative Preferred Stock, Series E'),
#  (133, 'AGM-F', 'Federal Agricultural Mortgage Corporation 5.250% Non-Cumulative Preferred Stock, Series F'),
#  (134, 'AGM-G', 'Federal Agricultural Mortgage Corporation 4.875% Non-Cumulative Preferred Stock, Series G'),
#  (135, 'AGM.A', 'Federal Agricultural Mortgage Corporation Common Stock'),
#  (136, 'AGO', 'Assured Guaranty Ltd. Common Stock'),
#  (137, 'AGO-E', 'Assured Guaranty Ltd.'),
#  (138, 'AGO-F', 'Assured Guaranty Ltd.'),
#  (139, 'AGOV', 'Exchange Listed Funds Trust Gavekal Asia Pacific Government Bond ETF'),
#  (140, 'AGOX', 'Adaptive Growth Opportunities ETF'),
#  (141, 'AGQ', 'ProShares Ultra Silver'),
#  (142, 'AGR', 'Avangrid, Inc. Common Stock'),
#  (143, 'AGRO', 'Adecoagro S.A. Common Shares'),
#  (144, 'AGS', 'PlayAGS, Inc. Common Stock'),
#  (145, 'AGT', 'iShares MSCI Argentina and Global Exposure ETF'),
#  (146, 'AGTI', 'Agiliti, Inc. Common Stock'),
#  (147, 'AGX', 'Argan, Inc. Common Stock'),
#  (148, 'AGZ', 'iShares  Agency Bond ETF'),
#  (149, 'AHH', 'Armada Hoffler Properties, Inc. Common Stock'),
#  (150, 'AHH-A', 'Armada Hoffler Properties, Inc. 6.75% Series A Cumulative Redeemable Perpetual Preferred Stock'),
#  (151, 'AHL-C', 'Aspen Insurance Holdings Limited 5.95% Fixed-to-Floating Rate Perpetual Non-Cumulative Preference Shares'),
#  (152, 'AHL-D', 'Aspen Insurance Holdings Limited 5.625% Perpetual Non-Cumulative Preference Shares'),
#  (153, 'AHL-E', 'Aspen Insurance Holdings Limited Depositary Shares, each representing a 1/1000th interest in a share of 5.625% Perpetual Non-Cumulative Preference Shares'),
#  (154, 'AHT', 'Ashford Hospitality Trust Inc Common Stock'),
#  (155, 'AHT-D', 'Ashford Hospitality Trust Inc 8.45% Series D Cumulative Preferred Stock'),
#  (156, 'AHT-F', 'Ashford Hospitality Trust Inc 7.375% Series F Cumulative Preferred Stock'),
#  (157, 'AHT-G', 'Ashford Hospitality Trust Inc 7.375% Series G Cumulative Preferred Stock'),
#  (158, 'AHT-H', 'Ashford Hospitality Trust Inc 7.50% Series H Cumulative Preferred Stock'),
#  (159, 'AHT-I', 'Ashford Hospitality Trust Inc 7.50% Series I Cumulative Preferred Stock'),
#  (160, 'AI', 'C3.ai, Inc. Class A Common Stock'),
#  (161, 'AIC', 'Arlington Asset Investment Corp 6.750% Notes due 2025'),
#  (163, 'AIF', 'Apollo Tactical Income Fund Inc. Common Stock'),
#  (164, 'AIG', 'American International Group, Inc. New Common Stock'),
#  (165, 'AIG-A', 'American International Group, Inc. Depositary Shares Each Representing a 1/1,000th Interest in a Share of Series A 5.85% Non-Cumulative Perpetual Preferred Stock'),
#  (166, 'AIIQ', 'AI Powered International Equity ETF'),
#  (167, 'AIM', 'AIM ImmunoTech Inc. Common Stock'),
#  (168, 'AIN', 'Albany International Corporation Common Stock'),
#  (169, 'AINC', 'Ashford Inc. (Holding Company) Common Stock'),
#  (170, 'AIO', 'Virtus AllianzGI Artificial Intelligence & Technology Opportunities Fund Common Shares'),
#  (171, 'AIR', 'AAR Corp. Common Stock'),
#  (172, 'AIRC', 'Apartment Income REIT Corp. Common Stock'),
#  (173, 'AIRI', 'Air Industries Group Common Stock'),
#  (174, 'AIT', 'Applied Industrial Technologies, Inc. Common Stock'),
#  (175, 'AIV', 'Apartment Investment and Management Company Common Stock'),
#  (176, 'AIZ', 'Assurant, Inc. Common Stock'),
#  (177, 'AIZN', 'Assurant, Inc. 5.25% Subordinated Notes due 2061'),
#  (178, 'AJAX', 'Ajax I Class A Ordinary Shares'),
#  (179, 'AJAX=', 'Ajax I Units, each consisting of one Class A ordinary share and one-fourth of one redeemable warrant'),
#  (180, 'AJAX+', 'Ajax I Redeemable warrants, each whole warrant exercisable for one Class A ordinary share at an exercise price of $11.50'),
#  (181, 'AJG', 'Arthur J. Gallagher & Co. Common Stock'),
#  (182, 'AJRD', 'Aerojet Rocketdyne Holdings, Inc. Common Stock'),
#  (183, 'AJX', 'Great Ajax Corp. Common Stock'),
#  (184, 'AJXA', 'Great Ajax Corp. 7.25% Convertible Senior Notes due 2024'),
#  (185, 'AKO.A', 'Embotelladora Andina S.A. Common Stock'),
#  (186, 'AKO.B', 'Embotelladora Andina S.A. Common Stock'),
#  (187, 'AKR', 'Acadia Realty Trust Common Stock'),
#  (188, 'AL', 'Air Lease Corporation Class A Common Stock'),
#  (189, 'AL-A', 'Air Lease Corporation 6.150% Fixed-to-Floating Rate Non-Cumulative Perpetual Preferred Stock, Series A'),
#  (190, 'ALB', 'Albemarle Corporation Common Stock'),
#  (191, 'ALC', 'Alcon Inc. Ordinary Shares'),
#  (192, 'ALCC', 'AltC Acquisition Corp. Class A Common Stock'),
#  (193, 'ALE', 'Allete, Inc.'),
#  (194, 'ALEX', 'Alexander & Baldwin, Inc. Common Stock REIT Holding Company'),
#  (195, 'ALFA', 'AlphaClone Alternative Alpha ETF'),
#  (196, 'ALG', 'Alamo Group, Inc. Common Stock'),
#  (197, 'ALIN-A', 'Altera Infrastructure L.P. 7.25% Series A '),
#  (198, 'ALIN-B', 'Altera Infrastructure L.P. 8.50% Series B '),
#  (199, 'ALIN-E', 'Altera Infrastructure L.P. 8.875% Series E '),
#  (200, 'ALIT', 'Alight, Inc. Class A Common Stock'),
#  (201, 'ALIT+', 'Alight, Inc. Warrants, each exercisable for one share of Class A Common Stock at an exercise price of $11.50 per share'),
#  (202, 'ALK', 'Alaska Air Group, Inc. Common Stock'),
#  (203, 'ALL', 'Allstate Corporation (The) Common Stock'),
#  (204, 'ALL-B', 'Allstate Corporation (The) 5.100% Fixed-to-Floating Rate Subordinated Debentures due 2053'),
#  (205, 'ALL-G', 'Allstate Corporation (The) Depositary Shares each representing a 1/1,000th interest in a share of Fixed Rate Noncumulative Perpetual Preferred Stock, Series G'),
#  (206, 'ALL-H', 'Allstate Corporation (The) Depositary Shares each representing a 1/1,000th interest in a share of Fixed Rate Noncumulative Perpetual Preferred Stock, Series H'),
#  (207, 'ALL-I', 'Allstate Corporation (The) Depositary Shares each representing a 1/1,000th interest in a share of Fixed Rate Noncumulative Perpetual Preferred Stock, Series I'),
#  (208, 'ALLE', 'Allegion plc Ordinary Shares'),
#  (209, 'ALLY', 'Ally Financial Inc. Common Stock'),
#  (210, 'ALLY-A', 'GMAC Capital Trust I Fixed Rate Floating Rate Trust Preferred Securities, Series 2'),
#  (211, 'ALP-Q', 'Alabama Power Company 5.00% Class A Preferred Stock, Cumulative, Par Value $1 Per Share (Stated Capital $25 Per Share)'),
#  (212, 'ALSN', 'Allison Transmission Holdings, Inc. Common Stock'),
#  (213, 'ALTG', 'Alta Equipment Group Inc. Class A Common Stock'),
#  (214, 'ALTG-A', 'Alta Equipment Group Inc. Depositary Shares (each representing 1/1000th in a share of 10% Series A Cumulative Perpetual Preferred Stock)'),
#  (215, 'ALTL', 'Pacer Lunt Large Cap Alternator ETF'),
#  (216, 'ALTS', 'ProShares Morningstar Alternatives Solution ETF'),
#  (217, 'ALV', 'Autoliv, Inc. Common Stock'),
#  (218, 'ALX', "Alexander's, Inc. Common Stock"),
#  (219, 'AM', 'Antero Midstream Corporation Common Stock'),
#  (220, 'AMAM', 'Ambrx Biopharma Inc. American Depositary Shares (each representing seven Ordinary Shares)'),
#  (221, 'AMBC', 'Ambac Financial Group, Inc. Common Stock'),
#  (222, 'AMBC+', 'Ambac Financial Group, Inc. Warrants'),
#  (223, 'AMBO', 'Ambow Education Holding Ltd. American Depository Shares, each representing two Class A ordinary shares'),
#  (224, 'AMBP', 'Ardagh Metal Packaging S.A. Ordinary Shares'),
#  (225, 'AMBP+', 'Ardagh Metal Packaging S.A. Warrants, each exercisable for one Share at an exercise price of $11.50 per share'),
#  (226, 'AMC', 'AMC Entertainment Holdings, Inc. Class A Common Stock'),
#  (227, 'AMCR', 'Amcor plc Ordinary Shares'),
#  (228, 'AME', 'AMETEK, Inc.'),
#  (229, 'AMER', 'Emles Made in America ETF'),
#  (230, 'AMG', 'Affiliated Managers Group, Inc. Common Stock'),
#  (231, 'AMH', 'American Homes 4 Rent Common Shares of Beneficial Interest'),
#  (232, 'AMH-F', 'American Homes 4 Rent 5.875% Series F Cumulative Redeemable Perpetual Preferred Shares'),
#  (233, 'AMH-G', 'American Homes 4 Rent Series G cumulative redeemable perpetual preferred shares of beneficial interest'),
#  (234, 'AMH-H', 'American Homes 4 Rent Series H cumulative redeemable perpetual Preferred Shares of Beneficial Interest'),
#  (235, 'AMJ', 'JPMorgan Chase Capital XVI JP Morgan Alerian MLP ETN'),
#  (236, 'AMK', 'AssetMark Financial Holdings, Inc. Common Stock'),
#  (237, 'AMLP', 'Alerian MLP ETF'),
#  (238, 'AMN', 'AMN Healthcare Services Inc AMN Healthcare Services Inc'),
#  (239, 'AMNA', 'ETRACS Alerian Midstream Energy Index ETN'),
#  (240, 'AMND', 'UBS AG ETRACS Alerian Midstream Energy High Dividend Index ETN'),
#  (241, 'AMOM', 'QRAFT AI-Enhanced U.S. Large Cap Momentum ETF'),
#  (242, 'AMOV', 'America Movil, S.A.B. de C.V. Class A American Depositary Shares'),
#  (243, 'AMP', 'Ameriprise Financial, Inc. Common Stock'),
#  (244, 'AMPE', 'Ampio Pharmaceuticals, Inc.'),
#  (245, 'AMPI', 'Advanced Merger Partners, Inc. Class A Common Stock'),
#  (246, 'AMPI=', 'Advanced Merger Partners, Inc. Units, each consisting of one share of Class A common stock and one-sixth of one redeemable warrant'),
#  (247, 'AMPI+', 'Advanced Merger Partners, Inc. Warrants, each whole warrant exercisable for one share of Class A Common Stock at an exercise price of $11.50'),
#  (248, 'AMPY', 'Amplify Energy Corp. Common Stock'),
#  (249, 'AMR', 'Alpha Metallurgical Resources, Inc. Common Stock'),
#  (250, 'AMRC', 'Ameresco, Inc. Class A Common Stock'),
#  (251, 'AMRX', 'Amneal Pharmaceuticals, Inc. Class A Common Stock'),
#  (252, 'AMS', 'American Shared Hospital Services Common Stock'),
#  (253, 'AMT', 'American Tower Corporation (REIT) Common Stock'),
#  (254, 'AMTR', 'ETRACS Alerian Midstream Energy Total Return Index ETN'),
#  (255, 'AMUB', 'ETRACS Alerian MLP Index ETN Series B due July 18, 2042'),
#  (256, 'AMWL', 'American Well Corporation Class A Common Stock'),
#  (257, 'AMX', 'America Movil, S.A.B. de C.V. American Depository Receipt Series L'),
#  (258, 'AMZA', 'InfraCap MLP ETF'),
#  (259, 'AN', 'AutoNation, Inc. Common Stock'),
#  (260, 'ANAC', 'Arctos NorthStar Acquisition Corp. Class A Ordinary Shares'),
#  (261, 'ANAC=', 'Arctos NorthStar Acquisition Corp. Units, each consisting of one Class A ordinary share, and one-fourth of one redeemable warrant'),
#  (262, 'ANAC+', 'Arctos NorthStar Acquisition Corp. Warrants, each whole warrant exercisable for one Class A ordinary share at an exercise price of $11.50'),
#  (263, 'ANET', 'Arista Networks, Inc. Common Stock'),
#  (264, 'ANEW', 'ProShares MSCI Transformational Changes ETF'),
#  (265, 'ANF', 'Abercrombie & Fitch Company Common Stock'),
#  (266, 'ANTM', 'Anthem, Inc. Common Stock'),
#  (267, 'ANVS', 'Annovis Bio, Inc. Common Stock'),
#  (268, 'AOA', 'iShares Core Aggressive Allocation ETF'),
#  (269, 'AOD', 'Aberdeen Total Dynamic Dividend Fund Common Stock'),
#  (270, 'AOK', 'iShares Core Conservative Allocation ETF'),
#  (271, 'AOM', 'iShares Core Moderate Allocation ETF'),
#  (272, 'AOMR', 'Angel Oak Mortgage, Inc. Common Stock'),
#  (273, 'AON', 'Aon plc Class A Ordinary Shares (Ireland)'),
#  (274, 'AOR', 'iShares Core Growth Allocation ETF'),
#  (275, 'AOS', 'A.O. Smith Corporation Common Stock'),
#  (276, 'AP', 'Ampco-Pittsburgh Corporation Common Stock'),
#  (277, 'AP+', 'Ampco-Pittsburgh Corporation Series A Warrants to purchase Shares of common stock'),
#  (278, 'APAM', 'Artisan Partners Asset Management Inc. Class A Common Stock'),
#  (279, 'APD', 'Air Products and Chemicals, Inc. Common Stock'),
#  (280, 'APG', 'APi Group Corporation Common Stock'),
#  (281, 'APGB', 'Apollo Strategic Growth Capital II Class A Ordinary Shares'),
#  (282, 'APGB=', 'Apollo Strategic Growth Capital II Units, each consisting of one Class A Ordinary Share and one-fifth Warrant'),
#  (283, 'APGB+', 'Apollo Strategic Growth Capital II Warrants, each exercisable for one Class A Ordinary Share at an exercise price of $11.50 per share'),
#  (284, 'APH', 'Amphenol Corporation Common Stock'),
#  (285, 'APLE', 'Apple Hospitality REIT, Inc. Common Shares'),
#  (286, 'APO', 'Apollo Global Management, Inc. Class A Common Stock'),
#  (287, 'APO-A', 'Apollo Global Management, Inc. 6.375% Series A Preferred Shares'),
#  (288, 'APO-B', 'Apollo Global Management, Inc 6.375% Series B Preferred Shares'),
#  (289, 'APRN', 'Blue Apron Holdings, Inc. Class A Common Stock'),
#  (290, 'APRZ', 'Trust TrueShares Structured Outcome (April) ETF'),
#  (291, 'APSG', 'Apollo Strategic Growth Capital Class A Ordinary Shares'),
#  (292, 'APSG=', 'Apollo Strategic Growth Capital Units, each consisting of one Class A Ordinary Share and one-third Warrant'),
#  (293, 'APSG+', 'Apollo Strategic Growth Capital Warrants, each exercisable for one Class A Ordinary Share at an exercise price of $11.50 per share'),
#  (294, 'APT', 'Alpha Pro Tech, Ltd. Common Stock'),
#  (295, 'APTS', 'Preferred Apartment Communities, Inc. Common Stock'),
#  (296, 'APTV', 'Aptiv PLC Ordinary Shares'),
#  (297, 'APTV-A', 'Aptiv PLC 5.50% Series A Mandatory Convertible Preferred Shares'),
#  (298, 'AQN', 'Algonquin Power & Utilities Corp. Common Shares'),
#  (299, 'AQNA', 'Algonquin Power & Utilities Corp. 6.875% Fixed-to-Floating Rate Subordinated Notes Series 2018-A due October 17, 2078'),
#  (300, 'AQNB', 'Algonquin Power & Utilities Corp. 6.20% Fixed-to-Floating Subordinated Notes Series 2019-A due July 1, 2079'),
#  (301, 'AQNU', 'Algonquin Power & Utilities Corp. Corporate Units'),
#  (302, 'AQUA', 'Evoqua Water Technologies Corp. Common Stock'),
#  (303, 'AR', 'Antero Resources Corporation Common Stock'),
#  (304, 'ARB', 'AltShares Merger Arbitrage ETF'),
#  (305, 'ARC', 'ARC Document Solutions, Inc. Common Stock'),
#  (306, 'ARCH', 'Arch Resources, Inc. Class A Common Stock'),
#  (307, 'ARCM', 'Arrow Reserve Capital Management ETF'),
#  (308, 'ARCO', 'Arcos Dorados Holdings Inc. Class A Shares'),
#  (309, 'ARD', 'Ardagh Group S.A. Common Shares'),
#  (310, 'ARDC', 'Ares Dynamic Credit Allocation Fund, Inc. Common Shares'),
#  (311, 'ARE', 'Alexandria Real Estate Equities, Inc. Common Stock'),
#  (312, 'ARES', 'Ares Management Corporation Class A Common Stock'),
#  (313, 'ARGD', 'Argo Group International Holdings, Ltd. 6.5% Senior Notes Due 2042'),
#  (314, 'ARGO', 'Argo Group International Holdings, Ltd.'),
#  (315, 'ARGO-A', 'Argo Group International Holdings, Ltd. Depositary Shares, Each Representing a 1/1,000th Interest in a 7.00% Resettable Fixed Rate Preference Share, Series A'),
#  (316, 'ARGT', 'Global X MSCI Argentina ETF'),
#  (317, 'ARI', 'Apollo Commercial Real Estate Finance, Inc'),
#  (318, 'ARKF', 'ARK Fintech Innovation ETF'),
#  (319, 'ARKG', 'ARK Genomic Revolution ETF'),
#  (320, 'ARKK', 'ARK Innovation ETF'),
#  (321, 'ARKQ', 'ARK Autonomous Technology & Robotics ETF'),
#  (322, 'ARKW', 'ARK Next Generation Internet ETF'),
#  (323, 'ARKX', 'ARK Space Exploration & Innovation ETF'),
#  (324, 'ARL', 'American Realty Investors, Inc. Common Stock'),
#  (325, 'ARLO', 'Arlo Technologies, Inc. Common Stock'),
#  (326, 'ARMK', 'Aramark Common Stock'),
#  (327, 'ARMP', 'Armata Pharmaceuticals, Inc. Common Stock'),
#  (328, 'ARMR', 'Exchange Listed Funds Trust Armor US Equity Index ETF'),
#  (329, 'ARNC', 'Arconic Corporation Common Stock '),
#  (330, 'AROC', 'Archrock, Inc. Common Stock'),
#  (331, 'ARR', 'ARMOUR Residential REIT, Inc.'),
#  (332, 'ARR-C', 'ARMOUR Residential REIT, Inc. 7% Series C Cumulative Redeemable Preferred Stock (liquidation preference $25.00 per share)'),
#  (333, 'ARW', 'Arrow Electronics, Inc. Common Stock'),
#  (334, 'ASA', 'ASA  Gold and Precious Metals Limited'),
#  (335, 'ASAI', 'Sendas Distribuidora S.A. ADS'),
#  (336, 'ASAN', 'Asana, Inc. Class A Common Stock'),
#  (337, 'ASAQ', 'Atlantic Street Acquisition Corp Class A Common Stock'),
#  (338, 'ASAQ=', 'Atlantic Street Acquisition Corp Units, each consisting of one share of Class A common stock and one-half of one Warrant'),
#  (339, 'ASAQ+', 'Atlantic Street Acquisition Corp Warrants, each whole warrant exercisable for one share of Class A common stock at an exercise price of $11.50 per share'),
#  (340, 'ASB', 'Associated Banc-Corp Common Stock'),
#  (341, 'ASB-D', 'Associated Banc-Corp Depositary Shares, each representing a 1/40th interest in a share of Associated Banc-Corp 5.375% Non-Cumulative Perpetual Preferred Stock, Series D'),
#  (342, 'ASB-E', 'Associated Banc-Corp Depositary Shares, each representing a 1/40th interest in a share of 5.875% Non-Cumulative Perpetual Preferred Stock, Series E'),
#  (343, 'ASB-F', 'Associated Banc-Corp Depositary Shares, each representing a 1/40th interest in a share of Associated Banc-Corp 5.625% Non-Cumulative Perpetual Preferred Stock, Series F'),
#  (344, 'ASC', 'Ardmore Shipping Corporation Common Stock'),
#  (345, 'ASEA', 'Global X FTSE Southeast Asia ETF'),
#  (346, 'ASG', 'Liberty All-Star Growth Fund, Inc.'),
#  (347, 'ASGI', 'Aberdeen Standard Global Infrastructure Income Fund Common Shares of Beneficial Interest'),
#  (348, 'ASGN', 'ASGN Incorporated Common Stock'),
#  (349, 'ASH', 'Ashland Global Holdings Inc. Common Stock'),
#  (350, 'ASHR', 'Xtrackers Harvest CSI 300 China A-Shares ETF'),
#  (351, 'ASHS', 'Xtrackers Harvest CSI 500 China A-Shares Small Cap ETF'),
#  (352, 'ASHX', 'Xtrackers MSCI China A Inclusion Equity ETF'),
#  (353, 'ASIX', 'AdvanSix Inc. Common Stock '),
#  (354, 'ASM', 'Avino Silver & Gold Mines Ltd. Common Shares (Canada)'),
#  (355, 'ASPN', 'Aspen Aerogels, Inc. Common Stock'),
#  (356, 'ASPY', 'ASYMmetric ETFs Trust ASYMshares ASYMmetric 500 ETF'),
#  (357, 'ASR', 'Grupo Aeroportuario del Sureste, S.A. de C.V. Common Stock'),
#  (358, 'ASX', 'ASE Technology Holding Co., Ltd. American Depositary Shares (each representing Two Common Shares) '),
#  (359, 'ASXC', 'Asensus Surgical, Inc. Common Stock'),
#  (360, 'ASZ', 'Austerlitz Acquisition Corporation II Class A Ordinary Shares'),
#  (361, 'ASZ=', 'Austerlitz Acquisition Corporation II Units, each consisting of one Class A ordinary share and one-fourth of one redeemable warrant'),
#  (362, 'ASZ+', 'Austerlitz Acquisition Corporation II Warrants, each whole Warrant exercisable for one Class A Ordinary Share at an exercise price of $11.50 per share'),
#  (363, 'ATA', 'Americas Technology Acquisition Corp. Ordinary Shares'),
#  (364, 'ATA=', 'Americas Technology Acquisition Corp. Units, each consisting of one Ordinary Share and one half of Redeemable Warrant'),
#  (365, 'ATA+', 'Americas Technology Acquisition Corp. Redeemable Warrants, each whole warrant exercisable for one Ordinary Share at an exercise price of $11.50'),
#  (366, 'ATAQ', 'Altimar Acquisition Corp. III Class A Ordinary Shares'),
#  (367, 'ATAQ=', 'Altimar Acquisition Corp. III Units, each consisting of one Class A Ordinary Share and one-fourth of one redeemable warrant'),
#  (368, 'ATAQ+', 'Altimar Acquisition Corp. III Warrants, each whole warrant exercisable for one Class A Ordinary Share at an exercise price of $11.50 per share'),
#  (369, 'ATC', 'Atotech Limited Common Shares'),
#  (370, 'ATCO', 'Atlas Corp. Common Shares'),
#  (371, 'ATCO-D', 'Atlas Corp. 7.95% Series D'),
#  (372, 'ATCO-H', 'Atlas Corp. 7.875% Series H'),
#  (373, 'ATCO-I', 'Atlas Corp. Series I Fixed-to-Floating '),
#  (374, 'ATEN', 'A10 Networks, Inc. Common Stock'),
#  (375, 'ATEST', 'Tick Pilot Test Control Common Stock'),
#  (376, 'ATEST.A', 'Tick Pilot Test Group 1 Common Stock'),
#  (377, 'ATEST.B', 'Tick pilot Test 2 Common Stock'),
#  (378, 'ATEST.C', 'Tick Pilot Test 3 Common Stock'),
#  (379, 'ATFV', 'Alger 35 ETF'),
#  (380, 'ATGE', 'Adtalem Global Education Inc. Common Stock'),
#  (381, 'ATH', 'Athene Holding Ltd. Class A Common Shares'),
#  (382, 'ATH-A', 'Athene Holding Ltd. Depositary Shares, Each Representing a 1/1,000th Interest in a 6.35% Fixed-to-Floating Rate Perpetual Non-Cumulative Preference Share, Series A'),
#  (383, 'ATH-B', 'Athene Holding Ltd. Depositary Shares, Each Representing a 1/1,000th Interest in a 5.625% Fixed Rate Perpetual Non- Cumulative Preference Share, Series B, par value $1.00 per share'),
#  (384, 'ATH-C', 'Athene Holding Ltd. Depositary Shares, each representing a 1/1,000th Interest in a Share of 6.375% Fixed-Rate Reset Perpetual Non-Cumulative Preference Shares, Series C'),
#  (385, 'ATH-D', 'Athene Holding Ltd. Depositary Shares, Each Representing a 1/1,000th Interest in a 4.875% Fixed-Rate Perpetual Non-Cumulative Preference Share, Series D'),
#  (386, 'ATHM', 'Autohome Inc. American Depositary Shares, each representing four class A ordinary shares.'),
#  (387, 'ATHN', 'Athena Technology Acquisition Corp. Class A Common Stock'),
#  (388, 'ATHN=', 'Athena Technology Acquisition Corp. Units, each consisting of one share of Class A Common Stock and one-third of one Redeemable Warrant'),
#  (389, 'ATHN+', 'Athena Technology Acquisition Corp. Redeemable Warrants, each whole warrant exercisable for one share of Class A Common Stock at an exercise price of $11.50'),
#  (390, 'ATI', 'Allegheny Technologies Incorporated Common Stock'),
#  (391, 'ATIP', 'ATI Physical Therapy, Inc. Class A Common Stock'),
#  (392, 'ATIP+', 'ATI Physical Therapy, Inc. Warrants'),
#  (393, 'ATKR', 'Atkore Inc. Common Stock'),
#  (394, 'ATMP', 'iPath Select MLP ETN'),
#  (395, 'ATMR', 'Altimar Acquisition Corp. II Class A Ordinary Shares'),
#  (396, 'ATMR=', 'Altimar Acquisition Corp. II Units, each consisting of one Class A ordinary share and one-fourth of one redeemable warrant'),
#  (397, 'ATMR+', 'Altimar Acquisition Corp. II Warrants, each whole warrant exercisable for one Class A Ordinary Share at an exercise price of $11.50 per share'),
#  (398, 'ATNM', 'Actinium Pharmaceuticals, Inc. (Delaware) Common Stock'),
#  (399, 'ATO', 'Atmos Energy Corporation Common Stock'),
#  (400, 'ATR', 'AptarGroup, Inc. Common Stock'),
#  (401, 'ATTO', 'Atento S.A. Ordinary Shares'),
#  (402, 'ATUS', 'Altice USA, Inc. Class A Common Stock'),
#  (403, 'AU', 'AngloGold Ashanti Limited Common Stock'),
#  (404, 'AUD', 'Audacy Common Stock'),
#  (405, 'AUGZ', 'TrueShares Structured Outcome (August) ETF'),
#  (406, 'AUMN', 'Golden Minerals Company Common Stock'),
#  (407, 'AUS', 'Austerlitz Acquisition Corporation I Class A Ordinary Shares'),
#  (408, 'AUS=', 'Austerlitz Acquisition Corporation I Units, each consisting of one Class A ordinary share and one-fourth of one redeemable warrant'),
#  (409, 'AUS+', 'Austerlitz Acquisition Corporation I Warrants, each whole Warrant exercisable for one Class A Ordinary Share at an exercise price of $11.50 per share'),
#  (410, 'AUSF', 'Global X Funds Global X Adaptive U.S. Factor ETF'),
#  (411, 'AUY', 'Yamana Gold Inc. Ordinary Shares (Canada)'),
#  (412, 'AVA', 'Avista Corporation Common Stock'),
#  (413, 'AVAL', 'Grupo Aval Acciones y Valores S.A. ADR (Each representing 20 preferred shares)'),
#  (414, 'AVAN', 'Avanti Acquisition Corp. Class A Ordinary Shares'),
#  (415, 'AVAN=', 'Avanti Acquisition Corp. Units, each consisting of one Class A ordinary share, and redeemable warrant'),
#  (416, 'AVAN+', 'Avanti Acquisition Corp. Redeemable Warrants, each whole warrant exercisable for one Class A ordinary share at an exercise price of $11.50'),
#  (417, 'AVB', 'AvalonBay Communities, Inc. Common Stock'),
#  (418, 'AVD', 'American Vanguard Corporation Common Stock ($0.10 Par Value)'),
#  (419, 'AVDE', 'Avantis International Equity ETF'),
#  (420, 'AVDG', 'AVDR US LargeCap ESG ETF'),
#  (421, 'AVDR', 'AVDR US LargeCap Leading ETF'),
#  (422, 'AVDV', 'Avantis International Small Cap Value ETF'),
#  (423, 'AVEM', 'Avantis Emerging Markets Equity ETF'),
#  (424, 'AVIG', 'Avantis Core Fixed Income ETF'),
#  (425, 'AVK', 'Advent Convertible and Income Fund'),
#  (426, 'AVLR', 'Avalara, Inc. Common Stock'),
#  (427, 'AVMU', 'Avantis Core Municipal Fixed Income ETF'),
#  (428, 'AVNS', 'Avanos Medical, Inc. Common Stock'),
#  (429, 'AVNT', 'Avient Corporation Common Stock'),
#  (430, 'AVSF', 'Avantis Short-Term Fixed Income ETF'),
#  (431, 'AVTR', 'Avantor, Inc. Common Stock'),
#  (432, 'AVTR-A', 'Avantor, Inc. Series A Mandatory Convertible Preferred Stock'),
#  (433, 'AVUS', 'Avantis U.S. Equity ETF'),
#  (434, 'AVUV', 'Avantis U.S. Small Cap Value ETF'),
#  (435, 'AVY', 'Avery Dennison Corporation Common Stock'),
#  (436, 'AVYA', 'Avaya Holdings Corp. Common Stock'),
#  (437, 'AWAY', 'ETFMG Travel Tech ETF'),
#  (438, 'AWF', 'Alliancebernstein Global High Income Fund'),
#  (439, 'AWI', 'Armstrong World Industries Inc Common Stock'),
#  (440, 'AWK', 'American Water Works Company, Inc. Common Stock'),
#  (441, 'AWP', 'Aberdeen Global Premier Properties Fund Common Shares of Beneficial Interest'),
#  (442, 'AWR', 'American States Water Company Common Stock'),
#  (443, 'AWTM', 'Aware Ultra-Short Duration Enhanced Income ETF'),
#  (444, 'AWX', 'Avalon Holdings Corporation Common Stock'),
#  (445, 'AWYX', 'ETFMG 2X Daily Travel Tech ETF'),
#  (446, 'AX', 'Axos Financial, Inc. Common Stock'),
#  (447, 'AXL', 'American Axle & Manufacturing Holdings, Inc. Common Stock'),
#  (448, 'AXP', 'American Express Company Common Stock'),
#  (449, 'AXR', 'AMREP Corporation Common Stock'),
#  (450, 'AXS', 'Axis Capital Holdings Limited Common Stock'),
#  (451, 'AXS-E', 'Axis Capital Holdings Limited Depositary Shares, each representing 1/100th interest in a share of a 5.50% Series E Preferred Shares'),
#  (452, 'AXTA', 'Axalta Coating Systems Ltd. Common Shares'),
#  (453, 'AXU', 'Alexco Resource Corp Common Shares (Canada)'),
#  (454, 'AYI', 'Acuity Brands, Inc. '),
#  (455, 'AYX', 'Alteryx, Inc. Class A Common Stock'),
#  (456, 'AZAA', 'AllianzIM U.S. Large Cap Buffer10 Apr ETF'),
#  (457, 'AZAJ', 'AllianzIM U.S. Large Cap Buffer10 Jan ETF'),
#  (458, 'AZAL', 'AllianzIM U.S. Large Cap Buffer10 Jul ETF'),
#  (459, 'AZAO', 'AllianzIM U.S. Large Cap Buffer10 Oct ETF'),
#  (460, 'AZBA', 'AllianzIM U.S. Large Cap Buffer20 Apr ETF'),
#  (461, 'AZBJ', 'AllianzIM U.S. Large Cap Buffer20 Jan ETF'),
#  (462, 'AZBL', 'AllianzIM U.S. Large Cap Buffer20 Jul ETF'),
#  (463, 'AZBO', 'AllianzIM U.S. Large Cap Buffer20 Oct ETF'),
#  (464, 'AZEK', 'The AZEK Company Inc. Class A Common Stock'),
#  (465, 'AZO', 'AutoZone, Inc. Common Stock'),
#  (466, 'AZRE', 'Azure Power Global Limited Equity Shares'),
#  (467, 'AZUL', 'Azul S.A. American Depositary Shares (each representing three preferred shares)'),
#  (468, 'AZZ', 'AZZ Inc.'),
#  (469, 'B', 'Barnes Group, Inc. Common Stock'),
#  (470, 'BA', 'Boeing Company (The) Common Stock'),
#  (471, 'BAB', 'Invesco Taxable Municipal Bond ETF'),
#  (472, 'BABA', 'Alibaba Group Holding Limited American Depositary Shares each representing eight Ordinary share'),
#  (473, 'BAC', 'Bank of America Corporation Common Stock'),
#  (474, 'BAC-B', 'Bank of America Corporation Depositary Shares, each representing a 1/1,000th interest in a share of 6.000% Non-Cumulative Preferred Stock, Series GG'),
#  (475, 'BAC-E', 'Bank of America Corporation Depositary Sh repstg 1/1000th Perp Pfd Ser E'),
#  (476, 'BAC-K', 'Bank of America Corporation Depositary Shares, each representing a 1/1,000th interest in a share of 5.875% Non- Cumulative Preferred Stock, Series HH'),
#  (477, 'BAC-L', 'Bank of America Corporation Non Cumulative Perpetual Conv Pfd Ser L'),
#  (478, 'BAC-M', 'Bank of America Corporation Depositary Shares, each representing a 1/1,000th interest in a share of 5.375% Non-Cumulative Preferred Stock, Series KK'),
#  (479, 'BAC-N', 'Bank of America Corporation Depositary shares, each representing 1/1,000th interest in a share of 5.000% Non-Cumulative Preferred Stock, Series LL'),
#  (480, 'BAC-O', 'Bank of America Corporation Depositary shares, each representing 1/1,000th interest in a share of 4.375% Non-Cumulative Preferred Stock, Series NN'),
#  (481, 'BAC-P', 'Bank of America Corporation Depositary Shares, each representing a 1/1,000th interest in a share of 4.125% Non-Cumulative Preferred Stock, Series PP'),
#  (482, 'BAH', 'Booz Allen Hamilton Holding Corporation Common Stock'),
#  (483, 'BAK', 'Braskem SA ADR'),
#  (484, 'BAL', 'iPathA Series B Bloomberg Cotton Subindex Total Return ETN'),
#  (485, 'BALT', 'Innovator Defined Wealth Shield ETF'),
#  (486, 'BALY', "Bally's Corporation Common Stock"),
#  (487, 'BAM', 'Brookfield Asset Management Inc. Common Stock'),
#  (488, 'BAMH', 'Brookfield Finance Inc. 4.625% Subordinated Notes due October 16, 2080'),
#  (489, 'BAMI', 'Brookfield Finance Inc. 4.50% Perpetual Subordinated Notes'),
#  (490, 'BAMR', 'Brookfield Asset Management Reinsurance Partners Ltd. Class A Exchangeable Limited Voting Shares'),
#  (491, 'BANC', 'Banc of California, Inc. Common Stock'),
#  (492, 'BANC-E', 'Banc of California, Inc. Depositary Shares Each Representing a 1/40th Interest in a Share of 7.000% Non-Cumulative Perpetual Preferred Stock, Series E'),
#  (493, 'BAP', 'Credicorp Ltd. Common Stock'),
#  (494, 'BAPR', 'Innovator S&P 500 Buffer ETF - April '),
#  (495, 'BAR', 'GraniteShares Gold Trust Shares of Beneficial Interest'),
#  (496, 'BARK', 'The Original BARK Company Common Stock'),
#  (497, 'BARK+', 'The Original BARK Company Warrants'),
#  (498, 'BATL', 'Battalion Oil Corporation Common Stock'),
#  (499, 'BATT', 'Amplify Lithium & Battery Technology ETF'),
#  (500, 'BAUG', 'Innovator S&P 500 Buffer ETF - August'),
#  (501, 'BAX', 'Baxter International Inc. Common Stock'),
#  (502, 'BB', 'BlackBerry Limited Common Stock'),
#  (503, 'BBAR', 'Banco BBVA Argentina S.A. ADS'),
#  (504, 'BBAX', 'JPMorgan BetaBuilders Developed Asia-ex Japan ETF '),
#  (505, 'BBC', 'Virtus LifeSci Biotech Clinical Trials ETF'),
#  (506, 'BBCA', 'JPMorgan BetaBuilders Canada ETF '),
#  (507, 'BBD', 'Banco Bradesco Sa American Depositary Shares'),
#  (508, 'BBDC', 'Barings BDC, Inc. Common Stock'),
#  (509, 'BBDO', 'Banco Bradesco Sa American Depositary Shares (each representing one Common Share)'),
#  (510, 'BBEU', 'JPMorgan BetaBuilders Europe ETF '),
#  (511, 'BBIN', 'JPMorgan BetaBuilders International Equity ETF'),
#  (512, 'BBJP', 'JPMorgan BetaBuilders Japan ETF '),
#  (513, 'BBL', 'BHP Group PlcSponsored ADR'),
#  (514, 'BBMC', 'JPMorgan BetaBuilders U.S. Mid Cap Equity ETF'),
#  (515, 'BBN', 'BlackRock Taxable Municipal Bond Trust Common Shares of Beneficial Interest'),
#  (516, 'BBP', 'Virtus LifeSci Biotech Products ETF'),
#  (517, 'BBRE', 'JPMorgan BetaBuilders MSCI U.S. REIT ETF '),
#  (518, 'BBSA', 'JPMorgan BetaBuilders 1-5 Year U.S. Aggregate Bond ETF '),
#  (519, 'BBSC', 'JPMorgan BetaBuilders U.S. Small Cap Equity ETF'),
#  (520, 'BBU', 'Brookfield Business Partners L.P. Limited Partnership Units '),
#  (521, 'BBUS', 'JPMorgan BetaBuilders U.S. Equity ETF'),
#  (522, 'BBVA', 'Banco Bilbao Vizcaya Argentaria S.A. Common Stock'),
#  (523, 'BBW', 'Build-A-Bear Workshop, Inc. Common Stock'),
#  (524, 'BBWI', 'Bath & Body Works, Inc.'),
#  (525, 'BBY', 'Best Buy Co., Inc. Common Stock'),
#  (526, 'BC', 'Brunswick Corporation Common Stock'),
#  (527, 'BC-A', 'Brunswick Corporation 6.500% Senior Notes due 2048'),
#  (528, 'BC-B', 'Brunswick Corporation 6.625% Senior Notes due 2049'),
#  (529, 'BC-C', 'Brunswick Corporation 6.375% Notes due 2049'),
#  (530, 'BCAT', 'BlackRock Capital Allocation Trust Common Shares of Beneficial Interest'),
#  (531, 'BCC', 'Boise Cascade, L.L.C. Common Stock'),
#  (532, 'BCD', 'Aberdeen Standard Bloomberg All Commodity Longer Dated Strategy K-1 Free ETF'),
#  (533, 'BCE', 'BCE, Inc. Common Stock'),
#  (534, 'BCEI', 'Bonanza Creek Energy, Inc. Common Stock'),
#  (535, 'BCH', 'Banco De Chile Banco De Chile ADS'),
#  (536, 'BCI', 'Aberdeen Standard Bloomberg All Commodity Strategy K-1 Free ETF'),
#  (537, 'BCM', 'iPath Pure Beta Broad Commodity ETN'),
#  (538, 'BCO', 'Brinks Company (The) Common Stock'),
#  (539, 'BCS', 'Barclays PLC Common Stock'),
#  (540, 'BCSF', 'Bain Capital Specialty Finance, Inc. Common Stock'),
#  (541, 'BCV', 'Bancroft Fund, Ltd.'),
#  (542, 'BCV-A', 'Bancroft Fund Limited 5.375% Series A Cumulative Preferred Shares'),
#  (543, 'BCX', 'BlackRock Resources Common Shares of Beneficial Interest'),
#  (544, 'BDC', 'Belden Inc Common Stock'),
#  (545, 'BDCX', 'ETRACS Quarterly Pay 1.5X Leveraged MVIS BDC Index ETN due June 10, 2050'),
#  (546, 'BDCZ', 'ETRACS MVIS Business Development Companies Index ETN due April 26, 2041'),
#  (547, 'BDEC', 'Innovator S&P 500 Buffer ETF - December'),
#  (548, 'BDJ', 'Blackrock Enhanced Equity Dividend Trust'),
#  (549, 'BDL', "Flanigan's Enterprises, Inc. Common Stock"),
#  (550, 'BDN', 'Brandywine Realty Trust Common Stock'),
#  (551, 'BDR', 'Blonder Tongue Laboratories, Inc. Common Stock'),
#  (552, 'BDRY', 'Breakwave Dry Bulk Shipping ETF'),
#  (553, 'BDX', 'Becton, Dickinson and Company Common Stock'),
#  (554, 'BDXB', 'Becton, Dickinson and Company Depositary Shares, each Representing a 1/20th Interest in a Share of 6.00% Mandatory Convertible Preferred Stock, Series B'),
#  (555, 'BE', 'Bloom Energy Corporation Class A Common Stock'),
#  (556, 'BECO', 'BlackRock Future Climate and Sustainable Economy ETF'),
#  (557, 'BEDU', 'Bright Scholar Education Holdings Limited American Depositary Shares, each  representing one Class A Ordinary Share'),
#  (558, 'BEDZ', 'AdvisorShares Hotel ETF'),
#  (559, 'BEKE', 'KE Holdings Inc American Depositary Shares (each representing three Class A Ordinary Shares)'),
#  (560, 'BEN', 'Franklin Resources, Inc. Common Stock'),
#  (561, 'BEP', 'Brookfield Renewable Partners L.P. '),
#  (562, 'BEP-A', 'Brookfield Renewable Partners L.P. 5.25% Class A Preferred Limited Partnership Units, Series 17'),
#  (563, 'BEPC', 'Brookfield Renewable Corporation Class A Subordinate Voting Shares '),
#  (564, 'BEPH', 'Brookfield BRP Holdings (Canada) Inc. 4.625% Perpetual Subordinated Notes'),
#  (565, 'BERY', 'Berry Global Group, Inc. Common Stock'),
#  (566, 'BEST', 'BEST Inc. American Depositary Shares, each representing one Class A Ordinary Share'),
#  (567, 'BETZ', 'Roundhill Sports Betting & iGaming ETF'),
#  (568, 'BF.A', 'Brown Forman Inc Class A Common Stock'),
#  (569, 'BF.B', 'Brown Forman Inc Class B Common Stock'),
#  (570, 'BFAM', 'Bright Horizons Family Solutions Inc. Common Stock'),
#  (571, 'BFEB', 'Innovator S&P 500 Buffer ETF - February'),
#  (572, 'BFK', 'BlackRock Municipal Income Trust'),
#  (573, 'BFLY', 'Butterfly Network, Inc. Class A Common Stock'),
#  (574, 'BFLY+', 'Butterfly Network, Inc. Warrants'),
#  (575, 'BFOR', "Barron's 400"),
#  (576, 'BFS', 'Saul Centers, Inc. Common Stock'),
#  (577, 'BFS-D', 'Saul Centers, Inc. Depositary Shares, each representing 1/100th of a share of 6.125% Series D Cumulative Redeemable Preferred Stock'),
#  (833, 'CAPL', 'CrossAmerica Partners LP Common Units representing limited partner interests'),
#  (578, 'BFS-E', 'Saul Centers, Inc. Depositary shares, each representing a 1/100th fractional interest in a share of 6.000% Series E Cumulative Redeemable Preferred Stock'),
#  (579, 'BFTR', 'BlackRock Future Innovators ETF'),
#  (580, 'BFZ', 'BlackRock California Municipal Income Trust'),
#  (581, 'BG', 'Bunge Limited Bunge Limited'),
#  (582, 'BGB', 'Blackstone Strategic Credit Fund Common Shares'),
#  (583, 'BGH', 'Barings Global Short Duration High Yield Fund Common Shares of Beneficial Interests'),
#  (584, 'BGI', 'Birks Group Inc. Common Stock'),
#  (585, 'BGIO', 'BlackRock 2022 Global Income Opportunity Trust Common Shares of Beneficial Interest'),
#  (586, 'BGLD', 'FT Cboe Vest Gold Strategy Quarterly Buffer ETF'),
#  (587, 'BGR', 'BlackRock Energy and Resources Trust'),
#  (588, 'BGS', 'B&G Foods, Inc. B&G Foods, Inc. Common Stock'),
#  (589, 'BGSF', 'BGSF, Inc. Common Stock'),
#  (590, 'BGSX', 'Build Acquisition Corp. Class A Common Stock'),
#  (591, 'BGSX=', 'Build Acquisition Corp. Units, each consisting of one share of Class A common stock and one-third of one redeemable warrant'),
#  (592, 'BGSX+', 'Build Acquisition Corp. Redeemable warrants, each whole warrant exercisable for one Class A common stock at an exercise price of $11.50'),
#  (593, 'BGT', 'BlackRock Floating Rate Income Trust'),
#  (594, 'BGX', 'Blackstone Long Short Credit Income Fund Common Shares'),
#  (595, 'BGY', 'Blackrock Enhanced International Dividend Trust'),
#  (596, 'BH', 'Biglari Holdings Inc. Class B Common Stock'),
#  (597, 'BH.A', 'Biglari Holdings Inc. Class A Common Stock'),
#  (598, 'BHB', 'Bar Harbor Bankshares, Inc. Common Stock'),
#  (599, 'BHC', 'Bausch Health Companies Inc. Common Stock'),
#  (600, 'BHE', 'Benchmark Electronics, Inc. Common Stock'),
#  (601, 'BHG', 'Bright Health Group, Inc. Common Stock'),
#  (602, 'BHK', 'Blackrock Core Bond Trust Blackrock Core Bond Trust'),
#  (603, 'BHLB', 'Berkshire Hills Bancorp, Inc. Common Stock'),
#  (604, 'BHP', 'BHP Group Limited American Depositary Shares (Each representing two Ordinary Shares)'),
#  (605, 'BHR', 'Braemar Hotels & Resorts Inc. Common Stock'),
#  (606, 'BHR-B', 'Braemar Hotels & Resorts Inc. 5.50% Series B Cumulative Convertible Preferred Stock, par value $0.01 per share'),
#  (607, 'BHR-D', 'Braemar Hotels & Resorts Inc. 8.25% Series D Cumulative Preferred Stock,  par value $0.01 per share'),
#  (608, 'BHV', 'BlackRock Virginia Municipal Bond Trust'),
#  (609, 'BHVN', 'Biohaven Pharmaceutical Holding Company Ltd. Common Shares'),
#  (610, 'BIBL', 'Inspire 100 ETF'),
#  (611, 'BIF', 'Boulder Growth & Income Fund, Inc.'),
#  (612, 'BIG', 'Big Lots, Inc. Common Stock'),
#  (613, 'BIGY', 'Defiance Next Gen Big Data ETF'),
#  (614, 'BIGZ', 'BlackRock Innovation and Growth Trust Common Shares of Beneficial Interest'),
#  (615, 'BIL', 'SPDR Bloomberg Barclays 1-3 Month T-Bill ETF'),
#  (616, 'BILL', 'Bill.com Holdings, Inc. Common Stock'),
#  (617, 'BILS', 'SPDR Bloomberg Barclays 3-12 Month T-Bill ETF'),
#  (618, 'BIO', 'Bio-Rad Laboratories, Inc. Class A Common Stock'),
#  (619, 'BIO.B', 'Bio-Rad Laboratories, Inc. Class B  Common Stock'),
#  (620, 'BIP', 'Brookfield Infrastructure Partners LP Limited Partnership Units'),
#  (621, 'BIP-A', 'Brookfield Infrastructure Partners LP 5.125% Class A Preferred Limited Partnership Units, Series 13'),
#  (622, 'BIP-B', 'Brookfield Infrastructure Partners LP 5.000% Class A Preferred Limited Partnership Units, Series 14'),
#  (623, 'BIPC', 'Brookfield Infrastructure Partners LP Class A Subordinate Voting Shares '),
#  (624, 'BIPH', 'Brookfield Infrastructure Corporation 5.000% Subordinated Notes due 2081'),
#  (625, 'BIT', 'BlackRock Multi-Sector Income Trust Common Shares of Beneficial Interest'),
#  (626, 'BITE', 'Bite Acquisition Corp. Common Stock'),
#  (627, 'BITE=', 'Bite Acquisition Corp. Units, each consisting of one share of common stock and one-half of one redeemable warrant'),
# ...
#  (792, 'BWX', 'SPDR Bloomberg Barclays Intl Treasury Bd'),
#  (793, 'BWXT', 'BWX Technologies, Inc. Common Stock'),
#  (794, 'BWZ', 'SPDR Bloomberg Barclays Short Term International Treasury Bond ETF'),
#  (795, 'BX', 'The Blackstone Group Inc. Common Stock'),
#  (796, 'BXC', 'Bluelinx Holdings Inc. Common Stock'),
#  (797, 'BXMT', 'Blackstone Mortgage Trust, Inc. Common Stock'),
#  (798, 'BXMX', 'Nuveen S&P 500 Buy-Write Income Fund Common Shares of Beneficial Interest'),
#  (799, 'BXP', 'Boston Properties, Inc. Common Stock'),
#  (800, 'BXS', 'BancorpSouth Bank Common Stock'),
#  (801, 'BXS-A', 'BancorpSouth Bank 5.50% Series A Non-Cumulative Perpetual Preferred Stock'),
#  (802, 'BY', 'Byline Bancorp, Inc. Common Stock'),
#  (803, 'BYD', 'Boyd Gaming Corporation Common Stock'),
#  (804, 'BYLD', 'iShares Yield Optimized Bond ETF'),
#  (805, 'BYM', 'Blackrock Municipal Income Quality Trust Common Shares of Beneficial Interest'),
#  (806, 'BZH', 'Beazer Homes USA, Inc. Common Stock'),
#  (807, 'BZQ', 'ProShares UltraShort MSCI Brazil Capped'),
#  (808, 'C', 'Citigroup, Inc. Common Stock'),
#  (809, 'C-J', 'Citigroup Inc. Dep Shs Repstg 1/1000 Pfd Ser J Fixed/Fltg'),
#  (810, 'C-K', 'Citigroup Inc. Dep Shs Repstg 1/1000th Pfd Ser K'),
#  (811, 'C-N', 'Citigroup Capital XIII 7.875% Fixed rate Floating Rate trust Preferred Securities (TruPS)'),
#  (812, 'CAAP', 'Corporacion America Airports SA Common Shares'),
#  (813, 'CABO', 'Cable One, Inc. Common Stock'),
#  (814, 'CACI', 'CACI International, Inc. Class A Common Stock'),
#  (815, 'CADE', 'Cadence Bancorporation Class A Common Stock'),
#  (816, 'CAE', 'CAE Inc. Ordinary Shares'),
#  (817, 'CAF', 'Morgan Stanley China A Share Fund Inc. Common Stock'),
#  (818, 'CAG', 'ConAgra Brands, Inc. Common Stock'),
#  (819, 'CAH', 'Cardinal Health, Inc. Common Stock'),
#  (820, 'CAI', 'CAI International, Inc. Common Stock'),
#  (821, 'CAI-A', 'CAI International, Inc. 8.50% Series A Fixed-to-Floating Rate Cumulative Redeemable Perpetual Preferred Stock'),
#  (822, 'CAI-B', 'CAI International, Inc. 8.50% Series B Fixed-to-Floating Rate Cumulative Redeemable Perpetual Preferred Stock'),
#  (823, 'CAJ', 'Canon, Inc. American Depositary Shares'),
#  (824, 'CAL', 'Caleres, Inc. Common Stock'),
#  (825, 'CALF', 'Pacer US Small Cap Cash Cows 100 ETF'),
#  (826, 'CALX', 'Calix, Inc Common Stock'),
#  (827, 'CANE', 'Teucrium Sugar Fund ETV'),
#  (828, 'CANF', 'Can-Fite Biopharma Ltd Sponsored ADR (Israel)'),
#  (829, 'CANG', 'Cango Inc. American Depositary Shares,  each representing two (2) Class A Ordinary Shares'),
#  (830, 'CANO', 'Cano Health, Inc. Class A Common Stock'),
#  (831, 'CANO+', 'Cano Health, Inc. Warrants'),
#  (832, 'CAPE', 'iPath Shiller CAPE ETN'),
#  (836, 'CAS', 'Cascade Acquisition Corp. Class A Common Stock'),
#  (837, 'CAS=', 'Cascade Acquisition Corp. Units, each consisting of one share of Class A Common Stock and one-half of one Redeemable Warrant'),
#  (838, 'CAS+', 'Cascade Acquisition Corp. Redeemable Warrants, each whole warrant exercisable for one share of Class A Common Stock at an exercise price of $11.50'),
#  (839, 'CAT', 'Caterpillar, Inc. Common Stock'),
#  (840, 'CATO', 'Cato Corporation (The) Class A Common Stock'),
#  (841, 'CB', 'Chubb Limited  Common Stock'),
#  (842, 'CBAH', 'CBRE Acquisition Holdings, Inc. Class A Common Stock'),
#  (843, 'CBAH=', 'CBRE Acquisition Holdings, Inc. SAIL securities, each consisting of one share of Class A common stock, and one-fifth of one redeemable warrant'),
#  (844, 'CBAH+', 'CBRE Acquisition Holdings, Inc. Warrants'),
#  (845, 'CBB', 'Cincinnati Bell Inc. Common Stock'),
#  (846, 'CBB-B', 'Cincinnati Bell Inc. Preferred Stock'),
#  (847, 'CBD', 'Companhia Brasileira de Distribuicao American Depsitary Shares; each representing one Common Share'),
#  (848, 'CBH', 'Virtus AllianzGI Convertible & Income 2024 Target Term Fund Common Shares of Beneficial Interest'),
#  (849, 'CBLS', 'Changebridge Capital Long/Short Equity ETF'),
#  (850, 'CBO', 'CBO (Listing Market - NYSE - Networks A/E) Common Stock'),
#  (851, 'CBOE', 'Cboe Global Markets, Inc. Common Stock'),
#  (852, 'CBON', 'VanEck Vectors ChinaAMC China Bond ETF'),
#  (853, 'CBRE', 'CBRE Group Inc Common Stock Class A'),
#  (854, 'CBSE', 'Changebridge Capital Sustainable Equity ETF'),
#  (855, 'CBT', 'Cabot Corporation Common Stock'),
#  (856, 'CBTG', 'Cabot Growth ETF'),
#  (857, 'CBU', 'Community Bank System, Inc. Common Stock'),
#  (858, 'CBX', 'CBX (Listing Market NYSE Networks AE) Common Stock'),
#  (859, 'CBZ', 'CBIZ, Inc. Common Stock'),
#  (860, 'CC', 'Chemours Company (The) Common Stock'),
#  (861, 'CCAC', 'CITIC Capital Acquisition Corp. Class A Ordinary Shares'),
#  (862, 'CCAC=', 'CITIC Capital Acquisition Corp. Units'),
#  (863, 'CCAC+', 'CITIC Capital Acquisition Corp. Warrants, each whole warrant exercisable for one Class A ordinary share at an exercise price of $11.50 per share'),
#  (864, 'CCCS', 'CCC Intelligent Solutions Holdings Inc. Common Stock'),
#  (865, 'CCCS+', 'CCC Intelligent Solutions Holdings Inc. Warrants'),
#  (866, 'CCEP', 'Coca-Cola Europacific Partners plc Ordinary Shares'),
#  (867, 'CCF', 'Chase Corporation Common Stock'),
#  (868, 'CCI', 'Crown Castle International Corp. (REIT) Common Stock'),
#  (869, 'CCJ', 'Cameco Corporation Common Stock'),
#  (870, 'CCK', 'Crown Holdings, Inc.'),
#  (871, 'CCL', 'Carnival Corporation Common Stock'),
#  (872, 'CCM', 'Concord Medical Services Holdings Limited ADS (Each represents three ordinary shares)'),
#  (873, 'CCO', 'Clear Channel Outdoor Holdings, Inc. Common Stock'),
#  (874, 'CCON', 'Direxion Connected Consumer ETF'),
#  (875, 'CCOR', 'Core Alternative ETF'),
#  (876, 'CCRV', 'iShares U.S. ETF Trust iShares Commodity Curve Carry Strategy ETF'),
#  (877, 'CCS', 'Century Communities, Inc. Common Stock'),
#  (878, 'CCU', 'Compania Cervecerias Unidas, S.A. Common Stock'),
#  (879, 'CCV', 'Churchill Capital Corp V Class A Common Stock'),
#  (880, 'CCV=', 'Churchill Capital Corp V Units, each consisting of one share of Class A common stock, and one-fourth of one redeemable warrant'),
#  (881, 'CCV+', 'Churchill Capital Corp V Warrants, each exercisable for one share of Class A common stock at an exercise price of $11.50 per share'),
#  (882, 'CCVI', 'Churchill Capital Corp VI Class A Common Stock'),
#  (883, 'CCVI=', 'Churchill Capital Corp VI Units, each consisting of one share of Class A common stock, and one-fifth of one redeemable warrant'),
#  (884, 'CCVI+', 'Churchill Capital Corp VI Warrants, each exercisable for one share of Class A common stock at an exercise price of $11.50 per share'),
#  (885, 'CCZ', 'Comcast Holdings ZONES'),
#  (886, 'CDAY', 'Ceridian HCM Holding Inc. Common Stock'),
#  (887, 'CDE', 'Coeur Mining, Inc. Common Stock'),
#  (888, 'CDOR', 'Condor Hospitality Trust, Inc. Common Stock'),
#  (889, 'CDR', 'Cedar Realty Trust, Inc. Common Stock'),
#  (890, 'CDR-B', 'Cedar Realty Trust, Inc. 7.25% Series B Cumulative Redeemable Preferred Stock'),
#  (891, 'CDR-C', 'Cedar Realty Trust, Inc. 6.50% Series C Cumulative Redeemable Preferred Stock'),
#  (892, 'CE', 'Celanese Corporation Celanese Corporation Common Stock'),
#  (893, 'CEA', 'China Eastern Airlines Corporation Ltd. Common Stock'),
#  (894, 'CEE', 'The Central and Eastern Europe Fund, Inc. (The) Common Stock'),
#  (895, 'CEF', 'Sprott Physical Gold and Silver Trust Units'),
#  (896, 'CEFD', 'ETRACS Monthly Pay 1.5X Leveraged Closed-End Fund Index ETN'),
#  (897, 'CEFS', 'Exchange Listed Funds Trust ETF'),
#  (898, 'CEI', 'Camber Energy, Inc. Common Stock'),
#  (899, 'CEIX', 'CONSOL Energy Inc. Common Stock '),
#  (900, 'CELG^', 'Bristol-Myers Squibb Company Celegne Contingent Value Rights'),
#  (901, 'CELP', 'Cypress Environmental Partners, L.P. Common Units representing limited partner interests'),
#  (902, 'CEM', 'ClearBridge MLP and Midstream Fund Inc. Common Stock'),
#  (903, 'CEMB', 'iShares J.P. Morgan EM Corporate Bond ETF'),
#  (904, 'CEN', 'Center Coast Brookfield MLP & Energy Infrastructure Fund'),
#  (905, 'CEPU', 'Central Puerto S.A. American Depositary Shares (each represents ten Common Shares)'),
#  (906, 'CEQP', 'Crestwood Equity Partners LP'),
#  (907, 'CEQP-', 'Crestwood Equity Partners LP Preferred Units representing limited partner interests'),
#  (908, 'CET', 'Central Securities Corporation Common Stock'),
#  (909, 'CEV', 'Eaton Vance California Municipal Income Trust Shares of Beneficial Interest'),
#  (910, 'CEW', 'WisdomTree Emerging Currency Strategy Fund'),
#  (911, 'CF', 'CF Industries Holdings, Inc. Common Stock'),
#  (912, 'CFCV', 'ClearBridge Focus Value ESG ETF'),
#  (913, 'CFG', 'Citizens Financial Group, Inc. Common Stock'),
#  (914, 'CFG-D', 'Citizens Financial Group, Inc. Depositary Shares, each representing a 1/40th Interest in a Share of 6.350% Fixed-to-Floating Rate Non-Cumulative Perpetual Preferred Stock, Series D'),
#  (915, 'CFG-E', 'Citizens Financial Group, Inc. Depositary Shares Each Representing 1/40th Interest in a Share of 5.000% Fixed-Rate Non-Cumulative Perpetual Preferred Stock, Series E'),
#  (916, 'CFR', 'Cullen/Frost Bankers, Inc. Common Stock'),
#  (1076, 'CODI-C', 'Compass Diversified Holdings 7.875% Series C Cumulative Preferred Shares'),
#  (917, 'CFR-B', 'Cullen/Frost Bankers, Inc. Depositary Shares, each representing a 1/40th ownership interest in a share of 4.450% non-cumulative perpetual preferred stock, Series B'),
#  (918, 'CFX', 'Colfax Corporation Common Stock'),
#  (919, 'CFXA', 'Colfax Corporation 5.75% Tangible Equity Units'),
#  (920, 'CGA', 'China Green Agriculture, Inc. Common Stock'),
#  (921, 'CGAU', 'Centerra Gold Inc. Common Shares'),
#  (922, 'CGW', 'Invesco S&P Global Water Index ETF'),
#  (923, 'CHAA', 'Catcha Investment Corp. Class A Ordinary Shares'),
#  (924, 'CHAA=', 'Catcha Investment Corp. Units, each consisting of one Class A ordinary share, and one-third of one redeemable warrant'),
#  (925, 'CHAA+', 'Catcha Investment Corp. Redeemable Warrants, each whole warrant exercisable for one Class A ordinary share at an exercise price of $11.50'),
#  (926, 'CHAD', 'Direxion Daily CSI 300 China A Shares Bear 1X Shares'),
#  (927, 'CHAQ', 'Chardan Healthcare Acquisition 2 Corp. Common Stock'),
#  (928, 'CHAQ=', 'Chardan Healthcare Acquisition 2 Corp. Units, each consisting of one share of Common Stock, and one Warrant entitling the holder to purchase one-half of a share of Common Stock'),
#  (929, 'CHAQ+', 'Chardan Healthcare Acquisition 2 Corp. Warrants, entitling the holder thereof to purchase one-half (1/2) of a share of common stock at a price of $11.50 per whole share'),
#  (930, 'CHAU', 'Direxion Daily CSI 300 China A Share Bull 2X Shares'),
#  (931, 'CHCT', 'Community Healthcare Trust Incorporated Common Stock'),
#  (932, 'CHD', 'Church & Dwight Company, Inc. Common Stock'),
#  (933, 'CHE', 'Chemed Corp'),
#  (934, 'CHFW', 'Consonance-HFW Acquisition Corp. Class A Ordinary Shares'),
#  (935, 'CHFW=', 'Consonance-HFW Acquisition Corp. Units, each consisting of one Class A Ordinary Share, and one-third of one Warrant to acquire one Class A Ordinary Share'),
#  (936, 'CHFW+', 'Consonance-HFW Acquisition Corp. Warrants, each whole warrant exercisable for one Class A Ordinary Share at an exercise price of $11.50'),
#  (937, 'CHGG', 'Chegg, Inc. Common Stock'),
#  (938, 'CHGX', 'Change Finance U.S. Large Cap Fossil Fuel Free ETF'),
#  (939, 'CHH', 'Choice Hotels International, Inc. Common Stock'),
#  (940, 'CHIC', 'Global X Funds Global X MSCI China Communication Services ETF'),
#  (941, 'CHIE', 'Global X MSCI China Energy ETF'),
#  (942, 'CHIH', 'Global X Funds Global X MSCI China Health Care ETF'),
#  (943, 'CHII', 'Global X MSCI China Industrials ETF'),
#  (944, 'CHIK', 'Global X Funds Global X MSCI China Information Technology ETF'),
#  (945, 'CHIL', 'Global X Funds Global X MSCI China Large-Cap 50 ETF'),
#  (946, 'CHIM', 'Global X MSCI China Materials ETF'),
#  (947, 'CHIQ', 'Global X MSCI China Consumer Discretionary ETF'),
#  (948, 'CHIR', 'Global X Funds Global X MSCI China Real Estate ETF'),
#  (949, 'CHIS', 'Global X Funds Global X MSCI China Consumer Staples ETF'),
#  (950, 'CHIU', 'Global X Funds Global X MSCI China Utilities ETF'),
#  (951, 'CHIX', 'Global X MSCI China Financials ETF'),
#  (952, 'CHMI', 'Cherry Hill Mortgage Investment Corporation Common Stock'),
#  (953, 'CHMI-A', 'Cherry Hill Mortgage Investment Corporation 8.20% Series A Cumulative Redeemable Preferred Stock'),
#  (954, 'CHMI-B', 'Cherry Hill Mortgage Investment Corporation 8.250% Series B Fixed-to-Floating Rate Cumulative Redeemable Preferred Stock'),
#  (955, 'CHN', 'China Fund, Inc. (The) Common Stock'),
#  (956, 'CHPT', 'ChargePoint Holdings, Inc. Common Stock'),
#  (957, 'CHRA', 'Charah Solutions, Inc. Common Stock'),
#  (958, 'CHS', "Chico's FAS, Inc. Common Stock"),
#  (959, 'CHT', 'Chunghwa Telecom Co., Ltd.'),
#  (960, 'CHWY', 'Chewy, Inc. Class A Common Stock'),
#  (961, 'CI', 'Cigna Corporation Common Stock'),
#  (962, 'CIA', 'Citizens, Inc. Class A Common Stock ($1.00 Par)'),
#  (963, 'CIB', 'BanColombia S.A. Common Stock'),
#  (964, 'CIEN', 'Ciena Corporation Common Stock'),
#  (965, 'CIF', 'MFS Intermediate High Income Fund Common Stock'),
#  (966, 'CIG', 'Comp En De Mn Cemig ADS American Depositary Shares'),
#  (967, 'CIG.C', 'Comp En De Mn Cemig ADS American Depositary Receipts'),
#  (968, 'CII', 'Blackrock Capital and Income Fund, Inc.'),
#  (969, 'CIK', 'Credit Suisse Asset Management Income Fund, Inc. Common Stock'),
#  (970, 'CIM', 'Chimera Investment Corporation Common Stock'),
#  (971, 'CIM-A', 'Chimera Investment Corporation 8.00% Series A Cumulative Redeemable Preferred Stock'),
#  (972, 'CIM-B', 'Chimera Investment Corporation 8.00% Series B Fixed-to-Floating Rate Cumulative Redeemable Preferred Stock'),
#  (973, 'CIM-C', 'Chimera Investment Corporation 7.75% Series C Fixed-to-Floating Rate  Cumulative Redeemable  Preferred Stock'),
#  (974, 'CIM-D', 'Chimera Investment Corporation 8.00% Series D Fixed-to-Floating Rate Cumulative Redeemable Preferred Stock'),
#  (975, 'CINR', 'Ciner Resources LP Common Units representing Limited Partner Interests'),
#  (976, 'CIO', 'City Office REIT, Inc. Common Stock'),
#  (977, 'CIO-A', 'City Office REIT, Inc. 6.625% Series A Cumulative Redeemable Preferred Stock'),
#  (978, 'CIR', 'CIRCOR International, Inc. Common Stock'),
#  (979, 'CIT', 'CIT Group Inc (DEL) Common Stock'),
#  (980, 'CIT-B', 'CIT Group Inc (DEL) 5.625 % Non-Cumulative Perpetual Preferred Stock, Series B'),
#  (981, 'CIX', 'CompX International Inc. Common Stock'),
#  (982, 'CIXX', 'CI Financial Corp. Common Shares'),
#  (983, 'CKX', 'CKX Lands, Inc. Common Stock'),
#  (984, 'CL', 'Colgate-Palmolive Company Common Stock'),
#  (985, 'CLAA', 'Colonnade Acquisition Corp. II Class A Ordinary Shares'),
#  (986, 'CLAA=', 'Colonnade Acquisition Corp. II Units, each consisting of one Class A ordinary share and one-fifth of one redeemable warrant'),
#  (987, 'CLAA+', 'Colonnade Acquisition Corp. II Warrants, each whole warrant exercisable for one Class A ordinary share at an exercise price of $11.50 per share'),
#  (988, 'CLAS', 'Class Acceleration Corp. Class A Common Stock'),
#  (989, 'CLAS=', 'Class Acceleration Corp. Units, each consisting of one share of Class A common stock, and one-half of one redeemable warrant'),
#  (990, 'CLAS+', 'Class Acceleration Corp. Redeemable Warrants, each whole warrant exercisable for one share of Class A Common Stock at an exercise price of $11.50'),
#  (991, 'CLB', 'Core Laboratories N.V. Common Stock'),
#  (992, 'CLBR', 'Colombier Acquisition Corp. Class A Common Stock'),
#  (993, 'CLBR=', 'Colombier Acquisition Corp. Units, each consisting of one share of Class A common stock, and one-third of one redeemable warrant'),
#  (1774, 'ESGV', 'Vanguard ESG U.S. Stock ETF'),
#  (994, 'CLBR+', 'Colombier Acquisition Corp. Warrants, each exercisable for one share of Class A common stock at an exercise price of $11.50 per share'),
#  (995, 'CLDL', 'Direxion Daily Cloud Computing Bull 2X Shares'),
#  (996, 'CLDR', 'Cloudera, Inc. Common Stock'),
#  (997, 'CLDS', 'Direxion Daily Cloud Computing Bear 2X Shares'),
#  (998, 'CLDT', 'Chatham Lodging Trust (REIT) Common Shares of Beneficial Interest'),
#  ...]

# %% [markdown]
# Now you can use the `query_output` dataframe to do any other analysis or visualization that you learned in your other courses.

# %% [markdown]
# ### Using psycopg2 package (OPTIONAL)
#
# Refer [here](../additional/pscopg2.ipynb) if you want to know on psycopg2 package and how to use it.

# %% [markdown]
# ```{warning}
# If you are not using your RDS instance, make sure you shut it down from your AWS console. You can always restart it when working on your assignments/projects. However, your credits are limited, and if those get exhausted, we won't provide you with more.
# ```
#
# ```{note}
# Closing your lab doesn't shut down the RDS instance; you need to shut it down from your AWS console explicitly.
# ```

# %% [markdown]
# ## Can you ?
#
# - Setup your database in cloud ?
# - Recollect various options that are available while setting up ?
# - connect to your databases from various options (jupyter, tableau, pgadmin etc)that we discussed ?
# - use good practices in storing passwords and using them from your notebook ?
# - Load data to your database using dumps ?
#
# ## Class activity
#
# ```{margin}
# <img src='img/cloudb2.png' width=50%>
# ```
#
# ```{note}
# Check worksheet 2 in canvas for detailed instructions on activity and submission instructions.
# ```
#
# - Setup your RDS instance
# - Load data to your RDS instance using dump
# - Ensure you installed the necessary packages for this course (bait580env.yml). Refer to Conda installation instructions for more details.
